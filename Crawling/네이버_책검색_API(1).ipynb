# %%
import json ## JSON
import urllib.request ## 웹페이지 요청 ==> 브라우저 사용
client_id = "3wU5xwXfFVL4LweQzLHQ" # 애플리케이션 ID
client_secret = "K60NkftSAH" # 애플리케이션  Secret

encText = urllib.parse.quote("파이썬") ## 한글 URL 추가 ==> URL 인코딩
rangeText_start = urllib.parse.quote("1") ## 요청 변수
url = "https://openapi.naver.com/v1/search/book?query=" + encText + "&display=1" + "&start=" + rangeText_start ## 요청 URL + 요청 변수

request = urllib.request.Request(url) ## urllib.request.Request 클래스 == URL 요청 관련 정보 담는 추상화 클래스
request.add_header("X-Naver-Client-Id",client_id) ## add_header 메서드 ==> 헤더 정보 추가
request.add_header("X-Naver-Client-Secret",client_secret)  ## add_header 메서드 ==> 헤더 정보 추가

response = urllib.request.urlopen(request) ## urllib.request.urlopen 메서드 ==> url string OR request 객체 전달 받음
rescode = response.getcode()
list = []

if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8')) ## 인코딩 ==> 출력
    text = response_body.decode('utf-8')
    print(type(text))
    
else:
    print("Error Code:" + rescode) ## 네이버 API 오류 코드 ==> 가이드 참고
# Out:
# {
# "lastBuildDate": "Sat, 25 Dec 2021 22:38:19 +0900",
# "total": 1430,
# "start": 1,
# "display": 1,
# "items": [
# {
# "title": "이것이 취업을 위한 코딩 테스트다 with <b>파이썬</b> (취업과 이직을 결정하는 알고리즘 인터뷰 완벽 가이드)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16439154",
# "image": "https://bookthumb-phinf.pstatic.net/cover/164/391/16439154.jpg?type=m1&udate=20200928",
# "author": "나동빈",
# "price": "34000",
# "discount": "30600",
# "publisher": "한빛미디어",
# "pubdate": "20200805",
# "isbn": "1162243074 9791162243077",
# "description": "8가지 핵심 알고리즘 이론을 쉽게 설명하고, 관련 실전 문제를 풀이했다. 출제 유형 분석, 이론 설명, 기출문제 풀이까지! 어떤 코딩 테스트도 이 책 한 권으로 대비할 수 있을 것이다. 코딩 테스트에서 주로 선택하는 <b>파이썬</b>을 기반으로 설명되어 있으며, <b>파이썬</b> 코드 외에도 C/C++, 자바 코드를 추가로 제공한다."
#
# }
# ]
# }
#
# <class 'str'>

# %% [markdown]
# # total

# %%
import json ## JSON
import urllib.request ## 웹페이지 요청 ==> 브라우저 사용
client_id = "3wU5xwXfFVL4LweQzLHQ" # 애플리케이션 ID
client_secret = "K60NkftSAH" # 애플리케이션  Secret

encText = urllib.parse.quote("파이썬") ## 한글 URL 추가 ==> URL 인코딩
rangeText_start = urllib.parse.quote("1") ## 요청 변수
url = "https://openapi.naver.com/v1/search/book?query=" + encText + "&display=100" + "&start=" + rangeText_start ## 요청 URL + 요청 변수

request = urllib.request.Request(url) ## urllib.request.Request 클래스 == URL 요청 관련 정보 담는 추상화 클래스
request.add_header("X-Naver-Client-Id",client_id) ## add_header 메서드 ==> 헤더 정보 추가
request.add_header("X-Naver-Client-Secret",client_secret)  ## add_header 메서드 ==> 헤더 정보 추가

response = urllib.request.urlopen(request) ## urllib.request.urlopen 메서드 ==> url string OR request 객체 전달 받음
rescode = response.getcode()
list = []

if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8')) ## 인코딩 ==> 출력
    text = response_body.decode('utf-8')
    print(type(text))
    dict = json.loads(text)
    total = dict['total']
    print("검색결과", total)
else:
    print("Error Code:" + rescode) ## 네이버 API 오류 코드 ==> 가이드 참고
# Out:
# {
# "lastBuildDate": "Fri, 24 Dec 2021 12:29:59 +0900",
# "total": 1428,
# "start": 1,
# "display": 100,
# "items": [
# {
# "title": "이것이 취업을 위한 코딩 테스트다 with <b>파이썬</b> (취업과 이직을 결정하는 알고리즘 인터뷰 완벽 가이드)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16439154",
# "image": "https://bookthumb-phinf.pstatic.net/cover/164/391/16439154.jpg?type=m1&udate=20200928",
# "author": "나동빈",
# "price": "34000",
# "discount": "30600",
# "publisher": "한빛미디어",
# "pubdate": "20200805",
# "isbn": "1162243074 9791162243077",
# "description": "8가지 핵심 알고리즘 이론을 쉽게 설명하고, 관련 실전 문제를 풀이했다. 출제 유형 분석, 이론 설명, 기출문제 풀이까지! 어떤 코딩 테스트도 이 책 한 권으로 대비할 수 있을 것이다. 코딩 테스트에서 주로 선택하는 <b>파이썬</b>을 기반으로 설명되어 있으며, <b>파이썬</b> 코드 외에도 C/C++, 자바 코드를 추가로 제공한다."
#
# },
# {
# "title": "혼자 공부하는 <b>파이썬</b> (<b>파이썬</b> 최신 버전 반영)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=15028688",
# "image": "https://bookthumb-phinf.pstatic.net/cover/150/286/15028688.jpg?type=m1&udate=20211206",
# "author": "윤인성",
# "price": "18000",
# "discount": "16200",
# "publisher": "한빛미디어",
# "pubdate": "20190610",
# "isbn": "1162241888 9791162241882",
# "description": "1:1 과외하듯 배우는 <b>파이썬</b> 프로그래밍 자습서(<b>파이썬</b> 최신 버전 반영)\n27명의 베타리더 검증으로, ‘함께 만든’ 입문자 맞춤형 도서\n\n이 책은 독학으로 프로그래밍 언어를 처음 배우려는 입문자가, 혹은 <b>파이썬</b>을 배우려는 입문자가 ‘꼭 필요한 내용을 제대로’ 학습할 수 있도록 구성했다. ‘무엇을’... "
#
# },
# {
# "title": "Do it! 점프 투 <b>파이썬</b>",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=15052904",
# "image": "https://bookthumb-phinf.pstatic.net/cover/150/529/15052904.jpg?type=m1&udate=20200910",
# "author": "박응용",
# "price": "18800",
# "discount": "16900",
# "publisher": "이지스퍼블리싱",
# "pubdate": "20190620",
# "isbn": "1163030910 9791163030911",
# "description": "<b>파이썬</b> 4년 연속 베스트셀러 1위!\n《DO IT! 점프 투 <b>파이썬</b>》 전면 개정판 출시!문과생도 중고등학생도 직장인도 프로그래밍에 눈뜨게 만든 바로 그 책이... 점프 투 <b>파이썬</b>》으로 출간되었던 이 책은 약 4년 동안의 피드백을 반영하여 초보자가 더 빠르게 입문하고, 더 깊이 있게 공부할 수 있도록 개정되었다.... "
#
# },
# {
# "title": "<b>파이썬</b> 알고리즘 인터뷰 (95가지 알고리즘 문제 풀이로 완성하는 코딩 테스트)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16406247",
# "image": "https://bookthumb-phinf.pstatic.net/cover/164/062/16406247.jpg?type=m1&udate=20211209",
# "author": "박상길",
# "price": "38000",
# "discount": "34200",
# "publisher": "책만",
# "pubdate": "20200715",
# "isbn": "1189909170 9791189909178",
# "description": "물론, <b>파이썬</b>으로 구현하는 코드 풀이를 통해 성능 최적화 기법, <b>파이썬</b>의 핵심 문법과 다양한 실용 테크닉까지 배울 수 있는, 초보 개발자와 숙련 개발자... 이 책은 현업과 실무에 유용한 주요 알고리즘 이론을 깊숙이 이해하고, <b>파이썬</b>의 핵심 기능과 문법까지 상세하게 이해할 수 있는 취업용 코딩 테스트를... "
#
# },
# {
# "title": "<b>파이썬</b> 무작정 따라하기 (미래의 프로그래머를 위한)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21354236",
# "image": "https://bookthumb-phinf.pstatic.net/cover/213/542/21354236.jpg?type=m1&udate=20211215",
# "author": "송석리|서승희",
# "price": "16000",
# "discount": "14400",
# "publisher": "길벗",
# "pubdate": "20211220",
# "isbn": "1165217899 9791165217891",
# "description": "초등학생을 위한 <b>파이썬</b> 교재첫 코딩을 쉽고 재밌게!이 책은 초등학생부터 청소년까지 쉽고 체계적으로 <b>파이썬</b> 코딩을 배울 수 있는 책입니다. 데이터... 블록 코딩을 끝낸 뒤 텍스트 코딩을 본격적으로 배우고 싶다면 이 책으로 시작해 보세요!<b>파이썬</b> 설치부터 활용 방법, 기본 개념을 꼼꼼하게 자세하게... "
#
# },
# {
# "title": "<b>파이썬</b> 증권 데이터 분석 (<b>파이썬</b> 입문, 웹 스크레이핑, 트레이딩 전략, 자동 매매)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16381920",
# "image": "https://bookthumb-phinf.pstatic.net/cover/163/819/16381920.jpg?type=m1&udate=20201117",
# "author": "김황후",
# "price": "32000",
# "discount": "28800",
# "publisher": "한빛미디어",
# "pubdate": "20200701",
# "isbn": "1162243201 9791162243206",
# "description": "투자 기법과 프로그래밍 기술로 &#x0D;자신만의 퀀트 투자 시스템을 완성하라&#x0D;&#x0D;『<b>파이썬</b> 증권 데이터 분석』은 웹 스크레이핑으로 증권 데이터를 주기적으로 자동 수집, 분석, 자동 매매, 예측하는 전 과정을 <b>파이썬</b>으로 직접 구현한다. 그 과정에서 금융 데이터 처리 기본 라이브러리(팬더스)부터 주가... "
#
# },
# {
# "title": "<b>파이썬</b> 머신러닝 완벽 가이드 (다양한 캐글 예제와 함께 기초 알고리즘부터 최신 기법까지 배우는)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16238302",
# "image": "https://bookthumb-phinf.pstatic.net/cover/162/383/16238302.jpg?type=m1&udate=20200423",
# "author": "권철민",
# "price": "38000",
# "discount": "34200",
# "publisher": "위키북스",
# "pubdate": "20200207",
# "isbn": "1158391927 9791158391928",
# "description": "자세한 이론 설명과 <b>파이썬</b> 실습을 통해 머신러닝을 완벽하게 배울 수 있습니다!《<b>파이썬</b> 머신러닝 완벽 가이드》는 이론 위주의 머신러닝 책에서 탈피해 다양한 실전 예제를 직접 구현해 보면서 머신러닝을 체득할 수 있도록 만들었습니다.  캐글과 UCI 머신러닝 리포지토리에서 난이도가 있는 실습... "
#
# },
# {
# "title": "쉽게 따라 만드는 <b>파이썬</b> 주식 자동매매 시스템 (증권사 API 사용, 매매전략 구현, 실전 투자 전환까지!)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21119890",
# "image": "https://bookthumb-phinf.pstatic.net/cover/211/198/21119890.jpg?type=m1&udate=20211207",
# "author": "박준성",
# "price": "28000",
# "discount": "25200",
# "publisher": "길벗",
# "pubdate": "20211014",
# "isbn": "1165217163 9791165217167",
# "description": "개발 환경 구축부터 실전 투자 전환까지\n<b>파이썬</b>으로 나만의 주식 자동매매 시스템을 만든다!\n\n이 책은 <b>파이썬</b>을 이용하여 주식 자동매매 시스템을 만드는... 개발 환경을 구축하고, 프로젝트를 만드는 데 필요한 기초 <b>파이썬</b> 문법은 물론 증권 데이터를 주고받기 위해 키움증권 API를 사용하는 방법과 웹... "
#
# },
# {
# "title": "<b>파이썬</b>을 이용한 비트코인 자동매매",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=18214660",
# "image": "https://bookthumb-phinf.pstatic.net/cover/182/146/18214660.jpg?type=m1&udate=20210316",
# "author": "유대표|조대표",
# "price": "27000",
# "discount": "24300",
# "publisher": "파이스탁",
# "pubdate": "20210322",
# "isbn": "1196608814 9791196608811",
# "description": "이 책은 최근 인기 있는 프로그래밍 언어인 <b>파이썬</b>을 사용하여 국내 3대 거래소(코빗, 빗썸, 업비트)... 프로그래밍 경험이 없는 일반인을 대상으로 <b>파이썬</b> 기초 문법부터 시작하여 24시간 실시간 자동... 있어 <b>파이썬</b>을 처음 배우는 분들이 유익하고 재미있게 프로그래밍을 배울 수 있도록 합니다. 책에서... "
#
# },
# {
# "title": "머신 러닝 교과서 with <b>파이썬</b>, 사이킷런, 텐서플로 (최신 넘파이, 사이킷런, 텐서플로 2로 배우는 머신 러닝, 딥러닝 핵심 알고)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=18829375",
# "image": "https://bookthumb-phinf.pstatic.net/cover/188/293/18829375.jpg?type=m1&udate=20211207",
# "author": "세바스찬 라시카|바히드 미자리리",
# "price": "44000",
# "discount": "39600",
# "publisher": "길벗",
# "pubdate": "20210331",
# "isbn": "1165215187 9791165215187",
# "description": "<b>파이썬</b> 언어와 <b>파이썬</b> 기반의 머신 러닝 핵심 라이브러리(SciPy, NumPy, scikit-learn, Matplotlib, Pandas)를 사용해 머신 러닝을, 텐서플로(TensorFlow 2)를 사용해 딥러닝을 실습해본다. 특히 딥러닝은 최신 텐서플로 2에 맞춰 대폭 수정 및 보강되었다. 그러고 나서 GAN과 강화 학습도 자세하게 다룬다. 머신 러닝과... "
#
# },
# {
# "title": "생활코딩 머신러닝 실습편 with <b>파이썬</b> 텐서플로 (누구나 쉽게 시작하는 인공지능 첫걸음)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21344673",
# "image": "https://bookthumb-phinf.pstatic.net/cover/213/446/21344673.jpg?type=m1&udate=20211201",
# "author": "이숙번|이고잉",
# "price": "24000",
# "discount": "21600",
# "publisher": "위키북스",
# "pubdate": "20211215",
# "isbn": "1158392990 9791158392994",
# "description": "너무 어려워서 높은 벽처럼 느껴졌던 ‘딥러닝(DEEP LEARNING)’, 이 책과 함께라면 쉽게 시작할 수 있습니다!《생활코딩 머신러닝 실습편 WITH <b>파이썬</b> 텐서플로》는 초등학생부터 어르신까지, 딥러닝이 궁금하고 직접 코딩해보고 싶은 모든 분을 위한 책입니다. 복잡한 원리와 수학을 몰라도... "
#
# },
# {
# "title": "Do it! 첫 코딩 with <b>파이썬</b> (보통 사람이 알아야 할 프로그래밍 기초)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17727701",
# "image": "https://bookthumb-phinf.pstatic.net/cover/177/277/17727701.jpg?type=m1&udate=20210323",
# "author": "정동균",
# "price": "18000",
# "discount": "16200",
# "publisher": "이지스퍼블리싱",
# "pubdate": "20210115",
# "isbn": "1163032158 9791163032151",
# "description": "첫 코딩》 <b>파이썬</b> 버전 출간!\n국내 최초 ‘문과식’ 코딩 입문서!\n147가지 비유와 그림, 무료 온라인... 첫 코딩》이 <b>파이썬</b> 버전으로 출간 되었습니다.\n‘공대생도 놀란 책’에 걸맞은 147가지 비유와... 첫 코딩》 자바 버전보다 80쪽 늘어난 이 책에서는 특별히 <b>파이썬</b>으로 코딩하면 만나게 될 ‘데이터... "
#
# },
# {
# "title": "Do it! <b>파이썬</b> 생활 프로그래밍",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16437083",
# "image": "https://bookthumb-phinf.pstatic.net/cover/164/370/16437083.jpg?type=m1&udate=20211216",
# "author": "김창현",
# "price": "20000",
# "discount": "18000",
# "publisher": "이지스퍼블리싱",
# "pubdate": "20200727",
# "isbn": "1163031739 9791163031734",
# "description": "집필한 <b>파이썬</b> 생활 프로그래밍 책!\n웹 크롤링부터 데이터 분석까지, 11가지 프로그램을 내 손으로 직접 만든다!이 책은 생활 프로그래머 김창현 박사가 일상과 업무에서 <b>파이썬</b> 프로그래밍을 활용한 경험을... 이 프로그램들은 <b>파이썬</b> 문법을 한 번이라도 배운 적이 있는 사람이라면 누구나 따라 할 수 있는... "
#
# },
# {
# "title": "모두의 <b>파이썬</b> (20일 만에 배우는 프로그래밍 기초)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14126163",
# "image": "https://bookthumb-phinf.pstatic.net/cover/141/261/14126163.jpg?type=m1&udate=20210210",
# "author": "이승찬",
# "price": "12000",
# "discount": "10800",
# "publisher": "길벗",
# "pubdate": "20181009",
# "isbn": "1160505853 9791160505856",
# "description": "<b>파이썬</b> 분야 & 어린이 코딩 교육 분야\n2년 연속 베스트셀러! 개정판 출간!\n즐겁게 시작하는 나의 첫 프로그래밍!\n프로그래밍을 한 번도 해본 적이 없어도 괜찮다. <b>파이썬</b>이 무엇인지 몰라도 상관 없다.... 어느새 <b>파이썬</b> 프로그램으로 멋진 그림을 그리고, 계산을 하고, 간단한 게임을 만들고, 수학 문제를... "
#
# },
# {
# "title": "선형대수와 통계학으로 배우는 머신러닝 with <b>파이썬</b> (선형대수와 통계학으로 배우는 머신러닝 with <b>파이썬</b>)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17853038",
# "image": "https://bookthumb-phinf.pstatic.net/cover/178/530/17853038.jpg?type=m1&udate=20211207",
# "author": "장철원",
# "price": "37500",
# "discount": "33750",
# "publisher": "비제이퍼블릭",
# "pubdate": "20210126",
# "isbn": "1165920395 9791165920395",
# "description": "머신러닝에 필요한 선형대수, 통계학, 최적화 이론부터\n<b>파이썬</b>, 사이킷런, 텐서플로를 활용한 실습까지\n\n『선형대수와 통계학으로 배우는 머신러닝 with <b>파이썬</b>』은 머신러닝의 기본적인 사용 방법뿐만 아니라 통계학, 선형대수, 최적화 이론 등 머신러닝에 필요한 배경 이론까지 다룬다. 머신러닝 알고리즘을... "
#
# },
# {
# "title": "혼자 공부하는 첫 프로그래밍 with <b>파이썬</b> (1:1 과외하듯 배우는 왕초보 코딩 입문서)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16385280",
# "image": "https://bookthumb-phinf.pstatic.net/cover/163/852/16385280.jpg?type=m1&udate=20211207",
# "author": "문현일",
# "price": "17000",
# "discount": "15300",
# "publisher": "한빛미디어",
# "pubdate": "20200630",
# "isbn": "1162243031 9791162243039",
# "description": "비전공자도 ‘혼공’ 할 수 있다!\n1:1 과외하듯 배우는 왕초보 코딩 입문서\n\n유튜브 강의! 그림으로 보여주는 ‘눈코딩’ 예제! 프로그램 설치 없이 온라인 실습! 부록 용어 노트! 이 모든 것을 제공하기에 비전공자도 프로그래밍을 독학할 수 있습니다. 이 책은 비전공자가 시중에 나온 프로그래밍 책을 이해할 수... "
#
# },
# {
# "title": "모두의 데이터 분석 with <b>파이썬</b> (실생활 예제로 시작하는 데이터 분석 첫걸음)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14820571",
# "image": "https://bookthumb-phinf.pstatic.net/cover/148/205/14820571.jpg?type=m1&udate=20211029",
# "author": "송석리|이현아",
# "price": "18000",
# "discount": "16200",
# "publisher": "길벗",
# "pubdate": "20190425",
# "isbn": "1160507813 9791160507812",
# "description": "데이터 다운로드부터 정제, 문제 해결 방법 구상, <b>파이썬</b> 코드로 구현까지 차근차근 진행하면서, 초보자가 데이터 분석의 성공적인 첫걸음을 내딛도록... 최소한의 <b>파이썬</b> 문법만을 사용하여 설명하므로 프로그래밍 경험이 적은 사람도 충분히 따라 할 수 있습니다. 이제 데이터 분석 전문가가 아니어도, 자신의... "
#
# },
# {
# "title": "<b>파이썬</b> 코딩의 기술 (Effective Python 2nd,똑똑하게 코딩하는 법)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16876960",
# "image": "https://bookthumb-phinf.pstatic.net/cover/168/769/16876960.jpg?type=m1&udate=20211208",
# "author": "브렛 슬라킨",
# "price": "32000",
# "discount": "28800",
# "publisher": "길벗",
# "pubdate": "20201030",
# "isbn": "1165213192 9791165213190",
# "description": "아마존 <b>파이썬</b> 프로그래밍 분야 베스트셀러, 〈Effective Python〉 전면 개정 증보판! \n<b>파이썬</b>의 매력과 강점을 이용해 강력하고 우수한 성능의 코드를 작성하는 90가지 방법!\n\n<b>파이썬</b>다운 방식으로 프로그램을 작성하는 방법, <b>파이썬</b>을 사용하는 가장 좋은 방법에 대한 통찰을 담았다! 2판에서는 <b>파이썬</b> 3.... "
#
# },
# {
# "title": "Do it! 첫 <b>파이썬</b> (게임하듯 배우는 나의 첫 프로그래밍 책)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16324192",
# "image": "https://bookthumb-phinf.pstatic.net/cover/163/241/16324192.jpg?type=m1&udate=20211213",
# "author": "엘리스 코딩",
# "price": "14000",
# "discount": "12600",
# "publisher": "이지스퍼블리싱",
# "pubdate": "20200410",
# "isbn": "1163031569 9791163031567",
# "description": "왕초보 맞춤 <b>파이썬</b> 입문서\n\n초등 고학년부터 필수인 코딩, 주인공 ‘엘리스 토끼’와 함께 게임하듯 배우세요. 176가지 그림과 45가지 코딩 문제를 풀다... 마지막 과제인 ‘점심 메뉴 추첨기’ 프로그램까지 만들면 ‘<b>파이썬</b> 이수증’도 드립니다. 제대로 설계된 코딩 교육 콘텐츠를 찾는 학생·학부모·선생님은... "
#
# },
# {
# "title": "모두의 인공지능 with <b>파이썬</b> (누구나 쉽게 시작하는 딥러닝 기초 프로그래밍)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17664105",
# "image": "https://bookthumb-phinf.pstatic.net/cover/176/641/17664105.jpg?type=m1&udate=20210814",
# "author": "이영호",
# "price": "22000",
# "discount": "19800",
# "publisher": "길벗",
# "pubdate": "20201230",
# "isbn": "1165213982 9791165213985",
# "description": "<b>파이썬</b>을 모르는 사람도 볼 수 있도록 기초 <b>파이썬</b> 문법을 짚어주고, 개발 환경(코랩, 텐서플로, 케라스)을 구축하는 방법도 상세히 알려준다. 뒤에서는 앞에서 배운 원리를 활용하여 실제로 인공지능 모델을 만들어 본다. 손글씨로 쓴 숫자를 인식하는 인공지능, 코로나 19 확진자 수를 예측하는 인공지능... "
#
# },
# {
# "title": "Do it! 장고+부트스트랩 <b>파이썬</b> 웹 개발의 정석 (웹 기초부터 블로그 개발 배포 운영까지, 만들면서 배우는 웹 개발 A to Z)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17717279",
# "image": "https://bookthumb-phinf.pstatic.net/cover/177/172/17717279.jpg?type=m1&udate=20211207",
# "author": "이성용|김태곤",
# "price": "32000",
# "discount": "28800",
# "publisher": "이지스퍼블리싱",
# "pubdate": "20210118",
# "isbn": "1163032069 9791163032069",
# "description": "만들면서 배우는 <b>파이썬</b> 웹 개발 A to Z!\n<b>파이썬</b> 기초 문법만 알면 나만의 블로그 사이트를 만들 수 있다!\n\n이 책은 블로그 웹 사이트를 만드는 실습을... 이 과정에서 HTML, CSS, 자바스크립트부터 부트스트랩, <b>파이썬</b> 웹 프레임워크 장고(Django), 도커(Docker), 아마존 웹 서비스(AWS)까지 웹 사이트를 만들고... "
#
# },
# {
# "title": "<b>파이썬</b> 매일 코딩 (매일 10분, 50가지 연습 문제로 키우는 <b>파이썬</b> 코딩 실력!)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21307305",
# "image": "https://bookthumb-phinf.pstatic.net/cover/213/073/21307305.jpg?type=m1&udate=20211211",
# "author": "루벤 M. 러너",
# "price": "22000",
# "discount": "19800",
# "publisher": "길벗",
# "pubdate": "20211130",
# "isbn": "1165217880 9791165217884",
# "description": "능숙한 <b>파이썬</b> 프로그래머가 되기 위한 지름길!\n다양한 <b>파이썬</b> 문제를 풀어보며 프로그래밍 기술을 배우고 자신감을 키우자!\n \n<b>파이썬</b>을 마스터할 수 있는 유일한 방법은 연습이다. 숫자 맞히기 게임, 16진수 출력하기와 같은 간단한 문제부터 판매세 계산하기, 순환하는 이터레이터 만들기와 같은 궁금한... "
#
# },
# {
# "title": "Let’s Get IT <b>파이썬</b> 프로그래밍 (데이터 분석 프로젝트로 프로그래밍 사고력 기르기)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20677567",
# "image": "https://bookthumb-phinf.pstatic.net/cover/206/775/20677567.jpg?type=m1&udate=20211207",
# "author": "안지혜",
# "price": "22000",
# "discount": "19800",
# "publisher": "길벗",
# "pubdate": "20210705",
# "isbn": "1165215969 9791165215965",
# "description": "자세히 설명하고 직관적으로 이해할 수 있게내용은 풍부하게 넣고,가볍게 들고 다니도록 2권으로 분권 구성했습니다.\n\n이 책의 분권 구성\nVol.1(314쪽)\n_Part 1일주일만에 끝내는<b>파이썬</b> 기초\nVol.2(442쪽)\n_Part 2 <b>파이썬</b>으로 데이터 분석하기\n_Part 3 효율적인 프로그래밍을 위한 중급 <b>파이썬</b>"
#
# },
# {
# "title": "머신러닝&딥러닝 with <b>파이썬</b> (인공지능 핵심 개념과 사용 사례부터,한 권으로 다지는)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21122108",
# "image": "https://bookthumb-phinf.pstatic.net/cover/211/221/21122108.jpg?type=m1&udate=20211207",
# "author": "알베르토 아르타산체스|프라틱 조시",
# "price": "40000",
# "discount": "36000",
# "publisher": "한빛미디어",
# "pubdate": "20211021",
# "isbn": "1162244879 9791162244876",
# "description": "예제는 <b>파이썬</b>과 텐서플로를 사용하며 <b>파이썬</b> 입문자도 쉽게 따라 할 수 있는 코드로 구성되었다. <b>파이썬</b> 프로그래밍 경험이 있다면 코드를 자유롭게 활용해 원하는 프로그램을 만들어볼 수 있다.\n\n영화 추천 시스템 구축, 주식시장 분석, 객체 추적기 구축 등 흥미로운 예제를 따라 차근차근 학습하고 나면 다양한... "
#
# },
# {
# "title": "<b>파이썬</b> 딥러닝 파이토치 (Python Deep Learning PyTorch)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16778336",
# "image": "https://bookthumb-phinf.pstatic.net/cover/167/783/16778336.jpg?type=m1&udate=20210929",
# "author": "이경택|방성수|안상준",
# "price": "25000",
# "discount": "22500",
# "publisher": "정보문화사",
# "pubdate": "20201008",
# "isbn": "8956748578 9788956748573",
# "description": "<b>파이썬</b>은 선택이 아닌 필수! 파이토치로 딥러닝 입문하기!이 책은 딥러닝 기술에 초점을 두고 딥러닝을 구현하기 위해 <b>파이썬</b>을 이용하는데, 머신러닝 라이브러리인 파이토치를 활용하여 다양한 텐서를 지원하는 방법을 알아본다. 파이토치는 <b>파이썬</b> 코딩과 비슷하기 때문에 언어가 어렵지 않다.... "
#
# },
# {
# "title": "<b>파이썬</b> 생활밀착형 프로젝트 (웹크롤링, 카카오톡 메시지 보내기, 업무자동화까지 11가지 <b>파이썬</b>프로젝트, 백견불여일타 이젠 프로젝트다!)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20596927",
# "image": "https://bookthumb-phinf.pstatic.net/cover/205/969/20596927.jpg?type=m1&udate=20210609",
# "author": "김효실",
# "price": "25000",
# "discount": "22500",
# "publisher": "로드북",
# "pubdate": "20210616",
# "isbn": "8997924877 9788997924875",
# "description": "<b>파이썬</b>을 배웠는데 그 다음엔 뭘 할 수 있지? 라는 물음에서부터 기획되었다. 인간의 언어도 사용해봐야 늘 듯이, 프로그래밍 언어도 그렇다. 문법만... 웹 크롤링, 업무 자동화, 인공지능 비서, 주식 분석 자동화 등의 프로젝트를 재미나게 배우면서 <b>파이썬</b> 활용 실력도 높여보자."
#
# },
# {
# "title": "<b>파이썬</b> 인공지능 입문+실전 종합편 (한 권으로 끝내는, <b>파이썬</b>+넘파이+텐서플로우로 인공지능 딥러닝 직접 구현하기)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20937519",
# "image": "https://bookthumb-phinf.pstatic.net/cover/209/375/20937519.jpg?type=m1&udate=20211118",
# "author": "서민우",
# "price": "23000",
# "discount": "20700",
# "publisher": "앤써북",
# "pubdate": "20210925",
# "isbn": "118555386X 9791185553863",
# "description": "〈한 권으로 끝내는 <b>파이썬</b> 인공지능 입문+실전(종합편)〉 책을 통해 <b>파이썬</b>, 넘파이, 텐서플로우를 이용하여 인공지능 일고리즘을 구현해 보면서... ㆍ 1단계 : 인공지능 딥러닝 이해 ㆍ 2단계 : <b>파이썬</b>으로 딥러닝 알고리즘 구현ㆍ 3단계 : 넘파이로 행렬기반 딥러닝 알고리즘 구현 ㆍ 4단계 : 직접 구현으로... "
#
# },
# {
# "title": "엑셀 자동화 with <b>파이썬</b> (복잡하고 지루한 반복 업무를 쉽고 빠르게 해치우는 방법,일 잘하는 직장인을 위한)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16894128",
# "image": "https://bookthumb-phinf.pstatic.net/cover/168/941/16894128.jpg?type=m1&udate=20211002",
# "author": "최은석",
# "price": "30000",
# "discount": "27000",
# "publisher": "위키북스",
# "pubdate": "20201110",
# "isbn": "1158392265 9791158392260",
# "description": "<b>파이썬</b>을 활용해 엑셀 파일과 데이터를 자유자재로 다루자!엑셀은 기능이 풍부하고 사용하기가 쉬워서 오랫동안 사랑받아온 프로그램이지만 대량의... 이 책은 <b>파이썬</b>을 이용해 엑셀 업무를 자동화하는 방법을 다룹니다. 기본적인 <b>파이썬</b> 문법부터 데이터 분석과 엑셀 자동화까지 상세히 설명하고 있어 <b>파이썬</b>을... "
#
# },
# {
# "title": "<b>파이썬</b> 머신러닝 판다스 데이터 분석",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=15028524",
# "image": "https://bookthumb-phinf.pstatic.net/cover/150/285/15028524.jpg?type=m1&udate=20210317",
# "author": "오승환",
# "price": "25000",
# "discount": "22500",
# "publisher": "정보문화사",
# "pubdate": "20190615",
# "isbn": "8956748330 9788956748337",
# "description": "데이터 과학자가 되기 위한 첫걸음!<b>파이썬</b> 초급자나 중급자가 데이터 분석과 머신러닝을 배우고자 마음먹었다면 이 책을 선택해야 한다. 필수... 그 출발 선상에 섰다면 이 책과 함께 예제코드를 하나씩 실행해보면, <b>파이썬</b> 데이터 분석을 즐기고 있는 본인을 발견할 것이다.\n\n학습에 필요한 예제 코드와... "
#
# },
# {
# "title": "<b>파이썬</b> 데이터 클리닝 쿡북 (<b>파이썬</b>과 판다스를 활용한 데이터 전처리)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21289619",
# "image": "https://bookthumb-phinf.pstatic.net/cover/212/896/21289619.jpg?type=m1&udate=20211112",
# "author": "마이클 워커",
# "price": "28000",
# "discount": "25200",
# "publisher": "위키북스",
# "pubdate": "20211119",
# "isbn": "1158392788 9791158392789",
# "description": "《<b>파이썬</b> 데이터 클리닝 쿡북》은 <b>파이썬</b>으로 데이터를 다루고 정제할 때 사용할 수 있는 도구와 기법을 보여준다.먼저 통상적인 데이터 소스로부터... 체이닝으로 <b>파이썬</b> 판다스 작업 생산성을 향상◎ 시각화를 통해 통찰을 얻고 잠재적인 데이터 이슈를 식별◎ 데이터의 변동을 파악하는 능력을 향상◎ 사용자... "
#
# },
# {
# "title": "<b>파이썬</b> 라이브러리를 활용한 데이터 분석 (영화 평점, 이름 통계, 선거 데이터 등 실사례 사용)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14922211",
# "image": "https://bookthumb-phinf.pstatic.net/cover/149/222/14922211.jpg?type=m1&udate=20211207",
# "author": "웨스 맥키니",
# "price": "35000",
# "discount": "31500",
# "publisher": "한빛미디어",
# "pubdate": "20190520",
# "isbn": "116224190X 9791162241905",
# "description": "이 책은 NumPy, pandas, matplotlib, IPython, Jupyter 등 다양한 <b>파이썬</b> 라이브러리를 사용해서 효과적으로 데이터를 분석하는 방법을 알려준다. pandas의 새로운 기능뿐만 아니라 메모리 사용량을 줄이고 성능을 개선하는 고급 사용법까지 다룬다. 또한 모델링 도구인 statsmodels와 scikit-learn... "
#
# },
# {
# "title": "<b>파이썬</b> 머신러닝 실무 테크닉 100",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21347076",
# "image": "https://bookthumb-phinf.pstatic.net/cover/213/470/21347076.jpg?type=m1&udate=20211215",
# "author": "시모야마 데루마사|미키 다카유키|이토 준지",
# "price": "25000",
# "discount": "22500",
# "publisher": "제이펍",
# "pubdate": "20211214",
# "isbn": "1191600432 9791191600438",
# "description": "하지만 실무 현장에서의 기술 활용이나 대처 방법과 같은 노하우는 입문서로 공부하는 것만으로는 결코 익힐 수 없습니다.이 책은 큰 호평을 받았던 《<b>파이썬</b> 데이터 분석 실무 테크닉 100》을 잇는 것으로, 실제 실무 현장을 가정한 100개의 문제를 풀면서 현장의 관점과 응용력을 몸에 익히도록 구성한... "
#
# },
# {
# "title": "그림으로 배우는 <b>파이썬</b>",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21148889",
# "image": "https://bookthumb-phinf.pstatic.net/cover/211/488/21148889.jpg?type=m1&udate=20211028",
# "author": "다카하시 마나",
# "price": "18000",
# "discount": "16200",
# "publisher": "영진닷컴",
# "pubdate": "20211110",
# "isbn": "8931465858 9788931465853",
# "description": "<b>파이썬</b> 기초부터 라이브러리, 기계학습 입문까지 <b>파이썬</b>은 간결해서 배우기 쉽고, 프로그램을 빠르게 개발할 수 있으며, 인공지능 등 다양한 분야에... 이 책은 풍부한 일러스트와 친절한 설명을 통해 기초 문법부터 차근차근 다지고, 많은 예제 프로그램을 통해 초보자도 <b>파이썬</b> 프로그래밍을 확실히 익힐 수... "
#
# },
# {
# "title": "<b>파이썬</b>으로 살펴보는 아키텍처 패턴 (TDD, DDD, EDM 적용하기)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20554246",
# "image": "https://bookthumb-phinf.pstatic.net/cover/205/542/20554246.jpg?type=m1&udate=20211207",
# "author": "해리 퍼시벌|밥 그레고리",
# "price": "32000",
# "discount": "28800",
# "publisher": "한빛미디어",
# "pubdate": "20210603",
# "isbn": "1162244313 9791162244319",
# "description": "아키텍처 패턴의 기초부터 활용까지 다루는 실전 가이드\n\n<b>파이썬</b>을 활용한 프로젝트의 규모가 커지면서 육각형/클린 아키텍처, 이벤트 기반 아키텍처... 낮추고, 테스트 스위트에서 최선의 가치를 얻는 방법을 알려준다. 또한 자바나 C#보다 간단하고 우아한 <b>파이썬</b> 코드의 장점을 잘 살려 각 패턴을 설명한다."
#
# },
# {
# "title": "<b>파이썬</b>과 케라스를 이용한 딥러닝/강화학습 주식투자 (퀀트 투자 알고리즘 트레이딩을 위한 최첨단 해법 입문)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16330711",
# "image": "https://bookthumb-phinf.pstatic.net/cover/163/307/16330711.jpg?type=m1&udate=20200418",
# "author": "퀀티랩",
# "price": "28000",
# "discount": "25200",
# "publisher": "위키북스",
# "pubdate": "20200427",
# "isbn": "1158392036 9791158392031",
# "description": "실제 주식 데이터를 이용해 <b>파이썬</b>으로 강화학습 주식투자 프로그램을 직접 구현해 봅니다!강화학습은 스스로 학습하는 머신러닝 기법으로 주식 데이터 학습에 잘 적용되는 기법입니다. 이 책은 <b>파이썬</b>을 이용한 강화학습 기반의 주식투자 시뮬레이션 프로그램 개발에 대해 설명합니다. 이를 위한 이론과 코드... "
#
# },
# {
# "title": "<b>파이썬</b> 코딩 도장",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14144026",
# "image": "https://bookthumb-phinf.pstatic.net/cover/141/440/14144026.jpg?type=m1&udate=20191011",
# "author": "남재윤",
# "price": "25000",
# "discount": "22500",
# "publisher": "길벗",
# "pubdate": "20181130",
# "isbn": "1160506183 9791160506181",
# "description": "외우기만 해서는 <b>파이썬</b>도 어렵다!\n프로그래밍은 연습으로 배우는 것!\n문법을 외우기만 해서는 <b>파이썬</b>도 배우기 어렵다. 프로그래밍은 개념을 습득하고... 최고의 학습은 반복이고, 스스로 생각하기다\n<b>파이썬</b> 문법을 학습한 다음에는 반드시 퀴즈를 풀어보게 했다. 퀴즈를 풀어본 다음에는 반드시 연습문제로... "
#
# },
# {
# "title": "모두의 <b>파이썬</b> (20일 만에 배우는 프로그래밍 기초)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=10541921",
# "image": "https://bookthumb-phinf.pstatic.net/cover/105/419/10541921.jpg?type=m1&udate=20181102",
# "author": "이승찬",
# "price": "12000",
# "discount": "",
# "publisher": "길벗",
# "pubdate": "20160509",
# "isbn": "1186978899 9791186978894",
# "description": "<b>파이썬</b>이 무엇인지 몰라도 상관 없다. 《모두의 <b>파이썬</b>》은 어려운 개념과 복잡한 이론 설명은 최대한 줄이고, 초보자가 프로그래밍을 쉽게 배울 수... 어느새 <b>파이썬</b> 프로그램으로 멋진 그림을 그리고, 계산을 하고, 간단한 게임을 만들고, 수학 문제를 푸는 자신을 발견하게 될 것이다. 《모두의 <b>파이썬</b>》으로... "
#
# },
# {
# "title": "특강마스터 <b>파이썬</b> 마스터 3급",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21348572",
# "image": "https://bookthumb-phinf.pstatic.net/cover/213/485/21348572.jpg?type=m1&udate=20211214",
# "author": "김상민",
# "price": "18000",
# "discount": "16200",
# "publisher": "렉스미디어닷넷",
# "pubdate": "20211201",
# "isbn": "8959604143 9788959604142",
# "description": "[구성 및 특징]ㆍ <b>파이썬</b> 프로그램의 출제 기능을 쉽게 설명ㆍ <b>파이썬</b> 3급 출제 기준을 분석하여 예상 문제 제공ㆍ CBT 모의시험 방법 안내, 모의고사 8회 / 정답 및 해설 제공"
#
# },
# {
# "title": "이것이 데이터 분석이다 with <b>파이썬</b> (<b>파이썬</b>으로 배우는 데이터 분석 입문)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16237901",
# "image": "https://bookthumb-phinf.pstatic.net/cover/162/379/16237901.jpg?type=m1&udate=20210211",
# "author": "윤기태",
# "price": "28000",
# "discount": "25200",
# "publisher": "한빛미디어",
# "pubdate": "20200210",
# "isbn": "1162242515 9791162242513",
# "description": "실생활 예제로 쉽게, 단계별 분석에 따라 구조적으로 배우는 데이터 분석 입문서데이터를 다루는 데 언어나 라이브러리는 도구일 뿐입니다. 진짜 중요한 것은 문제해결 능력입니다. 이 책은 주어진 문제를 어떻게 단계적으로 접근하면 좋을지에 대해 독자 친화적으로 가이드를 주는 책입니다. 프로그래밍 기초... "
#
# },
# {
# "title": "AWS로 시작하는 AI 서비스 with <b>파이썬</b>",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21159306",
# "image": "https://bookthumb-phinf.pstatic.net/cover/211/593/21159306.jpg?type=m1&udate=20211029",
# "author": "이노우에 켄이치",
# "price": "22000",
# "discount": "19800",
# "publisher": "영진닷컴",
# "pubdate": "20211105",
# "isbn": "8931465823 9788931465822",
# "description": "AWS에서 제공하는 AI 서비스를 따라 하며 실제 실무에 적용한다!AWS의 모체인 AMAZON은 세계 제일의 쇼핑 사이트이다. AMAZON 내부에서 다양한 AI가 사용되고 있다는 것은 쉽게 상상할 수 있다. AWS의 AI 서비스는 무척 다양하여 전체를 파악하는 것조차도 상당히 어려울 정도이다. AWS에서는... "
#
# },
# {
# "title": "데이터 과학 기반의 <b>파이썬</b> 빅데이터 분석 (IT@COOKBOOK)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17762418",
# "image": "https://bookthumb-phinf.pstatic.net/cover/177/624/17762418.jpg?type=m1&udate=20210930",
# "author": "이지영",
# "price": "28000",
# "discount": "27440",
# "publisher": "한빛아카데미",
# "pubdate": "20201230",
# "isbn": "1156645077 9791156645078",
# "description": "핵심 <b>파이썬</b> 문법을 배울 수 있습니다.\n4차 산업혁명, 데이터 과학, 빅데이터의 관계를 이해하고 빅데이터 분석에 적용할 데이터 과학 방법론을 배웁니다. 빅데이터 분석에 필요한 핵심 <b>파이썬</b> 문법을 살펴보고 빅데이터 수집 방법으로 유용한 <b>파이썬</b> 크롤링 방법도 실습과 함께 살펴봅니다.\n\n■ 기본 분석부터... "
#
# },
# {
# "title": "<b>파이썬</b>과 데이터 과학 (따라하며 배우는)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17718057",
# "image": "https://bookthumb-phinf.pstatic.net/cover/177/180/17718057.jpg?type=m1&udate=20210509",
# "author": "천인국|박동규|강영민",
# "price": "26000",
# "discount": "25480",
# "publisher": "생능출판",
# "pubdate": "20201228",
# "isbn": "897050477X 9788970504773",
# "description": "최근 가장 빠르게 인기를 얻고 있는 프로그래밍 언어는 바로 <b>파이썬</b>이다. 그 속도는 놀라울 정도로 빠르며, 새롭게 프로그래밍 언어를 배우는 이들이 가장 많이 시작하는 언어로 자리 잡았다. 다른 언어를 주로 사용하던 프로그래머들도 <b>파이썬</b>을 접하고 나서는 자신이 사용하는 프로그래밍 언어 목록에서 <b>파이썬</b>... "
#
# },
# {
# "title": "<b>파이썬</b> 라이브러리를 활용한 머신러닝 (번역개정판,사이킷런 핵심 개발자가 쓴 머신러닝과 데이터 과학 실무서)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14645299",
# "image": "https://bookthumb-phinf.pstatic.net/cover/146/452/14645299.jpg?type=m1&udate=20211207",
# "author": "안드레아스 뮐러|세라 가이도",
# "price": "32000",
# "discount": "28800",
# "publisher": "한빛미디어",
# "pubdate": "20190329",
# "isbn": "1162241640 9791162241646",
# "description": "사이킷런 핵심 개발자에게 배우는 머신러닝 이론과 구현 \n\n현업에서 머신러닝을 연구하고 인공지능 서비스를 개발하기 위해 꼭 학위를 받을 필요는 없습니다. 사이킷런(scikit-learn)과 같은 훌륭한 머신러닝 라이브러리가 복잡하고 난해한 작업을 직관적인 인터페이스로 감싸주는 덕분이죠. 이 책에서는... "
#
# },
# {
# "title": "<b>파이썬</b> GUI 프로그래밍 쿡북 (Tkinter, PyQt5를 활용한 반응형 사용자 인터페이스 개발)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20906006",
# "image": "https://bookthumb-phinf.pstatic.net/cover/209/060/20906006.jpg?type=m1&udate=20211007",
# "author": "부르크하르트 메이어",
# "price": "35000",
# "discount": "31500",
# "publisher": "에이콘출판",
# "pubdate": "20210930",
# "isbn": "1161755713 9791161755717",
# "description": "<b>파이썬</b> 3를 사용해 GUI 프로그래밍 방법을 단계별로 설명한다. 2판의 레시피를 개선해 해당 라이브러리가 왜 필요하고, 어떻게 사용하는지 다양한 분야의 새로운 개념을 쉽게 이해할 수 있도록 설명한다. GUI 관련 기술뿐만 아니라 네트워크, 데이터베이스, 객체지향적 사고에 이르기까지 단계별로 배울 수... "
#
# },
# {
# "title": "고성능 <b>파이썬</b> (<b>파이썬</b> 성능 잠재력을 끌어내는 실용적인 개발 전략서)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=18992661",
# "image": "https://bookthumb-phinf.pstatic.net/cover/189/926/18992661.jpg?type=m1&udate=20211207",
# "author": "미샤 고렐릭|이안 오스발트",
# "price": "36000",
# "discount": "32400",
# "publisher": "한빛미디어",
# "pubdate": "20210510",
# "isbn": "1162244216 9791162244210",
# "description": "<b>파이썬</b>의 성능을 제대로 올려주는 코드 작성법\n\n<b>파이썬</b> 코드가 제대로 동작하더라도 더 빠르게 실행되도록 해야 할 때가 있다. 이 책은 <b>파이썬</b> 3에 맞춰 내용을 보강한 개정판으로, 처리할 데이터 용량이 큰 프로그램의 병목현상을 찾고, 이를 해결해 성능을 향상하는 방법을 알려준다. 프로그램 설계 시 여러 선택... "
#
# },
# {
# "title": "<b>파이썬</b> 딥러닝 머신러닝 입문",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17597510",
# "image": "https://bookthumb-phinf.pstatic.net/cover/175/975/17597510.jpg?type=m1&udate=20210509",
# "author": "오승환",
# "price": "25000",
# "discount": "22500",
# "publisher": "정보문화사",
# "pubdate": "20210105",
# "isbn": "8956749000 9788956749006",
# "description": "아직도 <b>파이썬</b>을 모른다고?&#x0D;&#x0D;이 책은 코드를 직접 입력하고 실행하는 데 필요한 기본적인 환경을 ‘구글 코랩’을 활용하여 <b>파이썬</b>의 가장 기본적인 문법 중 핵심적인 내용만 간단하게 설명한다. 머신러닝과 딥러닝을 직접 경험해보고 싶지만 <b>파이썬</b> 초보자라면 이 책이 적합할 것이다. 데이터를... "
#
# },
# {
# "title": "<b>파이썬</b>을 이용한 데이터 분석의 정석 (넘파이, 판다스, 맷플롯립과 실전 예제로 배우는)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20666311",
# "image": "https://bookthumb-phinf.pstatic.net/cover/206/663/20666311.jpg?type=m1&udate=20210628",
# "author": "채진석",
# "price": "32000",
# "discount": "28800",
# "publisher": "루비페이퍼",
# "pubdate": "20210625",
# "isbn": "1186710705 9791186710708",
# "description": "<b>파이썬</b> 데이터 분석에 필수로 사용되는 라이브러리를 단계적으로 다루어 데이터를 전처리하고 분석하는 능력을 갖춘다. 이 과정에서 넘파이, 판다스, 맷플롯립은 물론 연관 라이브러리까지 상세히 소개한다. 그리고 소개한 라이브러리를 종합하여 활용할 수 있는 세 가지 실전 예제를 담았다."
#
# },
# {
# "title": "<b>파이썬</b> 데이터 분석 실무 테크닉 100 (100가지 예제로 배우는 데이터 가공, 머신러닝, 이미지/자연어 처리의 기술)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16427881",
# "image": "https://bookthumb-phinf.pstatic.net/cover/164/278/16427881.jpg?type=m1&udate=20210509",
# "author": "시모야마 테루마사|마쯔다 유마|미키 타카유키",
# "price": "26000",
# "discount": "23400",
# "publisher": "위키북스",
# "pubdate": "20200730",
# "isbn": "1158392176 9791158392178",
# "description": "《<b>파이썬</b> 데이터 분석 실무 테크닉 100》은 실제 비즈니스 현장에서 마주칠 수 있는 100개의 예제를 풀면서 현장 분위기를 몸에 익히고 현장에 맞게 기술을 응용하는 힘을 기를 수 있게 설계한 문제집입니다.\n\n이 책에 실린 100개의 테크닉을 익힌다고 해서 바로 현장에 적용할 수 있는 것은 아니지만, 현장 감각을... "
#
# },
# {
# "title": "<b>파이썬</b>으로 배우는 게임 개발 (입문편, 미로, 진단 애플리케이션, RPG 등을, 블록 낙하 퍼즐,퀴즈, 주사위)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16851586",
# "image": "https://bookthumb-phinf.pstatic.net/cover/168/515/16851586.jpg?type=m1&udate=20211218",
# "author": "히로세 츠요시",
# "price": "28000",
# "discount": "25200",
# "publisher": "제이펍",
# "pubdate": "20201026",
# "isbn": "1190665441 9791190665445",
# "description": "인기 장르의 게임을 만들며 배우는 <b>파이썬</b> 활용법!\n25년차 현직 게임 프로그래머가 알려 주는 게임 개발 노하우!\n\n<b>파이썬</b>은 초보자도 직관적으로 이해하기... 입문편에서는 <b>파이썬</b>의 기초 규칙을 먼저 안내하고 미로 게임, 블록 낙하 퍼즐, RPG 등의 다양한 게임을 만드는 과정을 설명합니다."
#
# },
# {
# "title": "<b>파이썬</b>으로 배우는 포트폴리오 (금융공학/퀀트 투자의 기초부터 투자 모델, 머신 러닝까지!)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=18121206",
# "image": "https://bookthumb-phinf.pstatic.net/cover/181/212/18121206.jpg?type=m1&udate=20210327",
# "author": "곽승주",
# "price": "26000",
# "discount": "23400",
# "publisher": "길벗",
# "pubdate": "20210315",
# "isbn": "1165214865 9791165214869",
# "description": "포트폴리오, 재무 기초, <b>파이썬</b> 프로그래밍 기술까지\n실제 재무 데이터로 구현하는 이론과 실전의 최적 조합!이 책은 주식 투자에서 위험을 줄이고... 재무 기초, 포트폴리오 이론, 투자 모델을 수학과 그림, <b>파이썬</b> 코드를 사용해 명확히 이해시키고자 했다. <b>파이썬</b>의 기초는 물론 NUMPY, MATPLOTLIB, PANDAS의... "
#
# },
# {
# "title": "C#과 <b>파이썬</b>을 활용한 OpenCV 4 프로그래밍 (컴퓨터 비전 기초 이론부터 머신러닝을 활용한 영상 처리 프로젝트까지)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=18872549",
# "image": "https://bookthumb-phinf.pstatic.net/cover/188/725/18872549.jpg?type=m1&udate=20211207",
# "author": "윤대희",
# "price": "36000",
# "discount": "32400",
# "publisher": "위키북스",
# "pubdate": "20210415",
# "isbn": "1158392559 9791158392550",
# "description": "또한 C#과 <b>파이썬</b>이라는 두 가지 프로그래밍 언어로 구성돼 있어 C#이나 <b>파이썬</b> 개발자분들이 손쉽게 OpenCV를 배울 수 있는 영상처리 입문서입니다.\n\n이 책에서는 OpenCV를 폭넓게 활용할 수 있도록 머신러닝/딥러닝 모듈을 비롯해 Tesseract-OCR과 텐서플로(TensorFlow) 등을 활용해 영상 처리... "
#
# },
# {
# "title": "<b>파이썬</b> 해킹 레시피 (웹 크롤링 및 취약점 진단 도구를 구현해보는 정보 보안 실습)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20579892",
# "image": "https://bookthumb-phinf.pstatic.net/cover/205/798/20579892.jpg?type=m1&udate=20211208",
# "author": "공재웅",
# "price": "26000",
# "discount": "23400",
# "publisher": "비제이퍼블릭",
# "pubdate": "20210604",
# "isbn": "1165920727 9791165920722",
# "description": "이 책에서만 볼 수 있는 <b>파이썬</b> 요리 비법 대공개\n해킹 도구를 <b>파이썬</b>으로 직접 만들며 공부해보자\n\n<b>파이썬</b>은 서버, 머신러닝, 자동화 분야에 이미 광범위하게 이용되고 있어 하나의 언어로 여러 분야에 적용 가능하다. 또한 개발 입문자부터 데이터 분석가, 기업 실무자에 이르기까지 그 수요가 많다.\n이... "
#
# },
# {
# "title": "<b>파이썬</b> Express (파워 유저를 위한)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17526679",
# "image": "https://bookthumb-phinf.pstatic.net/cover/175/266/17526679.jpg?type=m1&udate=20210320",
# "author": "천인국",
# "price": "30000",
# "discount": "29400",
# "publisher": "생능출판",
# "pubdate": "20201120",
# "isbn": "8970504664 9788970504667",
# "description": "<b>파이썬</b>은 현재 가장 각광받는 언어라고 감히 말할 수 있다. 최근에 인공지능이나 데이터 과학, 영상 처리 분야는 <b>파이썬</b>으로 프로그램을 작성하는 것이 거의 표준으로 되어 있다. 해가 갈수록 <b>파이썬</b> 활용이 폭발적으로 늘어나고 있다.&#x0D;&#x0D;필자가 보기에 <b>파이썬</b>은 두 얼굴을 가진 언어인 거 같다. 쉽게... "
#
# },
# {
# "title": "<b>파이썬</b>으로 만드는 인공지능",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17848721",
# "image": "https://bookthumb-phinf.pstatic.net/cover/178/487/17848721.jpg?type=m1&udate=20211207",
# "author": "오일석|이진석",
# "price": "31000",
# "discount": "30380",
# "publisher": "한빛아카데미",
# "pubdate": "20210105",
# "isbn": "1156645085 9791156645085",
# "description": "이론과 실습으로 배우는 인공지능과 딥러닝\n\n인공지능 이론을 79개의 <b>파이썬</b> 프로그램으로 실습하며 배우는 책입니다. 컨볼루션 신경망, 순환 신경망, 강화 학습 등의 인공지능 핵심 이론을 다양한 예시와 수식, 그래프를 통해 학습할 수 있습니다. 또한 로봇 기자, 집 지킴이, 비트코인 가격 예측, 동요 편곡, 패션... "
#
# },
# {
# "title": "<b>파이썬</b>으로 하는 데브옵스 (자동화, 클라우드, 머신러닝, 데이터 엔지니어링까지)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20626882",
# "image": "https://bookthumb-phinf.pstatic.net/cover/206/268/20626882.jpg?type=m1&udate=20210813",
# "author": "노아 기프트|케네디 베어먼|알프레도 데자|그릭 게오르규",
# "price": "40000",
# "discount": "36000",
# "publisher": "에이콘출판",
# "pubdate": "20210630",
# "isbn": "1161755381 9791161755380",
# "description": "<b>파이썬</b>을 통해 데브옵스를 가장 효율적으로 실천할 수 있는 방법을 구체적인 사례와 함께 설명한다. 특히 CI/CD, 모니터링, 테스트 자동화 등 데브옵스 전문가에게 필요한 다양한 업무와 더 나아가 클라우드와 머신러닝에 이르기까지 <b>파이썬</b>을 활용해 얼마나 다양하고 가치 있는 일을 할 수 있는지 배울 수 있다."
#
# },
# {
# "title": "직장인을 위한 데이터 분석 실무 with <b>파이썬</b> (마케팅, 영업, 기획 실무 담당자를 위한 데이터 분석의 기술)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17134126",
# "image": "https://bookthumb-phinf.pstatic.net/cover/171/341/17134126.jpg?type=m1&udate=20201106",
# "author": "이형석|장남수|전상환|정상욱",
# "price": "28000",
# "discount": "25200",
# "publisher": "위키북스",
# "pubdate": "20201112",
# "isbn": "1158392281 9791158392284",
# "description": "이 책은 <b>파이썬</b>을 처음 접하는 마케팅, 영업, 기획 실무 담당자들이 <b>파이썬</b>을 활용한 데이터 분석에 재미있게 빠져들 수 있도록 실제 업무에 활용할 수 있거나 흥미로운 예제로 구성돼 있습니다. 이 책을 마치고 나면 데이터를 기반으로 좋은 질문에 답할 수 있는 실력을 키울 수 있을 것입니다.\n\n★ 이 책에서... "
#
# },
# {
# "title": "<b>파이썬</b> 딥러닝 텐서플로",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20740822",
# "image": "https://bookthumb-phinf.pstatic.net/cover/207/408/20740822.jpg?type=m1&udate=20210708",
# "author": "오승환|이경록|김태헌|홍재권",
# "price": "27000",
# "discount": "24300",
# "publisher": "정보문화사",
# "pubdate": "20210630",
# "isbn": "8956749094 9788956749099",
# "description": "파트1에서는 <b>파이썬</b> 코드를 직접 실행할 수 있는 개발 환경을 설정하는 방법을 소개한다. 파트2에서는 텐서플로의 특징과 텐서플로에서 데이터를 처리하는 기본 자료형인 텐서에 대해 설명한다. 파트3에서는 딥러닝 프레임워크 중에서도 텐서플로 케라스에 대해 설명한다. 또한 인공신경망 구조를 정의하고... "
#
# },
# {
# "title": "400제로 배우는 <b>파이썬</b> 입문 (취업 성공을 위한 속성 프로세스 + 400제 plus)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21154037",
# "image": "https://bookthumb-phinf.pstatic.net/cover/211/540/21154037.jpg?type=m1&udate=20211207",
# "author": "김범준",
# "price": "28000",
# "discount": "25200",
# "publisher": "심통",
# "pubdate": "20211029",
# "isbn": "1197529527 9791197529528",
# "description": "400제 plus로 <b>파이썬</b> 활용 능력 키우기!  \n\n핵심 문법을 배우고 400여 개의 예제를 하나하나 만들어 가다 보면 <b>파이썬</b>을 마음대로 활용할 수 있도록 구성하였습니다!\n\n1 챕터 시작 전, 맛보기 예제로 워밍업\n맛보기 예제를 일단 따라하다 보면 이 챕터에서 배울 핵심 내용을 미리 익힐 수 있습니다.\n\n2 상세한 소스... "
#
# },
# {
# "title": "처음 시작하는 <b>파이썬</b> (<b>파이썬</b> 패키지를 활용한 모던 컴퓨팅 입문)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16588295",
# "image": "https://bookthumb-phinf.pstatic.net/cover/165/882/16588295.jpg?type=m1&udate=20201012",
# "author": "빌 루바노빅",
# "price": "36000",
# "discount": "32400",
# "publisher": "한빛미디어",
# "pubdate": "20200824",
# "isbn": "1162243333 9791162243336",
# "description": "전 세계 1등 언어 <b>파이썬</b>을 <b>파이썬</b>답게 쓰게 해주는 최고의 안내서이 책은 프로그래밍을 막 시작하는 입문자나, 이미 다른 프로그래밍 언어를 학습한 개발자가 <b>파이썬</b>을 쉽고 빠르게 배울 수 있게 안내한다. 1판과 다르게 2판은 1부와 2부로 나뉘었다. 1부에서는 테스팅, 디버깅, 코드 재사용 방법, 기타... "
#
# },
# {
# "title": "머신 러닝·딥 러닝에 필요한 기초 수학 with <b>파이썬</b>",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16890922",
# "image": "https://bookthumb-phinf.pstatic.net/cover/168/909/16890922.jpg?type=m1&udate=20211207",
# "author": "조준우",
# "price": "27000",
# "discount": "24300",
# "publisher": "인사이트",
# "pubdate": "20201104",
# "isbn": "8966262856 9788966262854",
# "description": "<b>파이썬</b> 등 프로그래밍 도구를 이용하여 배운 수학 개념을 눈으로 확인해 볼 수 있게 하였습니다.\n수학과 실제 작업을 단단하게 연결하는 경험을 통해서 앞으로 새로운 알고리즘을 공부할 때도 스스로 학습할 수 있는 능력을 기를 수 있도록 하였습니다."
#
# },
# {
# "title": "누구나 <b>파이썬</b> 통계분석",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16328841",
# "image": "https://bookthumb-phinf.pstatic.net/cover/163/288/16328841.jpg?type=m1&udate=20201024",
# "author": "타니아이 히로키",
# "price": "26000",
# "discount": "23400",
# "publisher": "한빛아카데미",
# "pubdate": "20200406",
# "isbn": "1156644887 9791156644880",
# "description": "<b>파이썬</b>을 활용하면 복잡한 수식이 없이도 통계분석을 할 수 있습니다!\n책을 따라 실습하다 보면 어느새 통계분석을 하는 자신을 발견하게 됩니다.\n\n이런 분들이 보면 더 좋습니다.\n■ <b>파이썬</b>을 사용해 통계분석을 공부하고 싶다.\n■ <b>파이썬</b>의 기초는 배웠지만, 이어서 공부할 내용을 찾지 못했다.\n■ 통계분석에... "
#
# },
# {
# "title": "두근두근 <b>파이썬</b> (쉽고! 재밌고! 흥미로운 코딩 맛!)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=11573148",
# "image": "https://bookthumb-phinf.pstatic.net/cover/115/731/11573148.jpg?type=m1&udate=20210129",
# "author": "천인국",
# "price": "24000",
# "discount": "22800",
# "publisher": "생능출판",
# "pubdate": "20170116",
# "isbn": "8970508937 9788970508931",
# "description": "『두근두근 <b>파이썬</b>』은 프로그래밍을 처음 시작하는 학습자도 쉽게 따라올 수 있도록 변수, 조건문, 반복문, 함수 등의 기본적인 프로그래밍 개념을 자세히 설명하여 탄탄한 기초를 만들 수 있다. 또한, 적절한 그림을 가능한 많이 사용하여 더욱 친숙하고, 지루하지 않으며 독자들이 이해하기 쉬우며... "
#
# },
# {
# "title": "시간순삭 <b>파이썬</b>",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16625087",
# "image": "https://bookthumb-phinf.pstatic.net/cover/166/250/16625087.jpg?type=m1&udate=20210509",
# "author": "천인국|정영민|최자영",
# "price": "22000",
# "discount": "19800",
# "publisher": "생능출판",
# "pubdate": "20200827",
# "isbn": "8970504656 9788970504650",
# "description": "다루는 친근한 소재를 융합적으로 다루어 실습 예제인 LAB으로 제공하고 있다. 이 책을 읽게 된다면 <b>파이썬</b>이 얼마나 재미있는 프로그래밍 언어인지 알게 될 것이다! 또한 코딩 플랫폼 ‘엘리스 아카데미(HTTPS://ACADEMY.ELICE..IO/COURSES/5056/INFO)’를 통해 책에 있는 모든 예제를 직접 실습해볼 수 있습니다."
#
# },
# {
# "title": "엑셀과 비교하며 배우는 <b>파이썬</b> 데이터 분석",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20596443",
# "image": "https://bookthumb-phinf.pstatic.net/cover/205/964/20596443.jpg?type=m1&udate=20210608",
# "author": "장쥔홍",
# "price": "24000",
# "discount": "21600",
# "publisher": "제이펍",
# "pubdate": "20210617",
# "isbn": "1191600114 9791191600117",
# "description": "어떠한 데이터이든지 처리하고 정리하여 일목요연하게 파악하기 쉽도록 만들어주는 최고의 툴인 엑셀과 <b>파이썬</b>을, 둘 중 어느 것도 놓치지 않고 두 도구의 장점만을 취해 데이터 처리와 분석을 효과적으로 쉽게 해낼 수 있도록 해줍니다. 이 책과 함께라면 데이터를 다루는 그 어떤 업무에서도 빠르고 효율적으로... "
#
# },
# {
# "title": "<b>파이썬</b>을 이용한 알고리즘 트레이딩 (아이디어 도출부터 클라우드 배포까지)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20764338",
# "image": "https://bookthumb-phinf.pstatic.net/cover/207/643/20764338.jpg?type=m1&udate=20210819",
# "author": "이브스 힐피쉬",
# "price": "29000",
# "discount": "26100",
# "publisher": "제이펍",
# "pubdate": "20210729",
# "isbn": "1191600106 9791191600100",
# "description": "'<b>파이썬</b>을 이용한 알고리즘 트레이딩'이라는 주제와 관련해서 말하자면, 이 정도로 넓고 깊게 다루는... <b>파이썬</b>과 이와 관련된 강력한 패키지 생태계는 오늘날 수많은 트레이더가 선택하는 필수 도구가... 분야에서 <b>파이썬</b>을 활용하는 방법을 보여줍니다.또한, 이 책은 자동화한 알고리즘 트레이딩 전략을... "
#
# },
# {
# "title": "<b>파이썬</b> 2학년 스크래핑의 구조 (체험으로 배우고! 대화 형식으로 공부!,Python)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21259836",
# "image": "https://bookthumb-phinf.pstatic.net/cover/212/598/21259836.jpg?type=m1&udate=20211111",
# "author": "모리 요시나오",
# "price": "17000",
# "discount": "15300",
# "publisher": "성안당",
# "pubdate": "20211117",
# "isbn": "8931556896 9788931556896",
# "description": "데이터 수집이나 해석, 분석에 대해 알기 쉽게 설명!<b>파이썬</b>은 인공지능의 기초 언어로 배우기 쉬우면서 각종 데이터 분석에 사용되는 프로그래밍 언어로 절정의 인기를 누리고 있다. 기존이 <b>파이썬</b>... 하는데, <b>파이썬</b>은 인터넷에 액세스할 수 있는 라이브러리가 풍부해 이 두가지 모두 쉽고 편하게 할 수... "
#
# },
# {
# "title": "전문가를 위한 <b>파이썬</b> (간단하고, 명료하고, 효율적인 <b>파이썬</b> 프로그래밍,<b>파이썬</b>3 버전 기준)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=10910543",
# "image": "https://bookthumb-phinf.pstatic.net/cover/109/105/10910543.jpg?type=m1&udate=20211210",
# "author": "루시아누 하말류",
# "price": "55000",
# "discount": "49500",
# "publisher": "한빛미디어",
# "pubdate": "20160812",
# "isbn": "8968484988 9788968484988",
# "description": "<b>파이썬</b> 기능을 활용하여, 효율적인 <b>파이썬</b> 코드 작성 방법을 제시하는 실용 안내서『전문가를 위한 <b>파이썬</b>』. 이 책은 특히 다른 언어에서는 찾아볼 수 없는 <b>파이썬</b> 고유의 기능을 중점적으로 살펴본다. <b>파이썬</b>의 핵심 요소 및 주요 기본 라이브러리도 기본에 충실하게 소개한다."
#
# },
# {
# "title": "똑똑한 <b>파이썬</b> (주니어를 위한 최적의 코딩 학습서)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20567964",
# "image": "https://bookthumb-phinf.pstatic.net/cover/205/679/20567964.jpg?type=m1&udate=20210602",
# "author": "황재호|황예린",
# "price": "18000",
# "discount": "16200",
# "publisher": "인포앤북",
# "pubdate": "20210601",
# "isbn": "1196440980 9791196440985",
# "description": "이 책은 2019년 출간된 『똑똑한 <b>파이썬</b>』의 개정판으로 <b>파이썬</b>이 처음인 초중학생을 대상으로 문제 풀이 위주로 <b>파이썬</b>을 재미있게 공부할 수 있도록 고안되었습니다. 이번 개정판에서는 기존의 책이 가지고 있던 장점인 아이들에게 친근한 일러스트 편집, 쉬운 예제 중심의 학습 등은 그대로 유지하고... "
#
# },
# {
# "title": "<b>파이썬</b>으로 완성하는 비지도 학습 알고리즘 (비감독 모형과 텐서플로 2를 이용한 전처리 기법의 머신러닝 구현)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21376355",
# "image": "https://bookthumb-phinf.pstatic.net/cover/213/763/21376355.jpg?type=m1&udate=20211222",
# "author": "송동근",
# "price": "34000",
# "discount": "30600",
# "publisher": "비제이퍼블릭",
# "pubdate": "20211130",
# "isbn": "1165921103 9791165921101",
# "description": "다양한 비지도 학습 문제들을이제 실제 <b>파이썬</b> 코드로 구현한다!실제 이론을 코드로 구현하는 데에는... 나누고 <b>파이썬</b> 코드로 단계별 결과들을 최대한 상세하게 다루었다.또한 텐서플로 2의 오토 인코더와... 이 책이 필요한 독자- <b>파이썬</b>을 데이터 분석에 활용하고자 하는 분- 비지도 학습에 대해 더 자세히... "
#
# },
# {
# "title": "<b>파이썬</b> for Beginner (쉽고 빠르게 익히는 프로그래밍의 기본 원리)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=15871779",
# "image": "https://bookthumb-phinf.pstatic.net/cover/158/717/15871779.jpg?type=m1&udate=20210902",
# "author": "우재남",
# "price": "23000",
# "discount": "22540",
# "publisher": "한빛아카데미",
# "pubdate": "20200106",
# "isbn": "1156644666 9791156644668",
# "description": "다양한 예제와 프로젝트를 활용해 초보자도 쉽게 프로그래밍의 기본을 익힐 수 있는 <b>파이썬</b> 입문서. 문법을 사전식으로 나열하지 않고 작지만 기능적인 프로그램을 하나씩 완성하면서 익힐 수 있게 구성했다. 단계별로 완성하는 프로젝트를 바탕으로 자신만의 그럴듯한 프로그램도 완성할 수 있다.\n\nIT... "
#
# },
# {
# "title": "<b>파이썬</b>으로 배우는 알고리즘 트레이딩 (내 손으로 만드는 자동 주식 거래 시스템)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14623546",
# "image": "https://bookthumb-phinf.pstatic.net/cover/146/235/14623546.jpg?type=m1&udate=20211206",
# "author": "조대표",
# "price": "40000",
# "discount": "36000",
# "publisher": "위키북스",
# "pubdate": "20190307",
# "isbn": "1158391463 9791158391461",
# "description": "이 책은 <b>파이썬</b>이라는 프로그래밍 언어를 이용한 알고리즘 트레이딩을 다룹니다. 프로그래밍을 전혀 모르는 비전공자나 HTS(Home Trading System)로 주식 투자 정도만 할 수 있는 일반인도 빠르게 <b>파이썬</b>과 알고리즘 트레이딩을 배울 수 있는 알고리즘 트레이딩 입문서입니다.\n\n<b>파이썬</b> 기초 문법에 대한... "
#
# },
# {
# "title": "<b>파이썬</b>과 리액트를 활용한 주식 자동 거래 시스템 구축 (데이터 수집부터 거래 자동화, API 서버, 웹 개발, 데이터 분석까지 아우르는)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16241301",
# "image": "https://bookthumb-phinf.pstatic.net/cover/162/413/16241301.jpg?type=m1&udate=20210509",
# "author": "박재현",
# "price": "28000",
# "discount": "25200",
# "publisher": "위키북스",
# "pubdate": "20200212",
# "isbn": "1158391889 9791158391881",
# "description": "<b>파이썬</b>을 이용해 데이터를 수집, 저장, 가공, 분석하는 방법부터 리액트를 이용해 사용자의 화면까지 개발하는 방법까지 한 권에 담았다. 이 책을... ★ 이 책에서 다루는 내용 ★\n◎ 증권사(이베스트)에서 제공하는 API를 이용해 <b>파이썬</b>으로 거래 자동화 시스템을 개발한다.\n◎ 외부로 기능을 제공하기 위한... "
#
# },
# {
# "title": "IT 비전공자를 위한 돈 버는 <b>파이썬</b> 코딩 (N잡러 자동부업 수익창출)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20938214",
# "image": "https://bookthumb-phinf.pstatic.net/cover/209/382/20938214.jpg?type=m1&udate=20211025",
# "author": "비현코",
# "price": "18000",
# "discount": "16200",
# "publisher": "디지털북스",
# "pubdate": "20211010",
# "isbn": "8960883808 9788960883802",
# "description": "그러나 수학과 담을 쌓은 문과, 인문, 비전공자라면 나와는 상관 없는, 남의 나라 남의 이야기처럼 들릴 것이다.본 도서는 코딩으로 <b>파이썬</b>을 배운다는... 싶은데, 회사는 다녀야겠고, 내가 잠자는 동안에도 내가 일하는 동안에도, 나 대신 ‘코딩’으로 무엇인가 수익을 창출하는 수단으로써 <b>파이썬</b> 코딩을 접근한다."
#
# },
# {
# "title": "<b>파이썬</b> 스킬 업 (기초를 넘어서, <b>파이썬</b>을 <b>파이썬</b>답게 사용하자!)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20569414",
# "image": "https://bookthumb-phinf.pstatic.net/cover/205/694/20569414.jpg?type=m1&udate=20211207",
# "author": "브라이언 오버랜드|존 베넷",
# "price": "40000",
# "discount": "36000",
# "publisher": "길벗",
# "pubdate": "20210531",
# "isbn": "1165215675 9791165215675",
# "description": "기초를 넘어서, <b>파이썬</b> 고수로 성장하는 첫걸음!\n런타임 효율성, 고급 문법, 람다 함수, 정규표현식... 이 책으로 <b>파이썬</b> 전체 기본 문법을 깊은 수준으로 처음부터 끝까지 훑어보면서 그 과정에서 학습한... 또한, 스킬 업할 수 있는 다양한 주제들도 함께 설명하므로 <b>파이썬</b> 기초를 익힌 후 다음 단계로 나아가고... "
#
# },
# {
# "title": "엑셀 × <b>파이썬</b> 업무 자동화 (매크로, VBA는 이제 낡았다!)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17468044",
# "image": "https://bookthumb-phinf.pstatic.net/cover/174/680/17468044.jpg?type=m1&udate=20210217",
# "author": "카네히로 카즈미",
# "price": "18000",
# "discount": "16200",
# "publisher": "인사이트",
# "pubdate": "20201203",
# "isbn": "8966262848 9788966262847",
# "description": "- 2020년 일본 아마존 IT 분야 최고의 베스트셀러 -이 책은 업무에서 가장 많이 사용하는 엑셀을 <b>파이썬</b>으로... 이제 누구나 쉽게 배울 수 있고, 확장성도 뛰어난 <b>파이썬</b>으로 회사 업무에 활력을 불어넣자.\n\n이 책의 특징\n1. 반복 업무만 줄여도 업무 시간을 반으로\n반복적인 엑셀 수작업을 <b>파이썬</b>으로 순식간에... "
#
# },
# {
# "title": "<b>파이썬</b> 입문 (예제 중심)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16328732",
# "image": "https://bookthumb-phinf.pstatic.net/cover/163/287/16328732.jpg?type=m1&udate=20210509",
# "author": "황재호",
# "price": "25000",
# "discount": "22500",
# "publisher": "인포앤북",
# "pubdate": "20200601",
# "isbn": "1196440921 9791196440923",
# "description": "알지만 <b>파이썬</b>은 처음인 분을 대상으로 내용이 구성되었습니다. 이 책은 두 단계로 구성되어 있습니다. 첫 단계에서는 변수, 데이터 형, 조건문, 반복문, 함수, 리스트, 튜플, 딕셔너리, 객체지향 등의 <b>파이썬</b> 기초를 익힙니다. 그리고 두 번째 단계에서는 Numpy, Pandas, Matplotlib의 <b>파이썬</b> 패키지를 이용하여... "
#
# },
# {
# "title": "<b>파이썬</b> 프로그래밍 (데이터 과학을 위한)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14412454",
# "image": "https://bookthumb-phinf.pstatic.net/cover/144/124/14412454.jpg?type=m1&udate=20211209",
# "author": "최성철",
# "price": "25000",
# "discount": "24500",
# "publisher": "한빛아카데미",
# "pubdate": "20190101",
# "isbn": "1156644364 9791156644361",
# "description": "데이터 과학을 기반으로 쉽게 배우는 <b>파이썬</b> 프로그래밍\n\n《데이터 과학을 위한 <b>파이썬</b> 프로그래밍》은 K-MOOC 공개강좌인 최성철 교수의 ‘데이터 과학을 위한 <b>파이썬</b>’ 강의를 기반으로 집필하였습니다. \n\n이 책은 <b>파이썬</b>으로 프로그래밍을 시작하는 입문자가 쉽게 이해할 수 있도록 기본 개념을 상세하게... "
#
# },
# {
# "title": "윤성우의 열혈 <b>파이썬</b> 기초편",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14261211",
# "image": "https://bookthumb-phinf.pstatic.net/cover/142/612/14261211.jpg?type=m1&udate=20210509",
# "author": "윤성우",
# "price": "16000",
# "discount": "14400",
# "publisher": "오렌지미디어",
# "pubdate": "20181120",
# "isbn": "8996094080 9788996094081",
# "description": "누구나 쉽게 공부할 수 있는 <b>파이썬</b>의 기초를 설명한다.\n<b>파이썬</b> 3을 기본으로 코딩 경험이 없는 초보자에게 <b>파이썬</b>을 설명합니다.그러나 이 책의 내용만 다 공부하더라도 기본적인 <b>파이썬</b> 활용이 가능한 수준에 이를 수 있습니다.\n또한 연계해서 출간되는 책들을 통해 학습을 이어 나갈 수 있다는 장점도... "
#
# },
# {
# "title": "<b>파이썬</b>으로 웹 크롤러 만들기 (초간단 나만의 웹 크롤러로 원하는 데이터를 가져오는 방법)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14649485",
# "image": "https://bookthumb-phinf.pstatic.net/cover/146/494/14649485.jpg?type=m1&udate=20210113",
# "author": "라이언 미첼",
# "price": "25000",
# "discount": "22500",
# "publisher": "한빛미디어",
# "pubdate": "20190329",
# "isbn": "1162241632 9791162241639",
# "description": "필요한 무기는 이 책과 <b>파이썬</b>뿐. BEAUTIFULSOUP, 셀레니움, 테서랙트 등 강력한 <b>파이썬</b> 라이브러리 사용법과 함께 API, 인증, 이미지 및 텍스트 인식, 로그인 처리 등 웹 크롤링의 기초부터 고급 기법까지 종합적으로 다루는 유일한 책. 실제 업무와 생활에 적용할 수 있는 예제가 가득하다. 2판은 예제를 추가... "
#
# },
# {
# "title": "<b>파이썬</b> 챌린지 (150개의 코딩 과제로 배운다)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20477376",
# "image": "https://bookthumb-phinf.pstatic.net/cover/204/773/20477376.jpg?type=m1&udate=20211208",
# "author": "니콜라 레이시",
# "price": "11200",
# "discount": "10080",
# "publisher": "제이펍",
# "pubdate": "20210512",
# "isbn": "1191600017 9791191600018",
# "description": "150개의 챌린지(코딩 과제)로 배우는 <b>파이썬</b> 코딩!\n\n영국의 캠브리지 대학교에서 출판한 이 책은 핵심 위주의 문법 설명. 그리고 그 문법 이해를 도와주는 간결한 예제, 이어서 독자들의 도전 의식을 자극하는 150개의 코딩 챌린지(도전 과제)가 이어지는 구성을 취하고 있습니다. 난이도가 점차 높아지는 150개의... "
#
# },
# {
# "title": "게임으로 배우는 <b>파이썬</b>",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14641076",
# "image": "https://bookthumb-phinf.pstatic.net/cover/146/410/14641076.jpg?type=m1&udate=20190315",
# "author": "다나카 겐이치로",
# "price": "17000",
# "discount": "15300",
# "publisher": "영진닷컴",
# "pubdate": "20190329",
# "isbn": "893145998X 9788931459982",
# "description": "게임을 만들며 즐겁게 배우는 <b>파이썬</b> 프로그래밍<b>파이썬</b>은 머신러닝과 AI 등 최첨단의 분야에서 주목받고 있으며, 프로그래밍의 원리를 배우기 위한... 이 책에서는 간단한 게임을 직접 만들어 보면서 쉽고 재미있게 <b>파이썬</b>을 배웁니다. 기초편에서는 <b>파이썬</b> 문법과 PYGAME 등 기초 지식에 대해서 설명하고... "
#
# },
# {
# "title": "<b>파이썬</b> for Beginner (쉽고 빠르게 익히는 프로그래밍의 기본 원리)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21371083",
# "image": "https://bookthumb-phinf.pstatic.net/cover/213/710/21371083.jpg?type=m1&udate=20211221",
# "author": "우재남",
# "price": "25000",
# "discount": "22500",
# "publisher": "한빛아카데미",
# "pubdate": "20220103",
# "isbn": "1156645743 9791156645740",
# "description": "일단 따라하면 바로 이해되는 <b>파이썬</b> 프로그래밍\n<b>파이썬</b>을 처음 접하는 독자를 대상으로 일대일 수업처럼 자세히 설명한 책입니다.\n꼭 알아야 할 핵심... 일단 코드를 입력하고 실행하다 보면 어느새 <b>파이썬</b> 프로그래밍과 친숙해져 있을 것입니다!\n※ 본 도서는 대학 강의용 교재로 개발되었으므로 연습문제... "
#
# },
# {
# "title": "<b>파이썬</b> 웹 프로그래밍 (Django장고로 배우는 쉽고 빠른 웹 개발)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=13878877",
# "image": "https://bookthumb-phinf.pstatic.net/cover/138/788/13878877.jpg?type=m1&udate=20211208",
# "author": "김석훈",
# "price": "22000",
# "discount": "19800",
# "publisher": "한빛미디어",
# "pubdate": "20180817",
# "isbn": "1162241047 9791162241042",
# "description": "Django 웹 프로그래밍 대표 도서, 『<b>파이썬</b> 웹 프로그래밍』의 최신 개정판! 2015년 첫 출간 즉시, 장고 웹 프로그래밍 대표 도서로 자리매김한 『<b>파이썬</b> 웹 프로그래밍』, 기존 도서의 장점은 살리고, <b>파이썬</b> 3.x 버전과 장고 2.x 버전 및 독자의 피드백을 반영하여 업그레이드된 개정판으로 돌아왔다. 이... "
#
# },
# {
# "title": "<b>파이썬</b> 기반 강화학습 알고리듬 (DP, Q-Learning, AC, DQN, TRPO, PPO, DDPG, TD3)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20813413",
# "image": "https://bookthumb-phinf.pstatic.net/cover/208/134/20813413.jpg?type=m1&udate=20210915",
# "author": "안드레아 론자",
# "price": "30000",
# "discount": "27000",
# "publisher": "에이콘출판",
# "pubdate": "20210825",
# "isbn": "1161755578 9791161755571",
# "description": "강화학습(RL)은 인공지능의 인기 있고 유망한 분야로 변화하는 요구사항에 대응해 이상적인 행동을 자동으로 결정하는 에이전트와 스마트한 모델을 만드는 알고리듬이다. 이 책은 강화학습 알고리듬을 마스터하고 자가학습(SELF-LEARNING)하는 에이전트를 구현하는 방법을 이해할 수 있도록 도와준다.... "
#
# },
# {
# "title": "셜록 홈즈 만화로 배우는 <b>파이썬</b> : 8주 안에 끝내는 가장 쉬운 <b>파이썬</b>",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21298081",
# "image": "https://bookthumb-phinf.pstatic.net/cover/212/980/21298081.jpg?type=m1&udate=20211120",
# "author": "정준우|김민기",
# "price": "19200",
# "discount": "19200",
# "publisher": "페스트북",
# "pubdate": "20211119",
# "isbn": "1191611892 9791191611892",
# "description": "복잡하고 지루한 코딩 교육은 이제 그만!만화를 통해 쉽고 재미있게,<b>파이썬</b>의 기본과 코딩에 대한 이해도를 책 한 권에 담아 가자- 쉽고 친절한 설명과 예시- 만화로 배우는 재미있는 <b>파이썬</b> 교육 이 책에서... 중도에 포기하지 않도록 꼭 필요한 기본적인 개념만 담아서 코딩, <b>파이썬</b>에 관심을 가지고 지속해서... "
#
# },
# {
# "title": "<b>파이썬</b> 클린 코드 (유지보수가 쉬운 <b>파이썬</b> 코드를 만드는 비결)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14469064",
# "image": "https://bookthumb-phinf.pstatic.net/cover/144/690/14469064.jpg?type=m1&udate=20190130",
# "author": "마리아노 아나야",
# "price": "28000",
# "discount": "25200",
# "publisher": "터닝포인트",
# "pubdate": "20190225",
# "isbn": "1161340467 9791161340463",
# "description": "견고하면서도 확장성이 뛰어난 <b>파이썬</b> 코드를 만드는 비법\n\n<b>파이썬</b>은 누구나 쉽게 시작할 수 있는 프로그래밍 언어이다. 그러나 이 책에서 소개하는... 이 책을 통해 <b>파이썬</b>의 철학을 따르는 <b>파이썬</b>스러운 클린 코드를 작성하는 방법에 대해 알아보자.\n\n* 클린 코드란 무엇인가?\n* <b>파이썬</b>스러운(PYTHONIC)... "
#
# },
# {
# "title": "난생처음 컴퓨팅 사고 with <b>파이썬</b>",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17717718",
# "image": "https://bookthumb-phinf.pstatic.net/cover/177/177/17717718.jpg?type=m1&udate=20210828",
# "author": "김명호",
# "price": "23000",
# "discount": "22540",
# "publisher": "한빛아카데미",
# "pubdate": "20210105",
# "isbn": "1156645212 9791156645214",
# "description": "우선 컴퓨팅 사고의 의미를 이해하고 알고리즘을 표현하는 방법을 배운 후에 <b>파이썬</b> 문법을 다룬다. 또한 컴퓨팅 사고력과 코딩 실력을 함께 기르기 위하여 4개의 미니 프로젝트를 제공한다. 컴퓨팅 사고와 <b>파이썬</b>이 처음이더라도 188개의 예제를 따라 하다보면 어느새 프로그래밍 실력과 문제 해결 실력이... "
#
# },
# {
# "title": "윤성우의 열혈 <b>파이썬</b> 중급편",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=15658995",
# "image": "https://bookthumb-phinf.pstatic.net/cover/156/589/15658995.jpg?type=m1&udate=20210422",
# "author": "윤성우",
# "price": "16000",
# "discount": "14400",
# "publisher": "오렌지미디어",
# "pubdate": "20191029",
# "isbn": "8996094099 9788996094098",
# "description": "윤성우의 열혈 <b>파이썬</b> 기초편 이후를 말합니다.\n이미 출간되어서 좋은 평가를 받고 있는 '열혈 <b>파이썬</b> 기초편'의 뒤를 잇는 내용의 서적입니다. <b>파이썬</b>을 조금 더 알고 싶어하는 이들을 대상으로 내용이 구성되어 있기 때문에 이전에 저자가 출간한 <b>파이썬</b> 기초편에 준하는 수준의 기본 지식이 있다면 즐겁고... "
#
# },
# {
# "title": "금융 <b>파이썬</b> 쿡북 (금융 데이터 처리와 기술 분석부터 딥러닝 적용까지)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17932118",
# "image": "https://bookthumb-phinf.pstatic.net/cover/179/321/17932118.jpg?type=m1&udate=20210406",
# "author": "에릭 르윈슨",
# "price": "35000",
# "discount": "31500",
# "publisher": "에이콘출판",
# "pubdate": "20210210",
# "isbn": "1161750509 9791161750507",
# "description": "금융 데이터 처리와 기술 분석부터 딥러닝 적용까지\n금융 <b>파이썬</b> 쿡북<b>파이썬</b>은 금융에서 가장 보편적으로 사용되는 언어이면서 방대한 라이브러리를 갖고 있다. 금융 데이터를 다운로드하는 다양한 방법과 모델링을 위해 준비하는 기법을 알려준다. 기술분석에 사용되는 볼린저 밴드, MACD, RSI 그리고... "
#
# },
# {
# "title": "모두의 알고리즘 with <b>파이썬</b> (컴퓨팅 사고를 위한 기초 알고리즘)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=12057147",
# "image": "https://bookthumb-phinf.pstatic.net/cover/120/571/12057147.jpg?type=m1&udate=20210508",
# "author": "이승찬",
# "price": "16000",
# "discount": "14400",
# "publisher": "길벗",
# "pubdate": "20170518",
# "isbn": "1160501726 9791160501728",
# "description": "《모두의 알고리즘 with <b>파이썬</b>》은 중요하지만 어려운 주제인 알고리즘을 초보자와 비전공자가 배울 수 있게 최대한 전문 용어와 복잡한 수학을 사용하지 않고 설명한다. 또한, 간단한 문제를 풀면서 기초 알고리즘을 설명하기 때문에 쉽게 이해할 수 있다. 그동안 알고리즘을 배우고 싶었지만, 어려워서... "
#
# },
# {
# "title": "Introduction to <b>파이썬</b> (338 예제로 완성하는 <b>파이썬</b>)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17854273",
# "image": "https://bookthumb-phinf.pstatic.net/cover/178/542/17854273.jpg?type=m1&udate=20211208",
# "author": "황재호",
# "price": "25000",
# "discount": "22500",
# "publisher": "인포앤북",
# "pubdate": "20210301",
# "isbn": "1196440948 9791196440947",
# "description": "338 예제로 <b>파이썬</b>을 정복하자!\n<b>파이썬</b> 초보를 위한 최선의 학습서!\n\n이 책은 다양한 난이도의 예제를 재미있게 풀어보면서 자연스럽게 <b>파이썬</b> 프로그래밍의 기초와 활용 방법을 익힐 수 있도록 고안되었습니다. 프로그래밍을 처음 접하는 초보자나 다른 컴퓨터 언어는 어느 정도 알지만 <b>파이썬</b>은 처음인 분을... "
#
# },
# {
# "title": "<b>파이썬</b>으로 배우는 컴퓨팅 사고 (문제해결 중심의 <b>파이썬</b> 프로그래밍)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14618518",
# "image": "https://bookthumb-phinf.pstatic.net/cover/146/185/14618518.jpg?type=m1&udate=20200304",
# "author": "김완섭",
# "price": "17000",
# "discount": "16150",
# "publisher": "인피니티북스",
# "pubdate": "20200212",
# "isbn": "1185578439 9791185578439",
# "description": "<b>파이썬</b>은 프로그래밍 초보자가 사용하기에 매우 적합한 언어이다. 다른 언어에 비해 쉽기 때문에 자신도... 소프트웨어 분야에 호기심이 있고, 프로그래밍 언어에 관심이 있다면 <b>파이썬</b>으로 시작하는 게 정답일 것이다.\n\n그러나 쉬운 초보자용 언어라고 가볍게 생각하면 안 된다. <b>파이썬</b>은 쉬울 뿐만 아니라 매우... "
#
# },
# {
# "title": "<b>파이썬</b> 웹프로그래밍 실전편 (Django장고를 활용한 쉽고 빠른 웹 개발)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=15654623",
# "image": "https://bookthumb-phinf.pstatic.net/cover/156/546/15654623.jpg?type=m1&udate=20191202",
# "author": "김석훈",
# "price": "32000",
# "discount": "28800",
# "publisher": "한빛미디어",
# "pubdate": "20191101",
# "isbn": "1162242264 9791162242261",
# "description": "이 책이 제시하는 핵심 내용\n장고 프레임워크를 사용해서 상용화 수준의 앱을 만들고, 앱의 기능을 확장하고, 클라우드 서버에서 배포하는 것까지 다룬다."
#
# },
# {
# "title": "구글과 <b>파이썬</b>으로 시작하는 보안 (취약점은 이제 끝! 실전 예제와 코드로 배우는 데이터 보호)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20870356",
# "image": "https://bookthumb-phinf.pstatic.net/cover/208/703/20870356.jpg?type=m1&udate=20210910",
# "author": "김용재",
# "price": "33000",
# "discount": "29700",
# "publisher": "비제이퍼블릭",
# "pubdate": "20210831",
# "isbn": "1165920816 9791165920814",
# "description": "보여주는 <b>파이썬</b> 예제들로 구성되어 있습니다. 예제들을 통해 보안에서 <b>파이썬</b>을 어떻게 응용할지에 대한 아이디어를 얻고 책 전반을 통해 보안, 개인... - <b>파이썬</b> 코드를 통해 데이터의 흐름을 보며 좀더 직관적으로 이해할 수 있다.- 보안이 가진 원초적인 불완전함을 극복하기 위해 해야 될 노력들에... "
#
# },
# {
# "title": "<b>파이썬</b> 마스터 1·2급",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21223572",
# "image": "https://bookthumb-phinf.pstatic.net/cover/212/235/21223572.jpg?type=m1&udate=20211030",
# "author": "유성열",
# "price": "22000",
# "discount": "19800",
# "publisher": "명진씨앤피",
# "pubdate": "20211101",
# "isbn": "8992561520 9788992561525",
# "description": "<b>파이썬</b>에 대한 전문지식과 IT서비스 및 인프라 구축의 모든 것을 담았다〈<b>파이썬</b>의 기본 개념부터 심화 학습까지, <b>파이썬</b> 마스터로의 도약을 꿈꾸다〉<b>파이썬</b>은 초보자부터 전문가까지 넓은 사용자층을 보유하고 있다. 누구나 쉽게 접근할 수 있을 뿐 아니라 대부분의 응용 소프트웨어에서 사용 가능하기... "
#
# },
# {
# "title": "잡아라! 텍스트 마이닝 with <b>파이썬</b> (지금 바로 할 수 있는 데이터 추출과 분석)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14820664",
# "image": "https://bookthumb-phinf.pstatic.net/cover/148/206/14820664.jpg?type=m1&udate=20210509",
# "author": "서대호",
# "price": "17000",
# "discount": "15300",
# "publisher": "비제이퍼블릭",
# "pubdate": "20190430",
# "isbn": "1186697784 9791186697788",
# "description": "<b>파이썬</b>을 이용한 텍스트 마이닝으로\n‘아’ 다르고 ‘어’ 다른 한글 텍스트 분석하기알고리즘에 대한 수학적인 이해가 없어도 개념 파악을 도와주며 독자들이 코드를 따라하면서 결과를 바로바로 확인할 수 있도록 구성했다. 또한 텍스트 데이터 추출을 위해 필수적인 웹 크롤링 기술도 익힌다. 따라서... "
#
# },
# {
# "title": "21개의 작고 재미난 <b>파이썬</b> 프로젝트 (프로그래밍 스킬, 새로운 알고리즘, 테스트 주도 개발을 배우다)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20810302",
# "image": "https://bookthumb-phinf.pstatic.net/cover/208/103/20810302.jpg?type=m1&udate=20211218",
# "author": "켄 유엔스-클락",
# "price": "30000",
# "discount": "27000",
# "publisher": "제이펍",
# "pubdate": "20210811",
# "isbn": "1191600343 9791191600346",
# "description": "모든 <b>파이썬</b> 프로그래머를 위해 마련한 코딩 기술을 향상하기 위한 최고의 한 권!\n\n이 책은 다른 책들과 달리 명령줄 프로그램을 사용해서 다양한 <b>파이썬</b>의 기능을 설명하고 있다. 각 장마다 문제... 아울러 이 책은 잘 구조화되고 문서화돼 있으며, 테스트할 수 있는 코드를 <b>파이썬</b>으로 작성하는 방법을... "
#
# },
# {
# "title": "<b>파이썬</b> 데이터 과학 통계 학습",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20578051",
# "image": "https://bookthumb-phinf.pstatic.net/cover/205/780/20578051.jpg?type=m1&udate=20210731",
# "author": "황본현우|정지현",
# "price": "29000",
# "discount": "26100",
# "publisher": "정보문화사",
# "pubdate": "20210525",
# "isbn": "8956749078 9788956749075",
# "description": "<b>파이썬</b>으로 데이터 과학 완전 정복!이 책에서는 데이터 과학 데이터 분석을 위한 가장 보편적인 프로그래밍 언어인 <b>파이썬</b>을 다룬다. <b>파이썬</b>의 설치 방법과 기본적인 지식부터 차근차근 설명해나간다. 자료형, 변수, 예약어, 식별자, 리터럴 상수 등 <b>파이썬</b>의 기초부터 넘파이, 판다스, 사이파이, 사이킷런 등... "
#
# },
# {
# "title": "바이오<b>파이썬</b>으로 만나는 생물정보학 (<b>파이썬</b> 프로그래밍을 통해 풀어보는 생명의 구조)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14633452",
# "image": "https://bookthumb-phinf.pstatic.net/cover/146/334/14633452.jpg?type=m1&udate=20210211",
# "author": "한주현",
# "price": "26000",
# "discount": "23400",
# "publisher": "비제이퍼블릭",
# "pubdate": "20190322",
# "isbn": "1186697814 9791186697818",
# "description": "실제로 현업에서 사용하는 바이오<b>파이썬</b> 모듈과 100개의 프로그래밍 예제를 통해 &#x0D;생물정보학 <b>파이썬</b> 프로그래밍의 기초를 쌓을 수 있는 도서!&#x0D;... 쏟아지는 생물정보 빅데이터를 처리함에 있어 배우기 쉽고 원하는 결과를 신속하게 만들어 낼 수 있는 <b>파이썬</b>은 이 시대의 단연 인기 있는 언어다.... "
#
# },
# {
# "title": "<b>파이썬</b>을 활용한 나만의 RPA 만들기 (2021)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17716979",
# "image": "https://bookthumb-phinf.pstatic.net/cover/177/169/17716979.jpg?type=m1&udate=20210106",
# "author": "안정국",
# "price": "25000",
# "discount": "22500",
# "publisher": "삼일인포마인",
# "pubdate": "20210104",
# "isbn": "8959429120 9788959429127",
# "description": "<b>파이썬</b>을 활용하여 나만의 로봇 비서를 만들어 보자!\n\n[특장점]\n● 국내 최초로 <b>파이썬</b>을 활용한 RPA 제작 사례를 설명\n● <b>파이썬</b> 기초, 판다스 기초에 대한 상세한 설명\n● 일반업무 뿐만 아니라 재무/회계와 관련된 RPA 작성 사례 및 텔레그램을 이용한 자동 전달 기능 구현 사례 설명\n\n[주요내용]... "
#
# }
# ]
# }
#
# <class 'str'>
# 검색결과 1428

# %%
여기위에서 1을넣어서 total변수를생성해놓고
여기밑에서 쓰는식으로 구현이가능한데
현재로서는 스타트가 1000이니까
이제 꼭 total을 쓰지않아도 되는 일이 나타나버렸습니다.
넹 넵 한번 계쏙 진행하다가 질문있으시면 알려주세용 넹 감사합니다

# %%
client_id = "3wU5xwXfFVL4LweQzLHQ" # 애플리케이션 ID
client_secret = "K60NkftSAH" # 애플리케이션  Secret

encText = urllib.parse.quote("파이썬") ## 한글 URL 추가 ==> URL 인코딩



rangeText_start = urllib.parse.quote("1000") ## 요청 변수
url = "https://openapi.naver.com/v1/search/book?query=" + encText + "&display=100" + "&start=" + rangeText_start ## 요청 URL + 요청 변수

request = urllib.request.Request(url) ## urllib.request.Request 클래스 == URL 요청 관련 정보 담는 추상화 클래스
request.add_header("X-Naver-Client-Id",client_id) ## add_header 메서드 ==> 헤더 정보 추가
request.add_header("X-Naver-Client-Secret",client_secret)  ## add_header 메서드 ==> 헤더 정보 추가

response = urllib.request.urlopen(request) ## urllib.request.urlopen 메서드 ==> url string OR request 객체 전달 받음
rescode = response.getcode()
list = []

if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8')) ## 인코딩 ==> 출력
    text = response_body.decode('utf-8')
    print(type(text))
    dict = json.loads(text)
    total = dict['total']
    print("검색결과", total)
else:
    print("Error Code:" + rescode) ## 네이버 API 오류 코드 ==> 가이드 참고
# Out:
# {
# "lastBuildDate": "Fri, 24 Dec 2021 10:57:52 +0900",
# "total": 1428,
# "start": 1000,
# "display": 100,
# "items": [
# {
# "title": "정책 기반 시스코 ACI 데이터센터 (아키텍처, 개념, 방법론까지)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=9778665",
# "image": "https://bookthumb-phinf.pstatic.net/cover/097/786/09778665.jpg?type=m1&udate=20160218",
# "author": "Lucien Avramov|Maurizio Portolani",
# "price": "30000",
# "discount": "27000",
# "publisher": "성안당",
# "pubdate": "20151110",
# "isbn": "8931553897 9788931553895",
# "description": "이 책에서, 시스코 데이터센터 전문가는 루시엔 아라모브와 마우리지오 포르톨라니가 시스코 애플리케이션 중심 인프라스트럭처(ACI)와 <b>파이썬</b>... 그런 다음, 네트워크 관리를 자동화하고 ACI 환경에서 커스터마이제이션을 간단하게 하기 위해 <b>파이썬</b> 스크립트와 REST를 사용하는 방법을... "
#
# },
# {
# "title": "기업용 블록체인",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=15208965",
# "image": "https://bookthumb-phinf.pstatic.net/cover/152/089/15208965.jpg?type=m1&udate=20200821",
# "author": "나라얀 프루스티",
# "price": "25000",
# "discount": "22500",
# "publisher": "에이콘출판",
# "pubdate": "20190730",
# "isbn": "1161753451 9791161753454",
# "description": "기업용 블록체인 라이브러리인 큐오럼을 활용한 전자의료기록 관리, 글로벌 은행 간 자금 이체, 스마트폰 번호 기반 송금 등 이더리움의 스마트 계약 예제를 알기 쉽게 설명하는 책이다. 큐오럼은 GO 이더리움의 포크로서 접근성이 매우 높은 이더리움의 토대를 사용하되 기업 중에서도 특히 신뢰성과 보안성을... "
#
# },
# {
# "title": "앤서블 철저 입문 (Ansible로 클라우드 구성 관리 자동화하기)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=12685925",
# "image": "https://bookthumb-phinf.pstatic.net/cover/126/859/12685925.jpg?type=m1&udate=20171103",
# "author": "히로가와 히데토시|타이라 하지메|하시모토 나오야|모리타 구티히로|와타나베 카즈히로",
# "price": "25000",
# "discount": "22500",
# "publisher": "위키북스",
# "pubdate": "20171102",
# "isbn": "1158390807 9791158390808",
# "description": "앤서블 설치부터 사용 방법을 이 책 한 권으로 끝내세요!《앤서블 철저 입문》에서는 서버를 편하게 관리하는 방법을 소개합니다. 이 책은 실습 위주의 예제들로 구성되어 있어 어려움 없이 따라 할 수 있습니다. 또한 AWS, 애저 등에서도 활용할 수 있는 방법을 제시하여 실무에 적용할 수 있습니다. 서버 관리와... "
#
# },
# {
# "title": "아름다운 시각화 (전문가들이 알려주는 데이터 시각화의 비법)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=6925924",
# "image": "https://bookthumb-phinf.pstatic.net/cover/069/259/06925924.jpg?type=m1&udate=20190203",
# "author": "줄리 스틸|노아 일린스키",
# "price": "32000",
# "discount": "28800",
# "publisher": "인사이트",
# "pubdate": "20120519",
# "isbn": "8966260306 9788966260300",
# "description": "다양한 분야에서 활용할 수 있는 핵심 시각화 방법을 경험해보자&#x0D;&#x0D;시각화는 복잡한 정보가 쉽게 파악되도록 데이터를 그림과 같은 눈에 띄는 정보로 묘사하는 방법이다. 예를 들어 우리가 흔히 보는 지하철 노선도나, 선거 개표 방송, 각종 통계 자료 같은 것이 시각화로 표현한 정보이다. 그런데 똑같은... "
#
# },
# {
# "title": "빅데이터 분석을 위한 스파크 2 프로그래밍 (대용량 데이터 처리부터 머신러닝까지)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=13483878",
# "image": "https://bookthumb-phinf.pstatic.net/cover/134/838/13483878.jpg?type=m1&udate=20180406",
# "author": "백성민",
# "price": "35000",
# "discount": "31500",
# "publisher": "위키북스",
# "pubdate": "20180412",
# "isbn": "115839103X 9791158391034",
# "description": "특히 스파크를 써 보고 싶지만 새로운 언어를 배우는 데 따르는 부담 때문에 망설이던 개발자들을 위해 스칼라, 자바, <b>파이썬</b> 예제를 수록했습니다. 이 책을 통해 스파크에 대한 기초를 다지고 나면 각자의 영역에서 스파크가 제공하는 풍부한 기능들을 더 깊이 있고 자유롭게 활용할 수 있게 될 것입니다."
#
# },
# {
# "title": "JVM 언어 입문 (반양장, 자바, 스칼라, 클로저, 코틀린, 그루비 체험하기)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=13943248",
# "image": "https://bookthumb-phinf.pstatic.net/cover/139/432/13943248.jpg?type=m1&udate=20180902",
# "author": "빈센트 반 데르 렌",
# "price": "36000",
# "discount": "32400",
# "publisher": "에이콘출판",
# "pubdate": "20180830",
# "isbn": "1161751963 9791161751962",
# "description": "자바 가상 머신(JVM)을 등장시킨 자바 플랫폼에 대한 개괄적인 내용과 JVM의 주요 개념을 설명하고 가장 인기 있는 사용 사례를 소개한다. JVM 언어로 가장 대표적인 자바의 기본 원리와 애플리케이션 개발 방법을 시작으로 스칼라와 클로저, 코틀린, 그루비의 기본 원리와 개발 방법을 다룬다. 다양한 JVM... "
#
# },
# {
# "title": "데이터분석 따라하기(SPSS와 Python, 그리고 Excel을 활용한)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16563831",
# "image": "https://bookthumb-phinf.pstatic.net/cover/165/638/16563831.jpg?type=m1&udate=20200818",
# "author": "정철용",
# "price": "19000",
# "discount": "",
# "publisher": "북넷",
# "pubdate": "20200815",
# "isbn": "1186947497 9791186947494",
# "description": "사회과학을 공부하는 학생들에게 쉽게 데이터 분석을 하는 방법을 매학기 수업을 진행하면서 고민하는 문제이다. 한가지 데이터분석 툴을 가르치는 데에도 시간이 많이 소요된다. 툴에 대해서는 가장 기본적인 것만 이해시키고 하나의 데이터 셋을 사용하여 EXCEL,SPSS,PYTHON을 맛보게 한다는 생각에서 본... "
#
# },
# {
# "title": "Spark와 머신 러닝 (빅데이터 분석과 예측 모델 트레이닝을 위한)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=9917058",
# "image": "https://bookthumb-phinf.pstatic.net/cover/099/170/09917058.jpg?type=m1&udate=20160218",
# "author": "닉 펜트레스",
# "price": "35000",
# "discount": "",
# "publisher": "에이콘출판",
# "pubdate": "20160104",
# "isbn": "8960778060 9788960778061",
# "description": "이 책은 급변하는 비즈니스 환경에서 대규모 데이터를 실시간으로 처리해서 분류, 회귀, 클러스터 등 다양한 모델을 트레이닝한다. 데이터의 모델 트레이닝을 통해 다양한 소프트웨어 비즈니스 요구사항을 높은 정확도로 예측할 때 사용할 수 있다. 이 책은 독자가 대규모 실시간 데이터를 처리할 때 다양한... "
#
# },
# {
# "title": "머신러닝 인 액션 (기계 학습 알고리즘으로 데이터 마이닝하기)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=7235092",
# "image": "https://bookthumb-phinf.pstatic.net/cover/072/350/07235092.jpg?type=m1&udate=20210509",
# "author": "피터 해링턴",
# "price": "30000",
# "discount": "27000",
# "publisher": "제이펍",
# "pubdate": "20130626",
# "isbn": "8994506667 9788994506661",
# "description": "통계자료 처리, 데이터 분석, 데이터 시각화 등을 독자들의 업무에 바로 적용할 수 있도록 알고리즘 주요 부분을 재사용 가능한 코드로 사용하였다. 독특하고 다양한 <b>파이썬</b> 예제를 통해 분류, 예측, 추천 그리고 고차원 속성을 요약하고 간소화하는 개념과 방법을 이해할 수 있다."
#
# },
# {
# "title": "마이크로비트로 배우는 창의설계코딩 + 마이크로비트 Basic study KIT (+ 마이크로비트 Basic study KIT)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16314348",
# "image": "https://bookthumb-phinf.pstatic.net/cover/163/143/16314348.jpg?type=m1&udate=20200328",
# "author": "조영준",
# "price": "85000",
# "discount": "83300",
# "publisher": "광문각",
# "pubdate": "20200218",
# "isbn": "8970939911 9788970939919",
# "description": "또한, 최근 코딩 교육을 위한 블록 코딩 방식과 <b>파이썬</b> 언어를 사용하여 마이크로비트를 활용할 수 있다.\n\n본 책에서는 초등학생부터 코딩을 처음 접하는 성인들까지 활용할 수 있도록 기초 코딩 교육을 위한 블록 코딩 방식을 활용하고 있으며, 쉽고 간단한 예제를 다양하게 제공하고 있다. 또한... "
#
# },
# {
# "title": "사물인터넷을 활용한 드론 DIY 가이드 (드론, 입문부터 제작까지)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=12696567",
# "image": "https://bookthumb-phinf.pstatic.net/cover/126/965/12696567.jpg?type=m1&udate=20190724",
# "author": "김회진|김시준|패트릭 에릭슨",
# "price": "20000",
# "discount": "19600",
# "publisher": "광문각",
# "pubdate": "20171030",
# "isbn": "8970938621 9788970938622",
# "description": "『사물인터넷을 활용한 드론 DIY 가이드』는 드론을 제작하거나 연구를 목적으로 하고자 하는 분들을 위해 전반적인 배경 지식과 실무 지식을 습득하도록 구성하였다. 이러한 목적에 충실히 하고자 첫 번째, 드론의 전반적인 이해에 필요한 원리와 구조, 드론 플랫폼, 비행 컨트롤러, 추진력 설계, 통신 방안... "
#
# },
# {
# "title": "Software, Coding Python",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16441299",
# "image": "https://bookthumb-phinf.pstatic.net/cover/164/412/16441299.jpg?type=m1&udate=20200731",
# "author": "박준식(Sobaek)",
# "price": "10000",
# "discount": "10000",
# "publisher": "퍼플",
# "pubdate": "20200722",
# "isbn": "8924072285 9788924072280",
# "description": "<b>파이썬</b>의 채택이 증가하고 있을 뿐 아니라, 2018년부터 초중고에서 소프트웨어 교육이 정규 교과목으로 채택되어 의무 교육화 되었으며, 대학에서도 C언어나 JAVA 언어를 이용한 교육에서 <b>파이썬</b>... 이것이 바로 저자가 소프트웨어 코딩 공부를 위한 프로그래밍 언어로 <b>파이썬</b>을 채택한 이유이다.이 책은... "
#
# },
# {
# "title": "재무빅데이터 분석사 2급 (하)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16243723",
# "image": "https://bookthumb-phinf.pstatic.net/cover/162/437/16243723.jpg?type=m1&udate=20200319",
# "author": "김태식",
# "price": "25000",
# "discount": "22500",
# "publisher": "와이북스",
# "pubdate": "20200207",
# "isbn": "1135018634 9791135018633",
# "description": "- 독자대상 : 자격증시험 준비생\n- 구성 및 특징 : \t\t\t\t\t\t\t\t\t\t\n① 최근 경향 반영\t\t\t\t\t\t\t\t\t\t\n② 학습 내용 체계적으로 구성"
#
# },
# {
# "title": "HTML5 웹소켓 프로그래밍 (안전하고 확장 가능한 실시간 웹 애플리케이션 개발)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=8509494",
# "image": "https://bookthumb-phinf.pstatic.net/cover/085/094/08509494.jpg?type=m1&udate=20201021",
# "author": "밴고스 피터니어스",
# "price": "15000",
# "discount": "13500",
# "publisher": "에이콘출판",
# "pubdate": "20141219",
# "isbn": "8960776483 9788960776487",
# "description": "HTML5 웹소켓(WebSocket)은 서버와 클라이언트 사이에서 전이중 양방향 통신을 제공하여 실시간 웹 응용프로그램이 가능하게 해준다. 이 책에서는 실제로 동작하는 채팅 예제 응용프로그램 작성을 통해 웹소켓의 기능을 상세하게 설명하고 현대적인 웹 응용프로그램을 만드는 전체 과정을 안내해준다. 또한... "
#
# },
# {
# "title": "라즈베리파이3 (네트워크 프로그래밍)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14645242",
# "image": "https://bookthumb-phinf.pstatic.net/cover/146/452/14645242.jpg?type=m1&udate=20201006",
# "author": "이용진",
# "price": "18000",
# "discount": "17100",
# "publisher": "복두출판사",
# "pubdate": "20190304",
# "isbn": "1159065012 9791159065019",
# "description": "▶ 이 책은 네트워크 프로그래밍을 다룬 이론서입니다. 네트워크 프로그래밍의 기초적이고 전반적인 내용을 학습할 수 있습니다."
#
# },
# {
# "title": "Deep Learning Cookbook (빠르게 실무에 적용할 수 있는 딥러닝으로 할 수 있는 모든 예제)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14439963",
# "image": "https://bookthumb-phinf.pstatic.net/cover/144/399/14439963.jpg?type=m1&udate=20191010",
# "author": "Douwe Osinga",
# "price": "29000",
# "discount": "26100",
# "publisher": "느린생각",
# "pubdate": "20190107",
# "isbn": "1187139211 9791187139218",
# "description": "분명, DEEP LEARNING은 어려운 분야이다. 많은 수학 수식과 통계 지식이 필요하다. 하지만 GOOGLE사가 TENSORFLOW를 내놓은지 몇 년이 지난 지금, KERAS가 등장하고 수 많은 모델이 개발되었으며 많은 연구자들이 이 분야를 연구하면서 DEEP LEARNING은 조금씩 쉬워지고 있다.\n모든 분야가 그렇듯 DEEP... "
#
# },
# {
# "title": "컴퓨터 비전과 알고리즘 (OpenCV 알고리즘을 활용한 컴퓨터 비전 프로그래밍)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14960271",
# "image": "https://bookthumb-phinf.pstatic.net/cover/149/602/14960271.jpg?type=m1&udate=20201028",
# "author": "아민 아마디 타제칸디",
# "price": "30000",
# "discount": "27000",
# "publisher": "에이콘출판",
# "pubdate": "20190530",
# "isbn": "1161753079 9791161753072",
# "description": "컴퓨터의 처리 능력 및 성능 향상으로 인해 컴퓨터 비전 영역의 활용 가능성은 매우 긍정적인 평가를 받고 있다. 애플리케이션에서 컴퓨터 비전 작업을 좀 더 효율적으로 수행하기 위해 많은 알고리즘이 개발되고 있다.\n이 책은 비전 알고리즘에 대한 기본 내용으로 시작하며, 실습 예제를 통해 내부의 각 동작이... "
#
# },
# {
# "title": "The IDA Pro Book (리버스 엔지니어링에 날개를 달다,한국어판)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=6977530",
# "image": "https://bookthumb-phinf.pstatic.net/cover/069/775/06977530.jpg?type=m1&udate=20170811",
# "author": "크리스 이글",
# "price": "45000",
# "discount": "40500",
# "publisher": "에이콘출판",
# "pubdate": "20120823",
# "isbn": "8960773328 9788960773325",
# "description": "IDA Pro를 사용해보고 싶은데 어떻게 시작해야 할지 잘 모른다면 이 책으로 시작해보길 바란다. 이 책은 IDA Pro에 대한 훌륭한 가이드로, IDA Pro의 구성부터 기본적인 기능, 스크립트와 SDK를 활용한 당면한 문제를 쉽게 해결할 수 있는 방법 등 IDA의 모든 것을 알려준다. 이 책을 보고 나면 IDA Pro를... "
#
# },
# {
# "title": "애자일 데이터 과학 2.0 (변화에 기민하게 반응하는 견고한 데이터 분석 애플리케이션 구축)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=13464577",
# "image": "https://bookthumb-phinf.pstatic.net/cover/134/645/13464577.jpg?type=m1&udate=20201016",
# "author": "러셀 저니",
# "price": "28000",
# "discount": "25200",
# "publisher": "위키북스",
# "pubdate": "20180405",
# "isbn": "1158390947 9791158390945",
# "description": "개정판 《애자일 데이터 과학 2.0》에서는 애자일 데이터 과학 개발 방법론을 활용해 <b>파이썬</b>(PYTHON), 아파치 스파크(APACHE SPARK), 카프카(KAFKA) 등의 도구로 데이터 애플리케이션을 구축하는 방법을 배우게 될 것이다.\n\n이 책에서는 아파치 카프카와 아파치 스파크, 몽고DB, 엘라스틱서치(ELASTICSEARCH)... "
#
# },
# {
# "title": "실전! 딥러닝 (텐서플로와 케라스를 이용한 딥러닝 최신 기술 활용 가이드)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14488509",
# "image": "https://bookthumb-phinf.pstatic.net/cover/144/885/14488509.jpg?type=m1&udate=20190201",
# "author": "오타 미쯔히사|수도 코다이|쿠로사와 타쿠마|오다 다이스케",
# "price": "25000",
# "discount": "22500",
# "publisher": "위키북스",
# "pubdate": "20190215",
# "isbn": "1158391390 9791158391393",
# "description": "실무 현장에서 사용할 만한 유용한 딥러닝 응용 예제로 실습해 보자!구글이 오픈소스화한 ‘텐서플로’는 많은 개발자와 기업에서 사용되고 있습니다. 이 책은 텐서플로에 대한 기초적인 내용부터 고수준 API인 케라스를 이용한 딥러닝 모델 구축까지 상세하게 설명한 엔지니어를 위한 입문서입니다. 화제가 된... "
#
# },
# {
# "title": "메이커 매뉴얼 (메이커가 되고 싶은 이들을 위한 입문 가이드)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=10756357",
# "image": "https://bookthumb-phinf.pstatic.net/cover/107/563/10756357.jpg?type=m1&udate=20201028",
# "author": "안드레아 마이에타|파올로 알리베르티",
# "price": "25000",
# "discount": "22500",
# "publisher": "한빛미디어",
# "pubdate": "20160701",
# "isbn": "8968482888 9788968482885",
# "description": "[메이커 매뉴얼]은 메이커가 반드시 알아야 할 기본적이면서도 필수적인 지식들을 정리한 메이커 분야 입문서 및 안내서이다. 책은 메이커의 정의, 프로젝트의 시작 및 관리, 팀 협업 및 관리, 자금 조달 방법, 메이크 분야의 제조기술 등 메이커가 반드시 알고 있어야 하는 기초적이면서도 기본적인 내용을... "
#
# },
# {
# "title": "라즈베리 파이 3 (한 권으로 끝내자!,입문과 실전 활용)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=13796660",
# "image": "https://bookthumb-phinf.pstatic.net/cover/137/966/13796660.jpg?type=m1&udate=20211006",
# "author": "후쿠다 카즈히로",
# "price": "28000",
# "discount": "25200",
# "publisher": "위키북스",
# "pubdate": "20180726",
# "isbn": "1158391102 9791158391102",
# "description": "손바닥 크기의 리눅스 컴퓨터 ‘라즈베리 파이’를 자유자재로 다뤄보자!라즈베리 파이의 개요(종류와 각 부분 명칭 등)와 OS 설치 방법, 저전력 소형 컴퓨터로의 이용, 유?무선 LAN 설정 서버(웹 파일 서버) 구축, 프로그래밍 기본, 전자 공작, I2C 디바이스 제어, 인터넷 서비스를 이용한 응용까지 라즈베리... "
#
# },
# {
# "title": "쿠버네티스 쿡북 (클라우드 네이티브 애플리케이션 구축)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=13954113",
# "image": "https://bookthumb-phinf.pstatic.net/cover/139/541/13954113.jpg?type=m1&udate=20180825",
# "author": "세바스티앙 고아스구엔|마이클 하우젠블라스",
# "price": "20000",
# "discount": "18000",
# "publisher": "에이콘출판",
# "pubdate": "20180912",
# "isbn": "1161752013 9791161752013",
# "description": "쿠버네티스와 관련된 지식을 80여 가지의 레시피를 통해 설명하는 책이다. 쿠버네티스에 대한 개념을 더욱 심화하거나, 쿠버네티스를 실제로 사용할 때 참고할 만한 책이다. 쿠버네티스에 대한 기본 개념을 숙지한 상태로 쿠버네티스 인프라를 구축하기 전에 이 책을 가볍게 쭉 읽어 본다면 도움이 될 것이다."
#
# },
# {
# "title": "텐서플로로 시작하는 딥러닝 (합성곱 신경망 중심의 딥러닝 알고리즘)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=12210515",
# "image": "https://bookthumb-phinf.pstatic.net/cover/122/105/12210515.jpg?type=m1&udate=20191010",
# "author": "나카이 에츠지",
# "price": "24000",
# "discount": "21600",
# "publisher": "제이펍",
# "pubdate": "20170712",
# "isbn": "1185890874 9791185890876",
# "description": "텐서플로를 이용하여 ‘합성곱 신경망(CNN)’의 구조를 완벽히 이해한다!이 책은 머신러닝과 데이터 분석을 제대로 배운 적이 없는 개발자를 대상으로 한다. 딥러닝의 대표적 예인 ‘합성곱 신경망(CNN)’의 구조를 근본부터 이해하고, 텐서플로를 이용해 실제로 동작하는 코드를 작성하는 것이 이 책의 목표다.... "
#
# },
# {
# "title": "Make: 아두이노 DIY 프로젝트",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=7399475",
# "image": "https://bookthumb-phinf.pstatic.net/cover/073/994/07399475.jpg?type=m1&udate=20161123",
# "author": "키모 카르비넨|테로 카르비넨",
# "price": "25000",
# "discount": "22500",
# "publisher": "한빛미디어",
# "pubdate": "20140106",
# "isbn": "8968480737 9788968480737",
# "description": "치한 퇴치기, 곤충 로봇, 축구 로봇 등 아두이노로 실전 프로젝트를 만들어보자!오픈소스 하드웨어와 소프트웨어를 이용한 여섯 가지 봇 & 가제 『MAKE: 아두이노 DIY 프로젝트』. 아두이노로 프로토타입을 제작하는 방법을 알려주는 것에 궁극적인 목표로 둔 책이다. 취미공학자와 아두이노 입문자들을... "
#
# },
# {
# "title": "지능의 본질과 구현 (지능의 본질과 구현 가능성을 찾아가는 위대한 여정)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=13608460",
# "image": "https://bookthumb-phinf.pstatic.net/cover/136/084/13608460.jpg?type=m1&udate=20191010",
# "author": "이재현",
# "price": "30000",
# "discount": "27000",
# "publisher": "로드북",
# "pubdate": "20180524",
# "isbn": "8997924397 9788997924394",
# "description": "책의 내용은 지능 연구와 관련 없는 일반 교양인들도 쉽게 읽을 수 있도록 꾸미는 것을 목적으로 하였지만, 중간중간 다소 어려울 수 있다. 인문학과 과학, 수학과 프로그래밍이 엉켜있기 때문이기도 하다. 지능의 본질을 향한 저자의 질문은 날카롭고 진지하며, 이를 기반으로 한 지능의 알고리즘적 구현에서는... "
#
# },
# {
# "title": "데이터 분석을 떠받치는 수학 (엑셀과 수학, 통계로 배우는 데이터 과학의 기술)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16033123",
# "image": "https://bookthumb-phinf.pstatic.net/cover/160/331/16033123.jpg?type=m1&udate=20201202",
# "author": "손민규",
# "price": "27000",
# "discount": "24300",
# "publisher": "위키북스",
# "pubdate": "20200103",
# "isbn": "1158391846 9791158391843",
# "description": "엑셀은 데이터 관리 및 분석에 특화된 최고의 도구로 R이나 <b>파이썬</b> 같이 설치가 필요한 데이터 분석 프로그램과 달리 대부분의 컴퓨터에 기본으로 설치돼 있어 간편하게 사용할 수 있다.\n\n실습 예제로는 데이터 분석 입문할 때 가장 많이 사용되는 보스턴 주택 가격 데이터를 이용한 다중 선형 회귀 분석과 주성분... "
#
# },
# {
# "title": "코딩맨 엔트리 10 (최후의 결전)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=15970903",
# "image": "https://bookthumb-phinf.pstatic.net/cover/159/709/15970903.jpg?type=m1&udate=20191216",
# "author": "이준범",
# "price": "12000",
# "discount": "10800",
# "publisher": "다산어린이",
# "pubdate": "20191223",
# "isbn": "115639824X 9791156398240",
# "description": "4차 산업 혁명 시대, 코딩 교육은 선택이 아닌 필수!\n\n4차 산업 혁명 시대 오늘날, 정보 통신 기술과 인공 지능, 로봇, 빅 데이터 등의 기술이 융합되며 신기술과 산업이 개발되고 있습니다. 이에 맞는 인재 양성을 위해 많은 나라에서 코딩 교육을 시작하였습니다. 코딩 교육은 창의적인 아이디어를 키우고... "
#
# },
# {
# "title": "코딩맨 엔트리 1~10권 세트",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21347454",
# "image": "https://bookthumb-phinf.pstatic.net/cover/213/474/21347454.jpg?type=m1&udate=20211215",
# "author": "송아론|k프로덕션|이준범",
# "price": "96000",
# "discount": "86400",
# "publisher": "다산북스",
# "pubdate": "20191223",
# "isbn": "1130677915 9791130677910",
# "description": "·중·고 코딩 교육 의무화!4차 산업 혁명 시대, 코딩 교육은 선택이 아닌 필수!코딩 교육은 2019년부터 초등학교 실과 과목에 17시간이 포함되었고, 중학교는 34시간의 필수 과정, 고등학교는 선택 이수로 교육하고 있습니다. 코딩 교육의 궁극적인 목적은 원인과 결과가 분명한 문제를 분석해 자료를 구조화하면서... "
#
# },
# {
# "title": "PyGame 어드벤쳐 : 위니브 월드를 수복하라!",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17718135",
# "image": "https://bookthumb-phinf.pstatic.net/cover/177/181/17718135.jpg?type=m1&udate=20201229",
# "author": "이호준",
# "price": "0",
# "discount": "",
# "publisher": "사도출판",
# "pubdate": "20201231",
# "isbn": "1188786415 9791188786411",
# "description": "Python의 가장 큰 장점을 꼽을 한다면 확장성과 방대한 커뮤니티라고 할 수 있을 것입니다. \nPygame은 여러분들에게 보다 쉽게 게임을 만들어 볼 수 있는 경험을 제공할 것입니다. 조금 복잡한 게임을 만들다 보면 여러분도 어느새 문법에 좀 더 친숙해지실 수 있을 것이라 생각합니다.\nPython으로... "
#
# },
# {
# "title": "코딩시대 (코드, 미래를 지배하는 언어)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=11956998",
# "image": "https://bookthumb-phinf.pstatic.net/cover/119/569/11956998.jpg?type=m1&udate=20170518",
# "author": "바트|장재용",
# "price": "22000",
# "discount": "19800",
# "publisher": "클라우드북스",
# "pubdate": "20170411",
# "isbn": "8997793217 9788997793211",
# "description": "4차 산업혁명 시대에 코딩은 왜 중요한가. \n\n4차산업은 IT 정보기술이 모든 일상영역에 파고드는 것이다. 3차 산업혁명의 IT 기술이 일부 사람들의 전유물이었다고 한다면, 이제는 깊이 몰라도 일상에서 일반인들도 쉽게 응용하고 적용할 수 있을 정도로 IT 기술은 접근가능하다. 왜 전 세계적으로 코딩열풍이... "
#
# },
# {
# "title": "딥러닝 모델 설계를 떠받치는 기술 (딥러닝이 안 풀릴 때 보는 케라스 해법 정리서)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14457019",
# "image": "https://bookthumb-phinf.pstatic.net/cover/144/570/14457019.jpg?type=m1&udate=20191010",
# "author": "마이크 베르니코",
# "price": "25000",
# "discount": "22500",
# "publisher": "위키북스",
# "pubdate": "20190122",
# "isbn": "1158391323 9791158391324",
# "description": "이러한 구현에 필요하고 인기도 있는, <b>파이썬</b> 기반 딥러닝 프레임워크인 케라스와 텐서플로도 살펴본다. 각 장에서 딥러닝 신경망을 배우는 동안 여러분이 올바른 결정을 내리는 데 도움이 될 모범 사례와 안전한 선택지도 알 수 있다. \n이 책의 내용을 배우고 나면 현업 문제를 딥러닝 신경망을 사용해... "
#
# },
# {
# "title": "차근차근 딥 러닝 코딩 실습",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17664425",
# "image": "https://bookthumb-phinf.pstatic.net/cover/176/644/17664425.jpg?type=m1&udate=20201218",
# "author": "조민수",
# "price": "15000",
# "discount": "",
# "publisher": "좋은땅",
# "pubdate": "20201218",
# "isbn": "1166490041 9791166490040",
# "description": "딥 러닝은 2006년에 토론토 대학의 제프리 힌톤 박사가 고안했다. 딥 러닝이 세상에 알려진 것은 2012년에 구글이 “대규모 비지도 학습 이미지 데이터를 기반으로 기계가 고양이를 자동으로 인식할 수 있다”라고 발표하면서부터이다. 딥 러닝이 사회적으로 널리 알려진 것은 2016년에 구글의 알파고가... "
#
# },
# {
# "title": "누구나 쓱 읽고 싹 이해하는 IT 핵심 기술",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=13549858",
# "image": "https://bookthumb-phinf.pstatic.net/cover/135/498/13549858.jpg?type=m1&udate=20180421",
# "author": "Dave Lee",
# "price": "16000",
# "discount": "14400",
# "publisher": "영진닷컴",
# "pubdate": "20180511",
# "isbn": "8931457170 9788931457179",
# "description": "이 책은 IT를 처음 시작하는 사람을 위해 IT의 기초 지식부터 웹, <b>파이썬</b>, 데이터베이스, 머신러닝과 같은 핵심 기술, IT 분야의 업무환경과 개발자와의... <b>파이썬</b>의 기본 문법을 설명하고 <b>파이썬</b> 라이브러리를 활용하여 엑셀 보고서 자동으로 작성하기와 같은 실용적인 예제를 통해 <b>파이썬</b> 핵심 기술을... "
#
# },
# {
# "title": "Python Machine Learning By Example (예제로 배우는 머신 러닝 알고리즘)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=13976189",
# "image": "https://bookthumb-phinf.pstatic.net/cover/139/761/13976189.jpg?type=m1&udate=20201216",
# "author": "요우시 리우",
# "price": "25000",
# "discount": "22500",
# "publisher": "에이콘출판",
# "pubdate": "20180907",
# "isbn": "116175203X 9791161752037",
# "description": "▶ <b>파이썬</b> 머신 러닝에 관한 내용을 담은 전문서적입니다."
#
# },
# {
# "title": "엔진엑스로 운용하는 효율적인 웹사이트 (웹개발자와 시스템관리자를 위한 105가지 실전 예제)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=7161502",
# "image": "https://bookthumb-phinf.pstatic.net/cover/071/615/07161502.jpg?type=m1&udate=20210509",
# "author": "디판카 사카",
# "price": "25000",
# "discount": "22500",
# "publisher": "에이콘출판",
# "pubdate": "20130322",
# "isbn": "8960774081 9788960774087",
# "description": "강력한 웹서버 엔진엑스(NGINX)의 105가지 실전 예제!아파치를 대체하고 있는 강력한 웹서버 엔진엑스(NGINX)의 실제 활용 사례가 수록된 예제 모음집 『엔진엑스로 운용하는 효율적인 웹사이트』. 웹사이트 관리자나 개발자들이 흔히 겪는 대표적인 105가지 상황에 대한 검증된 솔루션을 이해하기 쉽도록... "
#
# },
# {
# "title": "Raspberry Pi를 활용한 IoT 제어",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=15621356",
# "image": "https://bookthumb-phinf.pstatic.net/cover/156/213/15621356.jpg?type=m1&udate=20191023",
# "author": "류기주|최영화",
# "price": "25000",
# "discount": "23500",
# "publisher": "사이버북스",
# "pubdate": "20190927",
# "isbn": "1186708557 9791186708552",
# "description": "3장에서는 리눅스명령어와 파일시스템을 다루고, 4장은 C언어와 <b>파이썬</b>언어를 그리고 5장에서는 센서 신호를 입력받기위한 포토제어를 학습한다. 6장은 무선통신을 위한 블루투스통신이고, 7장은 라즈베리파이와 아두이노의 통신, 그리고 8장은 원격제어를 위한 텔레그램을 학습한다.  9장부터 10장... "
#
# },
# {
# "title": "메이커를 위한 라즈베리 파이 (동작 원리와 물리 법칙으로 제대로 배우는 GPIO, 센서, 모터, 통신, 디스플레이 고급 프로그래밍, Making Insight)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=12254065",
# "image": "https://bookthumb-phinf.pstatic.net/cover/122/540/12254065.jpg?type=m1&udate=20171107",
# "author": "이승현",
# "price": "32000",
# "discount": "28800",
# "publisher": "인사이트",
# "pubdate": "20170719",
# "isbn": "8966264018 9788966264018",
# "description": "독자는 이 책을 통해 라즈베리 파이와 주변 장치(모터, 센서, 디스플레이 등)들이 어떻게 신호를 주고 받고 작동하는지 그 밑단의 물리 법칙부터 동작 원리, <b>파이썬</b> 언어를 기반으로 한 프로그램을 만드는 방법까지 배울 수 있다. 특히 책 곳곳에서는 부품의 규격 및 작동 방법을 상세히 설명한 데이터시트를... "
#
# },
# {
# "title": "마이크로비트 활용 (블록 프로그래밍과 전자 공작,스마트하고 귀여운)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=15001987",
# "image": "https://bookthumb-phinf.pstatic.net/cover/150/019/15001987.jpg?type=m1&udate=20190626",
# "author": "이시이 모루나|에사키 노리히데",
# "price": "17000",
# "discount": "16660",
# "publisher": "광문각",
# "pubdate": "20190530",
# "isbn": "8970939296 9788970939292",
# "description": "프로그래밍 언어는 C 언어부터 <b>파이썬</b>까지 여러 가지(당연히 스크래치도 포함). PC에 버금가는 스펙. PC + 자유자재로 사용 가능한 단자도 붙어 있어 만능으로 사용 가능.\n\n위의 두 가지와 비교하였을 때 라즈베리 파이만큼 고성능은 아니지만, 아두이노보다는 친근하다고 할 정도로 좋은 균형을... "
#
# },
# {
# "title": "Car Hacker's Handbook (자동차 보안 위협과 해킹 기술의 모든 것)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=11629640",
# "image": "https://bookthumb-phinf.pstatic.net/cover/116/296/11629640.jpg?type=m1&udate=20170218",
# "author": "크레이그 스미스",
# "price": "35000",
# "discount": "31500",
# "publisher": "에이콘출판",
# "pubdate": "20170217",
# "isbn": "896077927X 9788960779273",
# "description": "최근 자동차 분야의 기술 발전은 놀라울 정도로 빠르게 변화하고 있다. 그 배경에는 IT 기술과 자동차의 결합이 가장 중요한 역할을 하고 있다는 것은 이미 많은 사람이 인지하고 있다. 하지만 그 이면에는 IT 분야에 존재하고 있던 많은 보안 위협이 자동차 분야로 전이됐고, 이에 대한 심각성이 인지되기 시작한... "
#
# },
# {
# "title": "딥러닝 입문",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16311454",
# "image": "https://bookthumb-phinf.pstatic.net/cover/163/114/16311454.jpg?type=m1&udate=20200326",
# "author": "Eugene Charniak",
# "price": "20000",
# "discount": "19600",
# "publisher": "한티미디어",
# "pubdate": "20200310",
# "isbn": "8964214005 9788964214008",
# "description": "이 책의 저자는 구체적인 예제를 들어서 모든 것을 설명한다. 이 책은 딥러닝의 전형적인 경로를 따르지 않는다. 처음부터 MNIST의 손글씨 예제를 사용하고 있다. 또한 완전하지는 않지만 <b>파이썬</b> 코드를 제공하고 있다. <b>파이썬</b>을 수행하여 나온 실행 결과를 정성적으로 설명하는 것도 인상적이다."
#
# },
# {
# "title": "Redis와 Node.js를 사용한 웹 애플리케이션 개발 (클라우드 시대 웹 서비스의 확장성을 높이는)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=9193588",
# "image": "https://bookthumb-phinf.pstatic.net/cover/091/935/09193588.jpg?type=m1&udate=20170915",
# "author": "조슈아 조하난",
# "price": "33000",
# "discount": "29700",
# "publisher": "에이콘출판",
# "pubdate": "20150630",
# "isbn": "8960777293 9788960777293",
# "description": "이 책에서는 최근 많은 주목을 받고 있는 NODE.JS와 레디스(REDIS)를 사용해 실제 웹 애플리케이션을 개발하기 위한 노하우를 전수하고 있다. 성공적인 웹 서비스를 개발하고 운영하기 위해 필수적인 운영 시스템의 확장성을 보장하기 위한 방법을 최신의 프레임워크인 NODE.JS를 사용해 웹 애플리케이션을... "
#
# },
# {
# "title": "캐글 데이터로 보는 데이터분석 With Python & SAS",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17550719",
# "image": "https://bookthumb-phinf.pstatic.net/cover/175/507/17550719.jpg?type=m1&udate=20201203",
# "author": "이호준",
# "price": "0",
# "discount": "",
# "publisher": "사도출판",
# "pubdate": "20201030",
# "isbn": "1188786393 9791188786398",
# "description": "데이터 분석, 어떻게 공부해야 할까요? 기초부터 탄탄히 공부해야 할까요? 언제 실전처럼 분석을 할 수 있을까요? 이런 물음에서 이 책은 출발하였습니다. 우선, 데이터 분석에서 가장 유명하고, 실전처럼 훈련할 수 있는 데이터를 가져와 Python과 SAS로 분석을 해보도록 하겠습니다.\n그리고 좀 더 알고 싶은... "
#
# },
# {
# "title": "라즈베리 파이, 상상을 현실로 만드는 프로젝트 입문편 + 라즈베리 파이 키트 세트",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14254168",
# "image": "https://bookthumb-phinf.pstatic.net/cover/142/541/14254168.jpg?type=m1&udate=20190129",
# "author": "이준혁",
# "price": "105000",
# "discount": "",
# "publisher": "영진닷컴",
# "pubdate": "20181115",
# "isbn": "8931459610 9788931459616",
# "description": "기본적인 라즈베리 파이에 대한 소개와 운영체제인 라즈비안에 대해 설명하고 라즈베리 파이를 사용할 때 알아두면 편리한 <b>파이썬</b>에 대해 간단하게 소개합니다. 또한, 라즈비안에 있는 스크래치나 마인크래프트를 제어해보고, 파이 카메라나 MICRO:BIT, RETROPIE 등 여러 장치를 연결하여 제어할 수 있습니다.\n\n이... "
#
# },
# {
# "title": "오픈 소스 소프트웨어 아키텍처 (25개 애플리케이션으로 배우는)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=9011514",
# "image": "https://bookthumb-phinf.pstatic.net/cover/090/115/09011514.jpg?type=m1&udate=20190204",
# "author": "에이미 브라운|그레그 윌슨",
# "price": "36000",
# "discount": "32400",
# "publisher": "인사이트",
# "pubdate": "20150511",
# "isbn": "8966261264 9788966261260",
# "description": "[25개 애플리케이션으로 배우는 오픈 소스 소프트웨어 아키텍처]는 오픈 소스 소프트웨어의 아키텍처를 설명하고, 전체 구성은 어떻고, 각 하부 구조는 어떻게 상호동작하며, 왜 그런 방식으로 구축하게 되었으며, 다른 대규모 설계 문제에 적용될 수 있는 교훈은 어떤 것들이 있었는지 다룬다."
#
# },
# {
# "title": "자바스크립트 JSON 쿡북 (데스크탑, 서버, 웹, 모바일 애플리케이션에서 활용하는 80가지 레시피,acorn+PACKT 시리즈)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=11637588",
# "image": "https://bookthumb-phinf.pstatic.net/cover/116/375/11637588.jpg?type=m1&udate=20171003",
# "author": "레이 리쉬패터",
# "price": "20000",
# "discount": "18000",
# "publisher": "에이콘출판",
# "pubdate": "20170224",
# "isbn": "8960779695 9788960779693",
# "description": "JSON(JAVASCRIPT OBJECT NOTATION)은 인터넷을 통해 전송하는 데이터 객체를 생성하는 텍스트 기반의 가벼운 데이터 교환 포맷이다. 현재 JSON은 모바일 애플리케이션뿐만 아니라 일반적인 웹 애플리케이션에서도 널리 사용되고 있다. 이 책 [자바스크립트 JSON 쿡북]은 JSON의 일반적인 사용법에 대한 예제... "
#
# },
# {
# "title": "사물인터넷 자바스크립트 프로그래밍",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=13572690",
# "image": "https://bookthumb-phinf.pstatic.net/cover/135/726/13572690.jpg?type=m1&udate=20191010",
# "author": "루벤 올리바 라모스",
# "price": "28000",
# "discount": "25200",
# "publisher": "에이콘출판",
# "pubdate": "20180516",
# "isbn": "1161751556 9791161751559",
# "description": "사물인터넷(IOT)은 웹 개발자와 엔지니어에게 완전히 새로운 플랫폼이지만, 이 새로운 세계에서도 프로그래밍 언어는 일관성을 유지한다.\n자바스크립트는 인터넷에서 가장 널리 사용되는 언어며, IOT가 탄력을 얻으면서 연결된 장치와 상호작용하는데 자바스크립트의 힘을 활용하는 방법을 배워야할 필요가... "
#
# },
# {
# "title": "화이트 해커를 위한 암호와 해킹 (White Hat Python)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=10772872",
# "image": "https://bookthumb-phinf.pstatic.net/cover/107/728/10772872.jpg?type=m1&udate=20211007",
# "author": "장삼용",
# "price": "22000",
# "discount": "",
# "publisher": "정보문화사",
# "pubdate": "20160715",
# "isbn": "8956746974 9788956746975",
# "description": "책에서 구현한 주요 프로그램은 스크립트 언어인 ‘<b>파이썬</b>’을 이용했다. <b>파이썬</b>은 프로그래밍이 직관적이고 배우기 쉽다. <b>파이썬</b>은 스크립트 언어임에도 불구하고 C나 C++로 작성할 수 있는 대부분의 프로그램을 작성할 수 있으며, 동일한 목적의 프로그램을 C나 C++로 작성할 때와 비교하면 절반도 되지 않는... "
#
# },
# {
# "title": "라즈베리 파이와 슈퍼컴퓨팅 (병렬처리 시스템 구축 및 과학 프로그래밍 가이드북)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14030828",
# "image": "https://bookthumb-phinf.pstatic.net/cover/140/308/14030828.jpg?type=m1&udate=20180920",
# "author": "애쉬윈 파얀카",
# "price": "25000",
# "discount": "22500",
# "publisher": "에이콘출판",
# "pubdate": "20180928",
# "isbn": "1161752099 9791161752099",
# "description": "또한 <b>파이썬</b>을 활용한 수치 연산을 위해 NUMPY 라이브러리, 과학 연산 라이브러리인 SCIPY와 신호 처리 및 영상 처리에서 SCIPY의 애플리케이션을 살펴본다. 마지막으로 이미지 데이터를 표현하는 방법과 MATPLOLIB 라이브러리로 히스토그램을 계산하는 방법을 다룬다.\n\n이 책은 과학 연산의 놀라운... "
#
# },
# {
# "title": "Embedded Linux Projects Using Yocto Project Cookbook (임베디드 리눅스 전문가들의 Yocto 노하우 70가지 레시피)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=11323550",
# "image": "https://bookthumb-phinf.pstatic.net/cover/113/235/11323550.jpg?type=m1&udate=20161203",
# "author": "알렉스 곤잘레스",
# "price": "35000",
# "discount": "31500",
# "publisher": "에이콘출판",
# "pubdate": "20161130",
# "isbn": "8960779385 9788960779389",
# "description": "[EMBEDDED LINUX PROJECTS USING YOCTO PROJECT COOKBOOK]은 임베디드 리눅스 개발을 위한 YOCTO 프로젝트의 사용법과 노하우를 제시한다. YOCTO 빌드 시스템의 기본 개념을 다루며 임베디드 리눅스 개발자들이 쉽게 따라 할 수 있는 다수의 예제를 통해 프리스케일 완드보드를 이용한 BSP, 소프트웨어... "
#
# },
# {
# "title": "Python으로 시작하는 빅데이터 분석 및 인공지능",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=15407061",
# "image": "https://bookthumb-phinf.pstatic.net/cover/154/070/15407061.jpg?type=m1&udate=20200402",
# "author": "조준모",
# "price": "24000",
# "discount": "",
# "publisher": "인피니티북스",
# "pubdate": "20190830",
# "isbn": "1185578463 9791185578460",
# "description": "빅데이터 분석과 인공지능에 대한 완벽한 안내서!이 책은 <b>파이썬</b>의 기초를 익히고 빅데이터 분석과 인공지능의 기초지식을 확립하기 위해... 이를 위해 현재 각광을 받고 있는 구글의 주피터 노트북(JUPYTER NOTEBOOK)환경에서 넘파이(NUMPY)와 판다스(PANDAS)를 사용할 수 있는 <b>파이썬</b>(PYTHON)을 실습을 통해... "
#
# },
# {
# "title": "실전 예제로 살펴보는 PyQt Tutorial",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16779613",
# "image": "https://bookthumb-phinf.pstatic.net/cover/167/796/16779613.jpg?type=m1&udate=20200930",
# "author": "이호준",
# "price": "0",
# "discount": "",
# "publisher": "사도출판",
# "pubdate": "20200929",
# "isbn": "1188786350 9791188786350",
# "description": "C 계열에 있는 Qt를 <b>파이썬</b> 모듈로 변환해 주는 프로젝트에서 시작되었으며, <b>파이썬</b>에 간결함을 입어 쉽게 GUI프로그램을 만들 수 있습니다.\n또한, PyQt의 가장 큰 장점 중 하나는 Qt Designer를 사용하여 GUI 프로그램을 GUI를 사용하여 프로그래밍 할 수 있다는 것에 있습니다.\n하지만 쉽다고 해서... "
#
# },
# {
# "title": "머신러닝 이론 입문 (IT 엔지니어를 위한)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=10680481",
# "image": "https://bookthumb-phinf.pstatic.net/cover/106/804/10680481.jpg?type=m1&udate=20170726",
# "author": "나카이 에츠지",
# "price": "25000",
# "discount": "22500",
# "publisher": "위키북스",
# "pubdate": "20160617",
# "isbn": "1158390335 9791158390334",
# "description": "알고리즘의 이해를 위해 이 책에서는 머신러닝 이론을 수학적인 배경부터 하나씩 차근차근 설명합니다. 또 <b>파이썬</b>으로 샘플 프로그램을 실행해 볼 수 있도록 하였으며, 그 결과를 보는 것으로 머신러닝을 지탱하는 이론을 실감할 수 있도록 구성돼 있습니다."
#
# },
# {
# "title": "스마트 IoT 프로젝트 (스마트 온도 조절기, 머신 비전, 자율 주행 자동차 로봇 포함 다양한 사물 인터넷 구현)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=12059462",
# "image": "https://bookthumb-phinf.pstatic.net/cover/120/594/12059462.jpg?type=m1&udate=20211124",
# "author": "아구스 쿠니아완",
# "price": "25000",
# "discount": "22500",
# "publisher": "에이콘출판",
# "pubdate": "20170531",
# "isbn": "896077796X 9788960777965",
# "description": "『스마트 IOT 프로젝트』는 IOT와 지능 시스템을 결합해 실생활의 문제를 해결하는 데 꼭 필요한 참고 서적이다. 물리 장치에 의사 결정 시스템을 더욱 쉽게 구현할 수 있도록, 기본 통계 지식과 데이터 과학 및 기계 학습에 관련된 여러 가지 응용 알고리즘을 소개한다. 이 책에서는 스마트 온도 조절기, 머신... "
#
# },
# {
# "title": "더 강해지다 Active Defense (실습으로 미리 준비하는 보안 프레임워크)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=15516726",
# "image": "https://bookthumb-phinf.pstatic.net/cover/155/167/15516726.jpg?type=m1&udate=20210509",
# "author": "한주성|최도현|김진경|박제현",
# "price": "21000",
# "discount": "18900",
# "publisher": "비제이퍼블릭",
# "pubdate": "20191011",
# "isbn": "1190014505 9791190014502",
# "description": "주요 내용을 활용하고 확인할 수 있는 도구로는 <b>파이썬</b>을 주로 사용한다. 실습에 필요한 프로그램 설치 과정에서부터 실전에도 적용할 수 있는 실습 예제도 수록했다. 이를 바탕으로 여러 종류의 실습을 통해 Active Defense의 개념과 기술을 쉽게 이해할 수 있게 작성했다.&#x0D;"
#
# },
# {
# "title": "머신 러닝 워크북 (자바로 실습하고 이해한다)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=10524020",
# "image": "https://bookthumb-phinf.pstatic.net/cover/105/240/10524020.jpg?type=m1&udate=20211214",
# "author": "제이슨 벨",
# "price": "35000",
# "discount": "31500",
# "publisher": "길벗",
# "pubdate": "20160430",
# "isbn": "1187345008 9791187345008",
# "description": "머신 러닝, 자바와 다양한 도구로 실습하면서 이해한다!\n\n자바와 다양한 도구로 실습해보면서 머신 러닝의 개념과 도구 사용법을 배운다. 머신 러닝의 정의, 머신 러닝을 계획하는 방법부터 시작하여 의사결정트리, 베이지안 네트워크, 인공 신경망, 연관 규칙 학습, 서포트 벡터 머신, 클러스터링이 무엇이고... "
#
# },
# {
# "title": "GitHub를 활용한 다양한 도구 개발 (개발 워크플로 최적화)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14102605",
# "image": "https://bookthumb-phinf.pstatic.net/cover/141/026/14102605.jpg?type=m1&udate=20181115",
# "author": "크리스 도슨|벤 스트라우브",
# "price": "30000",
# "discount": "27000",
# "publisher": "에이콘출판",
# "pubdate": "20181029",
# "isbn": "1161752277 9791161752273",
# "description": "GITHUB의 활용에 대한 가이드로 소프트웨어 도구를 개발하기 위해 GITHUB 워크플로우를 최적화하는 방법을 보여준다. 각 장에 있는 실습 내용은 다양한 GITHUB를 활용해 애플리케이션을 개발하는 데 도움이 되는 사항을 다루고 있다. GITHUB에 익숙한 숙련된 프로그래머라면 GITHUB API의 활용... "
#
# },
# {
# "title": "데이터 과학자가 되는 핵심 기술 (데이터 분석에 필요한 수학, 통계, 프로그래밍의 기본)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=12835440",
# "image": "https://bookthumb-phinf.pstatic.net/cover/128/354/12835440.jpg?type=m1&udate=20190108",
# "author": "시난 오즈데미르",
# "price": "30000",
# "discount": "27000",
# "publisher": "에이콘출판",
# "pubdate": "20171211",
# "isbn": "1161750762 9791161750767",
# "description": "원리를 알면 수식을 무작정 외울 필요가 없다는 것을 이제야 깨닫게 될 것이다. 더불어 데이터 과학에서 통계, 수학, R과 <b>파이썬</b> 같은 프로그래밍 지식이 왜 필요한지 확실히 알게 된다. 데이터의 수집부터 필요한 정보만 정제하고, 유형을 살펴서 분석하고, 결과의 해석까지 필요한 원리를 복합적으로 다룬다."
#
# },
# {
# "title": "이것이 우리에게 딱 맞는 딥러닝 with 텐서플로 (알짜배기 예제로 배우는 텐서플로와 딥러닝의 모든 것)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=13740164",
# "image": "https://bookthumb-phinf.pstatic.net/cover/137/401/13740164.jpg?type=m1&udate=20210509",
# "author": "박재용",
# "price": "24000",
# "discount": "21600",
# "publisher": "비제이퍼블릭",
# "pubdate": "20180629",
# "isbn": "1186697652 9791186697658",
# "description": "<b>파이썬</b>을 기반으로 구글에서 공개한 텐서플로를 사용하며, 실행환경은 고성능 GPU가 탑재된 컴퓨터가 아니어도 괜찮습니다. “인공지능?... - <b>파이썬</b> 코딩 경험이 있으면서 머신러닝 구현에 대해 좀 더 알고 싶은 독자&#x0D;- <b>파이썬</b>은 모르지만 프로그래밍에 관심이 있고 머신러닝도 알고 싶은... "
#
# },
# {
# "title": "CUCKOO SANDBOX (쿡쿠 샌드박스 구축과 확장+운영 팁)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=13920534",
# "image": "https://bookthumb-phinf.pstatic.net/cover/139/205/13920534.jpg?type=m1&udate=20200821",
# "author": "최우석",
# "price": "35000",
# "discount": "31500",
# "publisher": "에이콘출판",
# "pubdate": "20180829",
# "isbn": "1161751955 9791161751955",
# "description": "쿡쿠 샌드박스는 오픈소스로 제작된 악성코드 자동 분석 시스템으로 끊임 없이 새로운 기능을 도입하고 새로운 악성코드 분석의 트렌드를 선호한다. 많은 기업과 연구가들이 쿡쿠 샌드박스를 구축하고 추가 개발을 통해 확장하는 흐름을 가진다. 이 책은 쿡쿠 샌드박스를 구축하고, 이 도구에서 지원하는 다양한... "
#
# },
# {
# "title": "MySQL 데이터베이스와 클라우드",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=15872426",
# "image": "https://bookthumb-phinf.pstatic.net/cover/158/724/15872426.jpg?type=m1&udate=20200707",
# "author": "김경신",
# "price": "21000",
# "discount": "",
# "publisher": "복두출판사",
# "pubdate": "20191126",
# "isbn": "1159066019 9791159066016",
# "description": "▶ 이 책은 MySQL 데이터베이스와 클라우드를 다룬 이론서입니다. MySQL 데이터베이스와 클라우드의 기초적이고 전반적인 내용을 학습할 수 있습니다."
#
# },
# {
# "title": "사물인터넷을 위한  라즈베리파이 3 활용",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14653172",
# "image": "https://bookthumb-phinf.pstatic.net/cover/146/531/14653172.jpg?type=m1&udate=20191202",
# "author": "정원석",
# "price": "25000",
# "discount": "24500",
# "publisher": "광문각",
# "pubdate": "20180228",
# "isbn": "8970938907 9788970938905",
# "description": "▶ 이 책은 라즈베리파이 3 활용을 다룬 이론서입니다."
#
# },
# {
# "title": "Qt5 프로그래밍 가이드 (예제 중심의 애플리케이션 개발을 위한)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=7658516",
# "image": "https://bookthumb-phinf.pstatic.net/cover/076/585/07658516.jpg?type=m1&udate=20190204",
# "author": "김대진",
# "price": "28000",
# "discount": "",
# "publisher": "성안당",
# "pubdate": "20140529",
# "isbn": "8931553196 9788931553192",
# "description": "Qt는 C++ 이외에 <b>파이썬</b>, 루비, 펄 등 다양한 언어를 지원하며 전 세계 약 40만 명 이상 Qt 개발자가 다양한 컴퓨팅 환경에서 수많은 소프트웨어를 개발하고 있다. 따라서 일반 사용자 애플리케이션, 멀티미디어, 시스템 관리를 Back-end, 자동차, 국방, 가전, 모바일에 이르기까지 다양한 분야에서 Qt를... "
#
# },
# {
# "title": "시작해요, 코딩 4 (앱과 게임 프로그래밍)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=13416226",
# "image": "https://bookthumb-phinf.pstatic.net/cover/134/162/13416226.jpg?type=m1&udate=20180324",
# "author": "헤더 라이언스",
# "price": "11000",
# "discount": "9900",
# "publisher": "시공주니어",
# "pubdate": "20180305",
# "isbn": "8952786521 9788952786524",
# "description": "스크래치, 엔트리, <b>파이썬</b>… 어떤 코딩 학습보다도\n선행해야 할 ‘코딩 개념 장착’을 위한 입문서!\n개념부터 똑똑하게, 액티비티로 재미있게\n코딩... [시작해요, 코딩] 시리즈는 ‘스크래치, 엔트리, <b>파이썬</b>, 자바 등 어떤 프로그래밍 언어로 코딩을 배우든, 무조건 이 책을 먼저 보고 시작하라!’는 콘셉트의... "
#
# },
# {
# "title": "HBase 인액션 (빅데이터를 위한 NoSQL 데이터베이스)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=7188930",
# "image": "https://bookthumb-phinf.pstatic.net/cover/071/889/07188930.jpg?type=m1&udate=20190204",
# "author": "닉 디미덕|아만딥 쿠라나",
# "price": "30000",
# "discount": "27000",
# "publisher": "비제이퍼블릭",
# "pubdate": "20130429",
# "isbn": "8994774386 9788994774381",
# "description": "이 책은 HBase를 기반으로 애플리케이션을 구축하고 실제 경에 애플리케이션을 실행하는 데 충분한 지식을 제공하는 것을 목표로 한다. HBase는 대량 데이터를 위한 고속의 랜덤 액세스용으로 설계된 NoSQL 저장 시스템이다. 일반적인 하드웨어에서 기동되며 수십억 개의 로우와 수백만 개의 컬럼으로... "
#
# },
# {
# "title": "[POD] 안드로이드 앱 개발로 배우는 자바 코딩 1 (자바 언어 기초)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14440225",
# "image": "https://bookthumb-phinf.pstatic.net/cover/144/402/14440225.jpg?type=m1&udate=20201127",
# "author": "정동근",
# "price": "11500",
# "discount": "11500",
# "publisher": "부크크(bookk)",
# "pubdate": "20181026",
# "isbn": "1127251015 9791127251017",
# "description": "스크래치나 <b>파이썬</b>은 배우기 쉽지만, 다른 언어를 배울때 어렵다는 단점이 있습니다. C계열 언어는 처음 배울때는 어렵지만, 익숙해진 이후에는 다른 언어를 쉽게 배울수 있습니다.# 스크래치는 쉽다는데 안드로이드 앱 개발은 어렵지 않을까요?저는 이 교재를 만들면서 앱개발 경험이 전혀 없는 초보자도... "
#
# },
# {
# "title": "Building Machine Learning Systems with Python (한국어판,Scikit-learn 라이브러리로 구현하는 기계 학습 시스템)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=9566723",
# "image": "https://bookthumb-phinf.pstatic.net/cover/095/667/09566723.jpg?type=m1&udate=20210509",
# "author": "루이스 페드로 코엘류|윌리 리커트",
# "price": "30000",
# "discount": "27000",
# "publisher": "에이콘출판",
# "pubdate": "20150918",
# "isbn": "8960777617 9788960777613",
# "description": "<b>파이썬</b>과 <b>파이썬</b> 생태계의 핵심인 NUMPY, SCIPY, SCIKIT-LEARN등 다양한 라이브러리를 활용하여 <b>파이썬</b> 언어를 좀 더 깊게 이해할 수 있다. 개정판은 초판과 달리, 간결하게 예제를 재정리했으며, 관련 설명도 보강했다. 초판에서 부족했던 라이브러리도 좀 더 풍부하게 소개한다."
#
# },
# {
# "title": "Python bootcamp - 얕은물",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16417123",
# "image": "https://bookthumb-phinf.pstatic.net/cover/164/171/16417123.jpg?type=m1&udate=20200720",
# "author": "이호준",
# "price": "0",
# "discount": "",
# "publisher": "사도출판",
# "pubdate": "20200706",
# "isbn": "1188786334 9791188786336",
# "description": "<b>파이썬</b> 기초 강의인 &lt;<b>파이썬</b> 부트캠프&gt;는 비전공자를 위한 '얕은물' 강의와, 전공자를 위한 '깊은 물' 강의로 이뤄져 있습니다.\n두 강의는 같은... '얕은물' 강의는 스토리를 활용하여 쉽고 재미있게 <b>파이썬</b>을 학습할 수 있으며, '깊은 물' 강의는 스토리 없이 단백한 핵심을 파고들 수 있도록 구성되어... "
#
# },
# {
# "title": "소프트웨어 테스트 자동화 (테스팅 전문가들의 생생한 사례연구 스토리로 익히는)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=7385239",
# "image": "https://bookthumb-phinf.pstatic.net/cover/073/852/07385239.jpg?type=m1&udate=20170222",
# "author": "도로시 그레이엄|마크 퓨스터",
# "price": "45000",
# "discount": "40500",
# "publisher": "에이콘출판",
# "pubdate": "20131223",
# "isbn": "8960775029 9788960775022",
# "description": "테스트 자동화는 절대로 한 번에 끝나지 않는다. 그렇기에 계속해서 내 손에 익숙한 툴과 방법을 찾아 연습과 적용을 거듭하고, 인내하면서 가꿔 나가야 한다. 이 책에는 여러 분야에서 다양한 서비스와 제품을 맡은 테스트 엔지니어들의 자동화 스토리가 고스란히 담겨 있다. 무엇보다도, 효과적인 자동화... "
#
# },
# {
# "title": "python으로 배우는 OpenCV 프로그래밍",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=13954210",
# "image": "https://bookthumb-phinf.pstatic.net/cover/139/542/13954210.jpg?type=m1&udate=20180828",
# "author": "김동근",
# "price": "26000",
# "discount": "",
# "publisher": "가메",
# "pubdate": "20180828",
# "isbn": "8980782993 9788980782994",
# "description": "PYTHON으로 OPENCV 프로그래밍을 구현하였습니다.- PYTHON, NUMPY, MATPLOTLIB, OPENCV. TENSORFLOW 사용- 영상 및 비디오 입출력, 그래픽, 이벤트 처리, OPENCV 기본연산- 임계값, 히스토그램 처리, 영상 필터링, 영상 분할- 특징 검출, 디스크립터, 매칭- 비디오에서 이동 물체 검출 및 물체 추적... "
#
# },
# {
# "title": "모바일 포렌식 (iOS, 안드로이드, 윈도우폰, 블랙베리 플랫폼 포렌식을 위한)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=9546892",
# "image": "https://bookthumb-phinf.pstatic.net/cover/095/468/09546892.jpg?type=m1&udate=20190204",
# "author": "사티시 봄미세티|로히트 타마|헤더 마하릭",
# "price": "33000",
# "discount": "29700",
# "publisher": "에이콘출판",
# "pubdate": "20150918",
# "isbn": "8960777587 9788960777583",
# "description": "이 책 [모바일 포렌식]은 IOS, 안드로이드, 윈도우, 블랙베리 플랫폼에서의 모바일 포렌식 기법에 대해 설명한다. 모바일 포렌식의 핵심적 요소와 기기에서 데이터를 추출하고 삭제된 데이터를 복구하고, 화면 잠금 메커니즘을 우회하는 방법과 포렌식 조사를 돕는 다양한 도구에 대해 다룬다."
#
# },
# {
# "title": "딥러닝 입문",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=15132445",
# "image": "https://bookthumb-phinf.pstatic.net/cover/151/324/15132445.jpg?type=m1&udate=20190806",
# "author": "Sandro Skansi",
# "price": "25000",
# "discount": "22500",
# "publisher": "휴먼싸이언스",
# "pubdate": "20190620",
# "isbn": "1189057123 9791189057121",
# "description": "▶ 이 책은 딥러닝을 다룬 이론서입니다."
#
# },
# {
# "title": "NUKE 101 (Professional compositing and visual effects)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=9414612",
# "image": "https://bookthumb-phinf.pstatic.net/cover/094/146/09414612.jpg?type=m1&udate=20160218",
# "author": "Ron Ganbar",
# "price": "36000",
# "discount": "",
# "publisher": "비엘북스",
# "pubdate": "20150910",
# "isbn": "1186573023 9791186573020",
# "description": "비주얼이펙트 아티스트를 위한 누크 입문서 [NUKE 101]. 전문 COMPOSITOR이자, 유명한 강사로 알려진 저자 RON GANBAR가 각 파트마다 NUKE의 중요한 합성 개념을 설명하고, 따라하기 방식의 튜토리얼로 구성해 초보자들도 쉽게 배울 수 있도록 했다. 합성의 작업흐름과 필요한 툴의... "
#
# },
# {
# "title": "시작해요, 코딩 3 (생활 속의 코딩)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=13416225",
# "image": "https://bookthumb-phinf.pstatic.net/cover/134/162/13416225.jpg?type=m1&udate=20180324",
# "author": "헤더 라이언스",
# "price": "11000",
# "discount": "9900",
# "publisher": "시공주니어",
# "pubdate": "20180305",
# "isbn": "8952786513 9788952786517",
# "description": "스크래치, 엔트리, <b>파이썬</b>… 어떤 코딩 학습보다도\n선행해야 할 ‘코딩 개념 장착’을 위한 입문서!\n개념부터 똑똑하게, 액티비티로 재미있게\n코딩... [시작해요, 코딩] 시리즈는 ‘스크래치, 엔트리, <b>파이썬</b>, 자바 등 어떤 프로그래밍 언어로 코딩을 배우든, 무조건 이 책을 먼저 보고 시작하라!’는 콘셉트의... "
#
# },
# {
# "title": "누구나 PYTHON 너도 데이터 가지고 놀 수 있어!",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16109062",
# "image": "https://bookthumb-phinf.pstatic.net/cover/161/090/16109062.jpg?type=m1&udate=20200107",
# "author": "민형기",
# "price": "14500",
# "discount": "",
# "publisher": "잇플ITPLE",
# "pubdate": "20200108",
# "isbn": "1190283719 9791190283717",
# "description": "tree 기법을 이용해서 아이리스 꽃 분류와 타이타닉 생존자 예측을 수행해 봅니다.\n이 책은 하나의 주제를 깊이 있게 다루는 것이 아니라 어쩌면 <b>파이썬</b>이 처음이거나 입문이신 분들을 대상으로 <b>파이썬</b>이 할 수 있는 재미있는 일들을 보여주어 동기를 부여하고 다양한 분야를 체험하는 것이 목표입니다."
#
# },
# {
# "title": "웹을 위한 머신 러닝 (머신 러닝을 활용한 영화 추천 및 감성 분석 웹 애플리케이션 개발)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=11784679",
# "image": "https://bookthumb-phinf.pstatic.net/cover/117/846/11784679.jpg?type=m1&udate=20191023",
# "author": "안드레아 아이소니",
# "price": "30000",
# "discount": "27000",
# "publisher": "에이콘출판",
# "pubdate": "20170322",
# "isbn": "8960779873 9788960779877",
# "description": "[웹을 위한 머신 러닝]은 머신 러닝과 함께 웹 마이닝, 자연어 처리 기법을 활용해 영화를 추천하고 영화 리뷰에 대한 감성을 분석하는 웹 애플리케이션을 직접 구현해볼 수 있도록 관련 이론과 예시를 실용적으로 제시한다. 실습을 통해 머신 러닝을 학습하고 이를 웹 애플리케이션에 적용하는 데 관심 있는... "
#
# },
# {
# "title": "누구나 할 수 있다. 비트코인 자동매매 (Larry Wiliams의 변동성 돌파 전략을 활용한)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14564794",
# "image": "https://bookthumb-phinf.pstatic.net/cover/145/647/14564794.jpg?type=m1&udate=20191226",
# "author": "유부장|조대표",
# "price": "20000",
# "discount": "",
# "publisher": "파이스탁",
# "pubdate": "20190218",
# "isbn": "1196608806 9791196608804",
# "description": "이 책은 최근 인기 있는 프로그래밍 언어인 <b>파이썬</b>을 사용하여 국내 3대 거래소(코빗, 빗썸, 업비트)... 프로그래밍 경험이 없는 일반인을 대상으로 <b>파이썬</b> 기초 문법부터 시작하여 24시간 실시간 자동... 있어 <b>파이썬</b>을 처음 배우는 분들이 유익하고 재미있게 프로그래밍을 배울 수 있도록 합니다. 책에서... "
#
# },
# {
# "title": "처음 시작하는 센서",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=8814363",
# "image": "https://bookthumb-phinf.pstatic.net/cover/088/143/08814363.jpg?type=m1&udate=20170114",
# "author": "키모 카르비넨|테로 카르비넨",
# "price": "13000",
# "discount": "11700",
# "publisher": "한빛미디어",
# "pubdate": "20150302",
# "isbn": "8968481695 9788968481697",
# "description": "《Make: 아두이노 DIY 프로젝트‘의 저자 키모 카르비넨과 테로 카르비넨이 소개하는 여러 프로젝트를 통해 다양한 센서의 간단한 사용법을 익히고, 이를 마이크로컨트롤러 보드에 적용해서 자신만의 장치를 만들어 볼 수 있다."
#
# },
# {
# "title": "내가 하는 사물인터넷 프로그래밍2 라즈베리 파이 파이 C++ 편",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=12470563",
# "image": "https://bookthumb-phinf.pstatic.net/cover/124/705/12470563.jpg?type=m1&udate=20211020",
# "author": "설상동|김혜숙",
# "price": "20000",
# "discount": "18000",
# "publisher": "지식과감성",
# "pubdate": "20170804",
# "isbn": "1159617724 9791159617720",
# "description": "I편 <b>파이썬</b>은 프로그램을 처음 접해보는 사람을 위한 안내서라면, II편 C++은 프로그램에 좀 더 관심이 있는 독자를 위한 안내서가 될 것입니다. 이를 통해 4차 산업혁명으로 모든 물체가 인터넷에 연결되고 있는 이때에, 특히 센서들이 여러 곳에 연결되어 다양한 정보를 수집하는 것이 무엇인지 실습을... "
#
# },
# {
# "title": "비전공자를 위한 R 입문서 (R로 만드는 워드 클라우드)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14152449",
# "image": "https://bookthumb-phinf.pstatic.net/cover/141/524/14152449.jpg?type=m1&udate=20181110",
# "author": "민서희",
# "price": "12000",
# "discount": "10800",
# "publisher": "행복한마음",
# "pubdate": "20181115",
# "isbn": "8991705421 9788991705425",
# "description": "서점에 가보면 <b>파이썬</b>(PYTHON)에 대한 책은 초등학생용도 몇 권이 나와있는데, R은 통계라고 생각해서 그런지 비전공 입문자들이 읽을 만한 책이 쉽게 눈에 띄지 않는다. \n\n이 책은 처음의 저자처럼 아무것도 모르는 사람을 대상으로 하였기 때문에, 많은 것을 다루지 않는다. 그저 소설처럼 부담 없이 26쪽부터... "
#
# },
# {
# "title": "나의 첫 아두이노 프로젝트",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=7152974",
# "image": "https://bookthumb-phinf.pstatic.net/cover/071/529/07152974.jpg?type=m1&udate=20190203",
# "author": "마이크 슈미트",
# "price": "18000",
# "discount": "16200",
# "publisher": "인사이트",
# "pubdate": "20130301",
# "isbn": "8966260675 9788966260676",
# "description": "기초부터 프로젝트까지, 아두이노와 친해지는 가장 빠른 방법!&#x0D;&#x0D;아두이노 기초에서 머무는 애벌레를 벗어나 나만의 프로젝트를 만드는 나비가 되기 위한 길로 안내한다. 전자공학 경험 없이도 이 책을 통해 기초를 다질 수 있으며, 유용하면서도 재미있는 예제들을 따라 하는 동안 직접 만들고 싶은... "
#
# },
# {
# "title": "지능형 웹 알고리즘",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=12724573",
# "image": "https://bookthumb-phinf.pstatic.net/cover/127/245/12724573.jpg?type=m1&udate=20171116",
# "author": "더글라스 매킬레이스|하라람보스 마르마니스|드미트리 바벤코",
# "price": "25000",
# "discount": "22500",
# "publisher": "위키북스",
# "pubdate": "20171110",
# "isbn": "1158390815 9791158390815",
# "description": "또한 머신러닝의 주요 개념을 <b>파이썬</b> 사이킷런(SCIKIT-LEARN)으로 작성된 코드 예제와 함께 설명하고, 웹에서 흘러 들어오는 데이터를 포착하고 저장하고 구조화하는 알고리즘을 안내한다. 나아가 추천 엔진을 탐구하고 통계적 알고리즘, 신경망, 딥러닝을 통해 분류에 대해 자세히 알아본다."
#
# },
# {
# "title": "Scikit-learn으로 머신 러닝 마스터 (지도 학습, 비지도 학습, 강화 학습-핵심 기법 이해와 활용)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=13616424",
# "image": "https://bookthumb-phinf.pstatic.net/cover/136/164/13616424.jpg?type=m1&udate=20201217",
# "author": "개빈 해클링",
# "price": "25000",
# "discount": "22500",
# "publisher": "에이콘출판",
# "pubdate": "20180530",
# "isbn": "1161751602 9791161751603",
# "description": "관해 <b>파이썬</b>의 SCIKIT-LEARN 패키지를 사용한 예제를 직접 수행해 볼 수 있다.\n특히 잘 정립되고 간결한... 또한 모든 예제를 <b>파이썬</b> SCIKIT-LEARN을 사용해 제공하기 때문에 코드를 직접 수행해 가면서 책을 읽을... 책을 읽을 때 머신 러닝의 기초 지식이나 <b>파이썬</b> 지식이 있으면 도움이 되겠지만 반드시 있어야만... "
#
# },
# {
# "title": "안드로이드 앱 개발로 배우는 자바 코딩 2 (자바 언어 기초 2)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14257793",
# "image": "https://bookthumb-phinf.pstatic.net/cover/142/577/14257793.jpg?type=m1&udate=20190204",
# "author": "정동근",
# "price": "11500",
# "discount": "11500",
# "publisher": "부크크(Bookk)",
# "pubdate": "20181121",
# "isbn": "1127251988 9791127251987",
# "description": "스크래치나 <b>파이썬</b>은 배우기 쉽지만, 다른 언어를 배울때 어렵다는 단점이 있습니다. C계열 언어는 처음 배울때는 어렵지만, 익숙해진 이후에는 다른 언어를 쉽게 배울수 있습니다.# 스크래치는 쉽다는데 안드로이드 앱 개발은 어렵지 않을까요?저는 이 교재를 만들면서 앱개발 경험이 전혀 없는 초보자도... "
#
# },
# {
# "title": "10 대를 위한 언플러그드 코딩카드 (게임으로 배우는 교과서 코딩 개념편)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14850493",
# "image": "https://bookthumb-phinf.pstatic.net/cover/148/504/14850493.jpg?type=m1&udate=20210324",
# "author": "(주)한국콘텐츠미디어 (부설)한국진로교육센터",
# "price": "12500",
# "discount": "",
# "publisher": "한국콘텐츠미디어",
# "pubdate": "20190419",
# "isbn": "1155056884 9791155056882",
# "description": "&lt;코딩카드&gt;는 80종 퀴즈 게임 카드로 초·중·고등학교 교과서에 수록된 코딩 개념 키워드를 재미있게 익힐 수 있다. 코딩 개념 카드는 이미지로 쉽게 기억할 수 있도록 구성했고 수업 시간에 친구들과 함께 학습할 수 있는 활용방법 카드도 수록했다.\n\n자료실 HTTP://CAFE.NAVER.COM/JOBCARD 에서... "
#
# },
# {
# "title": "앤서블 마스터하기 (앤서블의 고수가 되는 방법)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=12723491",
# "image": "https://bookthumb-phinf.pstatic.net/cover/127/234/12723491.jpg?type=m1&udate=20171228",
# "author": "제시 키팅",
# "price": "30000",
# "discount": "27000",
# "publisher": "에이콘출판",
# "pubdate": "20171123",
# "isbn": "1161750770 9791161750774",
# "description": "앤서블(ANSIBLE)은 최근 화두에 오른 IT 자동화 도구이다. IT 자동화는 사람이 일일이 서버에 접속해서 동일한 작업을 수행해야 하는 일을 한 번에 원격에서 처리하도록 하는 것이기 때문에 서버 관리자의 일을 엄청나게 줄여주며, 이때 발생할 수 있는 실수와 에러를 줄여준다. 앤서블은 쉽게 배워서 바로 쓸 수... "
#
# },
# {
# "title": "MXNet을 활용한 신경망 학습",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14564645",
# "image": "https://bookthumb-phinf.pstatic.net/cover/145/646/14564645.jpg?type=m1&udate=20190219",
# "author": "신병춘|차병래",
# "price": "13000",
# "discount": "12350",
# "publisher": "전남대학교출판문화원",
# "pubdate": "20190220",
# "isbn": "8968495963 9788968495960",
# "description": "최근 4차 산업혁명의 패러다임 변화와 더불어 대내외적으로 제4차 산업혁명 관련 전략과제를 발굴하고 있다. 특히 많은 수학자들을 제4차 산업혁명의 근본적인 연구의 주요 연구자로 흡입하는 정책을 펼치는 등 수학의 역할이 점차적으로 산업 및 경제에 기여하는 바가 커지고 있다. 인공신경망을 공부하는... "
#
# },
# {
# "title": "함께 만드는 인공지능 자주차",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=15041969",
# "image": "https://bookthumb-phinf.pstatic.net/cover/150/419/15041969.jpg?type=m1&udate=20210201",
# "author": "김평원|정형식|홍범진",
# "price": "20000",
# "discount": "18000",
# "publisher": "인천대학교출판부",
# "pubdate": "20190525",
# "isbn": "1189007126 9791189007126",
# "description": "자율주행자동차 개발 프로젝트를 고등학생들 수준에 맞게 제공하기 위해 개발한 자주차 프로젝트 교재이다. 인공지능 자주차 교육 프로그램은 현대모비스의 지원으로 김평원 교수팀에서 직접 이러닝 프로그램으로 제작한 후, 누구나 이용할 수 있도록 무상으로 공개하였다."
#
# },
# {
# "title": "아두이노처럼 사용하는 라즈베리 파이 3 직접 코딩하기 (wiringPi 라이브러리를 이용하여 아두이노 코딩처럼 배우는 라즈베리 파이 코딩북)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=13391886",
# "image": "https://bookthumb-phinf.pstatic.net/cover/133/918/13391886.jpg?type=m1&udate=20211214",
# "author": "서민우|박준원|장문철|조문국|김종용",
# "price": "22000",
# "discount": "19800",
# "publisher": "앤써북",
# "pubdate": "20180315",
# "isbn": "1185553363 9791185553368",
# "description": "아두이노를 배운 독자들이 <b>파이썬</b>을 몰라도 손쉽게 라즈베리 파이를 정복할 수 있도록 구성하였습니다. 외부 디바이스를 장착하여 라즈베리 파이의 기능을 확장하는 방법, L9110S DC 모터 드라이버 모듈을 이용하여 DC 모터를 제어할 수 있는 방법, HM10 블루투스 모듈 을 이용하여 라즈베리 파이의... "
#
# },
# {
# "title": "침투 테스트 (화이트 해커를 위한 실용 입문서)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=8995229",
# "image": "https://bookthumb-phinf.pstatic.net/cover/089/952/08995229.jpg?type=m1&udate=20190204",
# "author": "조지아 와이드먼",
# "price": "35000",
# "discount": "31500",
# "publisher": "비제이퍼블릭",
# "pubdate": "20150515",
# "isbn": "8994774955 9788994774954",
# "description": "화이트 해커를 위한 실용 입문서 [침투 테스트]. 이 책은 보안 전문가이자, 연구자 및 훈련자인 조지아 와이드먼이 침투 테스터라면 누구나 필요로 하는 기술과 기법의 핵심을 소개한다."
#
# },
# {
# "title": "Python Design Patterns (Python 예제 코드로 배우는 핵심 디자인 패턴)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=7456027",
# "image": "https://bookthumb-phinf.pstatic.net/cover/074/560/07456027.jpg?type=m1&udate=20190204",
# "author": "제나디 즐로빈",
# "price": "12000",
# "discount": "10800",
# "publisher": "에이콘출판",
# "pubdate": "20140321",
# "isbn": "8960775355 9788960775350",
# "description": "장황한 설명 없이 효율적으로 자신의 의사를 전달하고 불필요한 오해를 피할 수 있다. 이 책은 <b>파이썬</b>(Python)이라는 간결하고 강력한 언어를 통해 디자인 패턴(Design Pattern)을 설명한다. 객체 지향의 핵심 기능을 모두 가지고 있는 <b>파이썬</b>으로 직접 예제 코드를 구현하며 디자인 패턴의 세계로 빠져 보자."
#
# },
# {
# "title": "마이크로비트와 즐거운 코딩 배우기 2 (소리와 내장센서)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=15703760",
# "image": "https://bookthumb-phinf.pstatic.net/cover/157/037/15703760.jpg?type=m1&udate=20210724",
# "author": "박정호",
# "price": "20000",
# "discount": "",
# "publisher": "코비코퍼레이션",
# "pubdate": "20190701",
# "isbn": "1196717915 9791196717919",
# "description": "‘마이크로비트’는 영국 BBC 공영방송국에서 재단을 통해 세계적인 기업인 삼성전자,\n   마이크로소프트, ARM, 노르딕반도체, <b>파이썬</b> 등과 공동개발하여 만든 코딩교육 초소형 싱글보드 컴퓨터입니다.\n   \n   전세계 수많은 학교에서 폭 넓게 활용되고 있으며 아이들이 쉽고 재미있는 코딩교육을 접할 수 있도록... "
#
# },
# {
# "title": "인공지능을 위한 이산수학",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16323955",
# "image": "https://bookthumb-phinf.pstatic.net/cover/163/239/16323955.jpg?type=m1&udate=20200407",
# "author": "최종명",
# "price": "20000",
# "discount": "",
# "publisher": "J&H",
# "pubdate": "20200401",
# "isbn": "1196514038 9791196514037",
# "description": "프로그램 언어는 주로 <b>파이썬</b>을 사용하도록 하였고, 일부 C 언어와 프롤로그(Prolog) 언어를 사용하도록 하였다. 이 책으로 공부하는 컴퓨터 전공자가 교과목에서 배운 수학들이 실제 컴퓨터 영역에서 어떻게 활용되는지 구체적으로 배울 수 있는 기회가 되길 바란다."
#
# },
# {
# "title": "마이크로 소프트웨어 388호 2017.4 (검색의 재발견)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=11976122",
# "image": "https://bookthumb-phinf.pstatic.net/cover/119/761/11976122.jpg?type=m1&udate=20170711",
# "author": "마소팀",
# "price": "15000",
# "discount": "",
# "publisher": "IT조선",
# "pubdate": "20170420",
# "isbn": "1227622007 9771227622009",
# "description": "마이크로소프트웨어 388호  검색은 소프트웨어 개발에서 프론트엔드부터 백엔드까지 영역을 가리지 않고, 꼭 필요한 요소 중 하나입니다. 과거 자료를 아카이빙하는 기관이나 업체들은 문서 파일 내부의 내용까지 검색할 수 있어야 하고, 서버 관리자들은 실시간으로 쌓이는 로그를 관리해야 합니다. 다양한... "
#
# },
# {
# "title": "인공지능 (Python과 TensorFlow로 구현한)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=13954736",
# "image": "https://bookthumb-phinf.pstatic.net/cover/139/547/13954736.jpg?type=m1&udate=20181002",
# "author": "이권윤|이상부",
# "price": "17000",
# "discount": "15300",
# "publisher": "글로벌",
# "pubdate": "20180903",
# "isbn": "8955027648 9788955027648",
# "description": "▶  <b>파이썬</b>과 텐서플로우를 이용한 인공지능에 관한 내용을 담은 전문서적입니다."
#
# },
# {
# "title": "개발자를 위한 머신 러닝 (머신 러닝 시작이 막막한 개발자를 위한 안내서)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14095491",
# "image": "https://bookthumb-phinf.pstatic.net/cover/140/954/14095491.jpg?type=m1&udate=20201216",
# "author": "로돌포 본닌",
# "price": "25000",
# "discount": "22500",
# "publisher": "에이콘출판",
# "pubdate": "20181025",
# "isbn": "1161752188 9791161752181",
# "description": "러닝과 딥러닝에 관련된 서비스 및 라이브러리가 많이 공개돼 있지만, 이를 잘 활용하기 위해서는 머신 러닝에 대한 배경지식이 필수적이다. 이 책에서는 머신 러닝을 실제로 적용하는데 필요한 관련 배경지식을 최소한의 수식과 간단한 <b>파이썬</b> 코드를 통해 체계적으로 머신 러닝부터 딥러닝까지 소개하고 있다."
#
# },
# {
# "title": "뚝딱뚝딱 우리 집 프로그래밍 (아두이노 안드로이드로 직접 만드는 스마트 홈 프로젝트)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=7252705",
# "image": "https://bookthumb-phinf.pstatic.net/cover/072/527/07252705.jpg?type=m1&udate=20190204",
# "author": "마이크 라일리",
# "price": "18000",
# "discount": "16200",
# "publisher": "인사이트",
# "pubdate": "20130712",
# "isbn": "8966260772 9788966260775",
# "description": "아두이노, 안드로이드로 직접 만드는 스마트 홈 프로젝트 『우리 집 프로그래밍』. FLEX 센서를 이용한 수위 경보기를 비롯하여, 전자 경비견, 트윗하는 새 모이 그릇, 소포 배달 감지기, 웹과 연결된 전원 스위치, 안드로이드 문단속 장치 등의 내용이 수록되어 있다. 이 책에서 소개하는 프로젝트 대부분은 제작... "
#
# },
# {
# "title": "PyTorch를 활용한 머신러닝, 딥러닝 철저 입문 (파이토치를 활용한 머신러닝, 딥러닝 알고리즘의 원리와 구현)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14134742",
# "image": "https://bookthumb-phinf.pstatic.net/cover/141/347/14134742.jpg?type=m1&udate=20181110",
# "author": "코이즈미 사토시",
# "price": "25000",
# "discount": "",
# "publisher": "위키북스",
# "pubdate": "20181107",
# "isbn": "1158391226 9791158391225",
# "description": "파이토치는 딥러닝 라이브러리 중에서도 세계적으로 널리 쓰이는 TORCH를 <b>파이썬</b>으로 포팅한 것으로, 페이스북이 자사 서비스에 활용하면서 주목받고 있다. 이 책은 초심자를 대상으로 이 라이브러리를 사용해 이상탐지나 이미지 인식 등을 구현하는 과정을 경험해 볼 수 있도록 구성했다."
#
# },
# {
# "title": "텐서플로 입문서 (완전초보자도 따라하는)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14533437",
# "image": "https://bookthumb-phinf.pstatic.net/cover/145/334/14533437.jpg?type=m1&udate=20210509",
# "author": "비피제이기술거래",
# "price": "30000",
# "discount": "27000",
# "publisher": "비티타임즈",
# "pubdate": "20190218",
# "isbn": "1163450677 9791163450672",
# "description": "이러한 텐서플로를 처음 다루는 독자들을 위해 기초적인 내용을 다뤄보고자 한다. 본 보고서의 독자는 텐서플로우를 처음 접하고, <b>파이썬</b> 또한 사용해보지 않은 사용자로, 텐서플로우와 <b>파이썬</b>의 개념부터 텐서플로우를 설치하는 방법 그리고 다양한 텐서플로우 예제를 통해 이해를 높여보고자 한다."
#
# },
# {
# "title": "네이선 야우의 데이터 포인트 (데이터 시각화 인포그래픽을 깨우치다)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=7342676",
# "image": "https://bookthumb-phinf.pstatic.net/cover/073/426/07342676.jpg?type=m1&udate=20210509",
# "author": "네이선 야우",
# "price": "27500",
# "discount": "24750",
# "publisher": "비제이퍼블릭",
# "pubdate": "20131118",
# "isbn": "8994774505 9788994774503",
# "description": "독창적이고 의미 있는 데이터 시각화와 인포그래픽에 대한 고찰 &#x0D;&#x0D;효과적인 데이터 시각화를 위한 구체적인 테크닉을 소개한다. 저자는 일반 대중들이 이해하고 기억하기 쉬우면서도 독창적이고 의미 있는 데이터 시각화를 산출하기 위해 필요한 사고 과정들을 다루고,  데이터 속의 중요한 의미를... "
#
# }
# ]
# }
#
# <class 'str'>
# 검색결과 1428

# %%
len(dict['items'])
# Out:
# 100

# %% [markdown]
# # title

# %%
import urllib.request ## 웹페이지 요청 ==> 브라우저 사용
client_id = "3wU5xwXfFVL4LweQzLHQ" # 애플리케이션 ID
client_secret = "K60NkftSAH" # 애플리케이션  Secret
encText = urllib.parse.quote("파이썬") ## URL 인코딩
rangeText_start = urllib.parse.quote("1")


url = "https://openapi.naver.com/v1/search/book?query=" + encText + "&display=100" + "&start=" + rangeText_start
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
list = []

if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
    text = response_body.decode('utf-8')
    print(type(text))
    dict = json.loads(text) ##
    print(dict)
    val  = dict['items']
    for i in val :
        list.append(i['title'])
    print(list)
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Fri, 24 Dec 2021 12:35:14 +0900",
# "total": 1428,
# "start": 1,
# "display": 100,
# "items": [
# {
# "title": "이것이 취업을 위한 코딩 테스트다 with <b>파이썬</b> (취업과 이직을 결정하는 알고리즘 인터뷰 완벽 가이드)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16439154",
# "image": "https://bookthumb-phinf.pstatic.net/cover/164/391/16439154.jpg?type=m1&udate=20200928",
# "author": "나동빈",
# "price": "34000",
# "discount": "30600",
# "publisher": "한빛미디어",
# "pubdate": "20200805",
# "isbn": "1162243074 9791162243077",
# "description": "8가지 핵심 알고리즘 이론을 쉽게 설명하고, 관련 실전 문제를 풀이했다. 출제 유형 분석, 이론 설명, 기출문제 풀이까지! 어떤 코딩 테스트도 이 책 한 권으로 대비할 수 있을 것이다. 코딩 테스트에서 주로 선택하는 <b>파이썬</b>을 기반으로 설명되어 있으며, <b>파이썬</b> 코드 외에도 C/C++, 자바 코드를 추가로 제공한다."
#
# },
# {
# "title": "혼자 공부하는 <b>파이썬</b> (<b>파이썬</b> 최신 버전 반영)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=15028688",
# "image": "https://bookthumb-phinf.pstatic.net/cover/150/286/15028688.jpg?type=m1&udate=20211206",
# "author": "윤인성",
# "price": "18000",
# "discount": "16200",
# "publisher": "한빛미디어",
# "pubdate": "20190610",
# "isbn": "1162241888 9791162241882",
# "description": "1:1 과외하듯 배우는 <b>파이썬</b> 프로그래밍 자습서(<b>파이썬</b> 최신 버전 반영)\n27명의 베타리더 검증으로, ‘함께 만든’ 입문자 맞춤형 도서\n\n이 책은 독학으로 프로그래밍 언어를 처음 배우려는 입문자가, 혹은 <b>파이썬</b>을 배우려는 입문자가 ‘꼭 필요한 내용을 제대로’ 학습할 수 있도록 구성했다. ‘무엇을’... "
#
# },
# {
# "title": "Do it! 점프 투 <b>파이썬</b>",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=15052904",
# "image": "https://bookthumb-phinf.pstatic.net/cover/150/529/15052904.jpg?type=m1&udate=20200910",
# "author": "박응용",
# "price": "18800",
# "discount": "16900",
# "publisher": "이지스퍼블리싱",
# "pubdate": "20190620",
# "isbn": "1163030910 9791163030911",
# "description": "<b>파이썬</b> 4년 연속 베스트셀러 1위!\n《DO IT! 점프 투 <b>파이썬</b>》 전면 개정판 출시!문과생도 중고등학생도 직장인도 프로그래밍에 눈뜨게 만든 바로 그 책이... 점프 투 <b>파이썬</b>》으로 출간되었던 이 책은 약 4년 동안의 피드백을 반영하여 초보자가 더 빠르게 입문하고, 더 깊이 있게 공부할 수 있도록 개정되었다.... "
#
# },
# {
# "title": "<b>파이썬</b> 알고리즘 인터뷰 (95가지 알고리즘 문제 풀이로 완성하는 코딩 테스트)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16406247",
# "image": "https://bookthumb-phinf.pstatic.net/cover/164/062/16406247.jpg?type=m1&udate=20211209",
# "author": "박상길",
# "price": "38000",
# "discount": "34200",
# "publisher": "책만",
# "pubdate": "20200715",
# "isbn": "1189909170 9791189909178",
# "description": "물론, <b>파이썬</b>으로 구현하는 코드 풀이를 통해 성능 최적화 기법, <b>파이썬</b>의 핵심 문법과 다양한 실용 테크닉까지 배울 수 있는, 초보 개발자와 숙련 개발자... 이 책은 현업과 실무에 유용한 주요 알고리즘 이론을 깊숙이 이해하고, <b>파이썬</b>의 핵심 기능과 문법까지 상세하게 이해할 수 있는 취업용 코딩 테스트를... "
#
# },
# {
# "title": "<b>파이썬</b> 무작정 따라하기 (미래의 프로그래머를 위한)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21354236",
# "image": "https://bookthumb-phinf.pstatic.net/cover/213/542/21354236.jpg?type=m1&udate=20211215",
# "author": "송석리|서승희",
# "price": "16000",
# "discount": "14400",
# "publisher": "길벗",
# "pubdate": "20211220",
# "isbn": "1165217899 9791165217891",
# "description": "초등학생을 위한 <b>파이썬</b> 교재첫 코딩을 쉽고 재밌게!이 책은 초등학생부터 청소년까지 쉽고 체계적으로 <b>파이썬</b> 코딩을 배울 수 있는 책입니다. 데이터... 블록 코딩을 끝낸 뒤 텍스트 코딩을 본격적으로 배우고 싶다면 이 책으로 시작해 보세요!<b>파이썬</b> 설치부터 활용 방법, 기본 개념을 꼼꼼하게 자세하게... "
#
# },
# {
# "title": "<b>파이썬</b> 증권 데이터 분석 (<b>파이썬</b> 입문, 웹 스크레이핑, 트레이딩 전략, 자동 매매)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16381920",
# "image": "https://bookthumb-phinf.pstatic.net/cover/163/819/16381920.jpg?type=m1&udate=20201117",
# "author": "김황후",
# "price": "32000",
# "discount": "28800",
# "publisher": "한빛미디어",
# "pubdate": "20200701",
# "isbn": "1162243201 9791162243206",
# "description": "투자 기법과 프로그래밍 기술로 &#x0D;자신만의 퀀트 투자 시스템을 완성하라&#x0D;&#x0D;『<b>파이썬</b> 증권 데이터 분석』은 웹 스크레이핑으로 증권 데이터를 주기적으로 자동 수집, 분석, 자동 매매, 예측하는 전 과정을 <b>파이썬</b>으로 직접 구현한다. 그 과정에서 금융 데이터 처리 기본 라이브러리(팬더스)부터 주가... "
#
# },
# {
# "title": "<b>파이썬</b> 머신러닝 완벽 가이드 (다양한 캐글 예제와 함께 기초 알고리즘부터 최신 기법까지 배우는)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16238302",
# "image": "https://bookthumb-phinf.pstatic.net/cover/162/383/16238302.jpg?type=m1&udate=20200423",
# "author": "권철민",
# "price": "38000",
# "discount": "34200",
# "publisher": "위키북스",
# "pubdate": "20200207",
# "isbn": "1158391927 9791158391928",
# "description": "자세한 이론 설명과 <b>파이썬</b> 실습을 통해 머신러닝을 완벽하게 배울 수 있습니다!《<b>파이썬</b> 머신러닝 완벽 가이드》는 이론 위주의 머신러닝 책에서 탈피해 다양한 실전 예제를 직접 구현해 보면서 머신러닝을 체득할 수 있도록 만들었습니다.  캐글과 UCI 머신러닝 리포지토리에서 난이도가 있는 실습... "
#
# },
# {
# "title": "쉽게 따라 만드는 <b>파이썬</b> 주식 자동매매 시스템 (증권사 API 사용, 매매전략 구현, 실전 투자 전환까지!)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21119890",
# "image": "https://bookthumb-phinf.pstatic.net/cover/211/198/21119890.jpg?type=m1&udate=20211207",
# "author": "박준성",
# "price": "28000",
# "discount": "25200",
# "publisher": "길벗",
# "pubdate": "20211014",
# "isbn": "1165217163 9791165217167",
# "description": "개발 환경 구축부터 실전 투자 전환까지\n<b>파이썬</b>으로 나만의 주식 자동매매 시스템을 만든다!\n\n이 책은 <b>파이썬</b>을 이용하여 주식 자동매매 시스템을 만드는... 개발 환경을 구축하고, 프로젝트를 만드는 데 필요한 기초 <b>파이썬</b> 문법은 물론 증권 데이터를 주고받기 위해 키움증권 API를 사용하는 방법과 웹... "
#
# },
# {
# "title": "<b>파이썬</b>을 이용한 비트코인 자동매매",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=18214660",
# "image": "https://bookthumb-phinf.pstatic.net/cover/182/146/18214660.jpg?type=m1&udate=20210316",
# "author": "유대표|조대표",
# "price": "27000",
# "discount": "24300",
# "publisher": "파이스탁",
# "pubdate": "20210322",
# "isbn": "1196608814 9791196608811",
# "description": "이 책은 최근 인기 있는 프로그래밍 언어인 <b>파이썬</b>을 사용하여 국내 3대 거래소(코빗, 빗썸, 업비트)... 프로그래밍 경험이 없는 일반인을 대상으로 <b>파이썬</b> 기초 문법부터 시작하여 24시간 실시간 자동... 있어 <b>파이썬</b>을 처음 배우는 분들이 유익하고 재미있게 프로그래밍을 배울 수 있도록 합니다. 책에서... "
#
# },
# {
# "title": "머신 러닝 교과서 with <b>파이썬</b>, 사이킷런, 텐서플로 (최신 넘파이, 사이킷런, 텐서플로 2로 배우는 머신 러닝, 딥러닝 핵심 알고)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=18829375",
# "image": "https://bookthumb-phinf.pstatic.net/cover/188/293/18829375.jpg?type=m1&udate=20211207",
# "author": "세바스찬 라시카|바히드 미자리리",
# "price": "44000",
# "discount": "39600",
# "publisher": "길벗",
# "pubdate": "20210331",
# "isbn": "1165215187 9791165215187",
# "description": "<b>파이썬</b> 언어와 <b>파이썬</b> 기반의 머신 러닝 핵심 라이브러리(SciPy, NumPy, scikit-learn, Matplotlib, Pandas)를 사용해 머신 러닝을, 텐서플로(TensorFlow 2)를 사용해 딥러닝을 실습해본다. 특히 딥러닝은 최신 텐서플로 2에 맞춰 대폭 수정 및 보강되었다. 그러고 나서 GAN과 강화 학습도 자세하게 다룬다. 머신 러닝과... "
#
# },
# {
# "title": "생활코딩 머신러닝 실습편 with <b>파이썬</b> 텐서플로 (누구나 쉽게 시작하는 인공지능 첫걸음)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21344673",
# "image": "https://bookthumb-phinf.pstatic.net/cover/213/446/21344673.jpg?type=m1&udate=20211201",
# "author": "이숙번|이고잉",
# "price": "24000",
# "discount": "21600",
# "publisher": "위키북스",
# "pubdate": "20211215",
# "isbn": "1158392990 9791158392994",
# "description": "너무 어려워서 높은 벽처럼 느껴졌던 ‘딥러닝(DEEP LEARNING)’, 이 책과 함께라면 쉽게 시작할 수 있습니다!《생활코딩 머신러닝 실습편 WITH <b>파이썬</b> 텐서플로》는 초등학생부터 어르신까지, 딥러닝이 궁금하고 직접 코딩해보고 싶은 모든 분을 위한 책입니다. 복잡한 원리와 수학을 몰라도... "
#
# },
# {
# "title": "Do it! 첫 코딩 with <b>파이썬</b> (보통 사람이 알아야 할 프로그래밍 기초)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17727701",
# "image": "https://bookthumb-phinf.pstatic.net/cover/177/277/17727701.jpg?type=m1&udate=20210323",
# "author": "정동균",
# "price": "18000",
# "discount": "16200",
# "publisher": "이지스퍼블리싱",
# "pubdate": "20210115",
# "isbn": "1163032158 9791163032151",
# "description": "첫 코딩》 <b>파이썬</b> 버전 출간!\n국내 최초 ‘문과식’ 코딩 입문서!\n147가지 비유와 그림, 무료 온라인... 첫 코딩》이 <b>파이썬</b> 버전으로 출간 되었습니다.\n‘공대생도 놀란 책’에 걸맞은 147가지 비유와... 첫 코딩》 자바 버전보다 80쪽 늘어난 이 책에서는 특별히 <b>파이썬</b>으로 코딩하면 만나게 될 ‘데이터... "
#
# },
# {
# "title": "Do it! <b>파이썬</b> 생활 프로그래밍",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16437083",
# "image": "https://bookthumb-phinf.pstatic.net/cover/164/370/16437083.jpg?type=m1&udate=20211216",
# "author": "김창현",
# "price": "20000",
# "discount": "18000",
# "publisher": "이지스퍼블리싱",
# "pubdate": "20200727",
# "isbn": "1163031739 9791163031734",
# "description": "집필한 <b>파이썬</b> 생활 프로그래밍 책!\n웹 크롤링부터 데이터 분석까지, 11가지 프로그램을 내 손으로 직접 만든다!이 책은 생활 프로그래머 김창현 박사가 일상과 업무에서 <b>파이썬</b> 프로그래밍을 활용한 경험을... 이 프로그램들은 <b>파이썬</b> 문법을 한 번이라도 배운 적이 있는 사람이라면 누구나 따라 할 수 있는... "
#
# },
# {
# "title": "모두의 <b>파이썬</b> (20일 만에 배우는 프로그래밍 기초)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14126163",
# "image": "https://bookthumb-phinf.pstatic.net/cover/141/261/14126163.jpg?type=m1&udate=20210210",
# "author": "이승찬",
# "price": "12000",
# "discount": "10800",
# "publisher": "길벗",
# "pubdate": "20181009",
# "isbn": "1160505853 9791160505856",
# "description": "<b>파이썬</b> 분야 & 어린이 코딩 교육 분야\n2년 연속 베스트셀러! 개정판 출간!\n즐겁게 시작하는 나의 첫 프로그래밍!\n프로그래밍을 한 번도 해본 적이 없어도 괜찮다. <b>파이썬</b>이 무엇인지 몰라도 상관 없다.... 어느새 <b>파이썬</b> 프로그램으로 멋진 그림을 그리고, 계산을 하고, 간단한 게임을 만들고, 수학 문제를... "
#
# },
# {
# "title": "선형대수와 통계학으로 배우는 머신러닝 with <b>파이썬</b> (선형대수와 통계학으로 배우는 머신러닝 with <b>파이썬</b>)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17853038",
# "image": "https://bookthumb-phinf.pstatic.net/cover/178/530/17853038.jpg?type=m1&udate=20211207",
# "author": "장철원",
# "price": "37500",
# "discount": "33750",
# "publisher": "비제이퍼블릭",
# "pubdate": "20210126",
# "isbn": "1165920395 9791165920395",
# "description": "머신러닝에 필요한 선형대수, 통계학, 최적화 이론부터\n<b>파이썬</b>, 사이킷런, 텐서플로를 활용한 실습까지\n\n『선형대수와 통계학으로 배우는 머신러닝 with <b>파이썬</b>』은 머신러닝의 기본적인 사용 방법뿐만 아니라 통계학, 선형대수, 최적화 이론 등 머신러닝에 필요한 배경 이론까지 다룬다. 머신러닝 알고리즘을... "
#
# },
# {
# "title": "혼자 공부하는 첫 프로그래밍 with <b>파이썬</b> (1:1 과외하듯 배우는 왕초보 코딩 입문서)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16385280",
# "image": "https://bookthumb-phinf.pstatic.net/cover/163/852/16385280.jpg?type=m1&udate=20211207",
# "author": "문현일",
# "price": "17000",
# "discount": "15300",
# "publisher": "한빛미디어",
# "pubdate": "20200630",
# "isbn": "1162243031 9791162243039",
# "description": "비전공자도 ‘혼공’ 할 수 있다!\n1:1 과외하듯 배우는 왕초보 코딩 입문서\n\n유튜브 강의! 그림으로 보여주는 ‘눈코딩’ 예제! 프로그램 설치 없이 온라인 실습! 부록 용어 노트! 이 모든 것을 제공하기에 비전공자도 프로그래밍을 독학할 수 있습니다. 이 책은 비전공자가 시중에 나온 프로그래밍 책을 이해할 수... "
#
# },
# {
# "title": "모두의 데이터 분석 with <b>파이썬</b> (실생활 예제로 시작하는 데이터 분석 첫걸음)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14820571",
# "image": "https://bookthumb-phinf.pstatic.net/cover/148/205/14820571.jpg?type=m1&udate=20211029",
# "author": "송석리|이현아",
# "price": "18000",
# "discount": "16200",
# "publisher": "길벗",
# "pubdate": "20190425",
# "isbn": "1160507813 9791160507812",
# "description": "데이터 다운로드부터 정제, 문제 해결 방법 구상, <b>파이썬</b> 코드로 구현까지 차근차근 진행하면서, 초보자가 데이터 분석의 성공적인 첫걸음을 내딛도록... 최소한의 <b>파이썬</b> 문법만을 사용하여 설명하므로 프로그래밍 경험이 적은 사람도 충분히 따라 할 수 있습니다. 이제 데이터 분석 전문가가 아니어도, 자신의... "
#
# },
# {
# "title": "<b>파이썬</b> 코딩의 기술 (Effective Python 2nd,똑똑하게 코딩하는 법)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16876960",
# "image": "https://bookthumb-phinf.pstatic.net/cover/168/769/16876960.jpg?type=m1&udate=20211208",
# "author": "브렛 슬라킨",
# "price": "32000",
# "discount": "28800",
# "publisher": "길벗",
# "pubdate": "20201030",
# "isbn": "1165213192 9791165213190",
# "description": "아마존 <b>파이썬</b> 프로그래밍 분야 베스트셀러, 〈Effective Python〉 전면 개정 증보판! \n<b>파이썬</b>의 매력과 강점을 이용해 강력하고 우수한 성능의 코드를 작성하는 90가지 방법!\n\n<b>파이썬</b>다운 방식으로 프로그램을 작성하는 방법, <b>파이썬</b>을 사용하는 가장 좋은 방법에 대한 통찰을 담았다! 2판에서는 <b>파이썬</b> 3.... "
#
# },
# {
# "title": "Do it! 첫 <b>파이썬</b> (게임하듯 배우는 나의 첫 프로그래밍 책)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16324192",
# "image": "https://bookthumb-phinf.pstatic.net/cover/163/241/16324192.jpg?type=m1&udate=20211213",
# "author": "엘리스 코딩",
# "price": "14000",
# "discount": "12600",
# "publisher": "이지스퍼블리싱",
# "pubdate": "20200410",
# "isbn": "1163031569 9791163031567",
# "description": "왕초보 맞춤 <b>파이썬</b> 입문서\n\n초등 고학년부터 필수인 코딩, 주인공 ‘엘리스 토끼’와 함께 게임하듯 배우세요. 176가지 그림과 45가지 코딩 문제를 풀다... 마지막 과제인 ‘점심 메뉴 추첨기’ 프로그램까지 만들면 ‘<b>파이썬</b> 이수증’도 드립니다. 제대로 설계된 코딩 교육 콘텐츠를 찾는 학생·학부모·선생님은... "
#
# },
# {
# "title": "모두의 인공지능 with <b>파이썬</b> (누구나 쉽게 시작하는 딥러닝 기초 프로그래밍)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17664105",
# "image": "https://bookthumb-phinf.pstatic.net/cover/176/641/17664105.jpg?type=m1&udate=20210814",
# "author": "이영호",
# "price": "22000",
# "discount": "19800",
# "publisher": "길벗",
# "pubdate": "20201230",
# "isbn": "1165213982 9791165213985",
# "description": "<b>파이썬</b>을 모르는 사람도 볼 수 있도록 기초 <b>파이썬</b> 문법을 짚어주고, 개발 환경(코랩, 텐서플로, 케라스)을 구축하는 방법도 상세히 알려준다. 뒤에서는 앞에서 배운 원리를 활용하여 실제로 인공지능 모델을 만들어 본다. 손글씨로 쓴 숫자를 인식하는 인공지능, 코로나 19 확진자 수를 예측하는 인공지능... "
#
# },
# {
# "title": "Do it! 장고+부트스트랩 <b>파이썬</b> 웹 개발의 정석 (웹 기초부터 블로그 개발 배포 운영까지, 만들면서 배우는 웹 개발 A to Z)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17717279",
# "image": "https://bookthumb-phinf.pstatic.net/cover/177/172/17717279.jpg?type=m1&udate=20211207",
# "author": "이성용|김태곤",
# "price": "32000",
# "discount": "28800",
# "publisher": "이지스퍼블리싱",
# "pubdate": "20210118",
# "isbn": "1163032069 9791163032069",
# "description": "만들면서 배우는 <b>파이썬</b> 웹 개발 A to Z!\n<b>파이썬</b> 기초 문법만 알면 나만의 블로그 사이트를 만들 수 있다!\n\n이 책은 블로그 웹 사이트를 만드는 실습을... 이 과정에서 HTML, CSS, 자바스크립트부터 부트스트랩, <b>파이썬</b> 웹 프레임워크 장고(Django), 도커(Docker), 아마존 웹 서비스(AWS)까지 웹 사이트를 만들고... "
#
# },
# {
# "title": "<b>파이썬</b> 매일 코딩 (매일 10분, 50가지 연습 문제로 키우는 <b>파이썬</b> 코딩 실력!)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21307305",
# "image": "https://bookthumb-phinf.pstatic.net/cover/213/073/21307305.jpg?type=m1&udate=20211211",
# "author": "루벤 M. 러너",
# "price": "22000",
# "discount": "19800",
# "publisher": "길벗",
# "pubdate": "20211130",
# "isbn": "1165217880 9791165217884",
# "description": "능숙한 <b>파이썬</b> 프로그래머가 되기 위한 지름길!\n다양한 <b>파이썬</b> 문제를 풀어보며 프로그래밍 기술을 배우고 자신감을 키우자!\n \n<b>파이썬</b>을 마스터할 수 있는 유일한 방법은 연습이다. 숫자 맞히기 게임, 16진수 출력하기와 같은 간단한 문제부터 판매세 계산하기, 순환하는 이터레이터 만들기와 같은 궁금한... "
#
# },
# {
# "title": "Let’s Get IT <b>파이썬</b> 프로그래밍 (데이터 분석 프로젝트로 프로그래밍 사고력 기르기)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20677567",
# "image": "https://bookthumb-phinf.pstatic.net/cover/206/775/20677567.jpg?type=m1&udate=20211207",
# "author": "안지혜",
# "price": "22000",
# "discount": "19800",
# "publisher": "길벗",
# "pubdate": "20210705",
# "isbn": "1165215969 9791165215965",
# "description": "자세히 설명하고 직관적으로 이해할 수 있게내용은 풍부하게 넣고,가볍게 들고 다니도록 2권으로 분권 구성했습니다.\n\n이 책의 분권 구성\nVol.1(314쪽)\n_Part 1일주일만에 끝내는<b>파이썬</b> 기초\nVol.2(442쪽)\n_Part 2 <b>파이썬</b>으로 데이터 분석하기\n_Part 3 효율적인 프로그래밍을 위한 중급 <b>파이썬</b>"
#
# },
# {
# "title": "머신러닝&딥러닝 with <b>파이썬</b> (인공지능 핵심 개념과 사용 사례부터,한 권으로 다지는)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21122108",
# "image": "https://bookthumb-phinf.pstatic.net/cover/211/221/21122108.jpg?type=m1&udate=20211207",
# "author": "알베르토 아르타산체스|프라틱 조시",
# "price": "40000",
# "discount": "36000",
# "publisher": "한빛미디어",
# "pubdate": "20211021",
# "isbn": "1162244879 9791162244876",
# "description": "예제는 <b>파이썬</b>과 텐서플로를 사용하며 <b>파이썬</b> 입문자도 쉽게 따라 할 수 있는 코드로 구성되었다. <b>파이썬</b> 프로그래밍 경험이 있다면 코드를 자유롭게 활용해 원하는 프로그램을 만들어볼 수 있다.\n\n영화 추천 시스템 구축, 주식시장 분석, 객체 추적기 구축 등 흥미로운 예제를 따라 차근차근 학습하고 나면 다양한... "
#
# },
# {
# "title": "<b>파이썬</b> 딥러닝 파이토치 (Python Deep Learning PyTorch)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16778336",
# "image": "https://bookthumb-phinf.pstatic.net/cover/167/783/16778336.jpg?type=m1&udate=20210929",
# "author": "이경택|방성수|안상준",
# "price": "25000",
# "discount": "22500",
# "publisher": "정보문화사",
# "pubdate": "20201008",
# "isbn": "8956748578 9788956748573",
# "description": "<b>파이썬</b>은 선택이 아닌 필수! 파이토치로 딥러닝 입문하기!이 책은 딥러닝 기술에 초점을 두고 딥러닝을 구현하기 위해 <b>파이썬</b>을 이용하는데, 머신러닝 라이브러리인 파이토치를 활용하여 다양한 텐서를 지원하는 방법을 알아본다. 파이토치는 <b>파이썬</b> 코딩과 비슷하기 때문에 언어가 어렵지 않다.... "
#
# },
# {
# "title": "<b>파이썬</b> 생활밀착형 프로젝트 (웹크롤링, 카카오톡 메시지 보내기, 업무자동화까지 11가지 <b>파이썬</b>프로젝트, 백견불여일타 이젠 프로젝트다!)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20596927",
# "image": "https://bookthumb-phinf.pstatic.net/cover/205/969/20596927.jpg?type=m1&udate=20210609",
# "author": "김효실",
# "price": "25000",
# "discount": "22500",
# "publisher": "로드북",
# "pubdate": "20210616",
# "isbn": "8997924877 9788997924875",
# "description": "<b>파이썬</b>을 배웠는데 그 다음엔 뭘 할 수 있지? 라는 물음에서부터 기획되었다. 인간의 언어도 사용해봐야 늘 듯이, 프로그래밍 언어도 그렇다. 문법만... 웹 크롤링, 업무 자동화, 인공지능 비서, 주식 분석 자동화 등의 프로젝트를 재미나게 배우면서 <b>파이썬</b> 활용 실력도 높여보자."
#
# },
# {
# "title": "<b>파이썬</b> 인공지능 입문+실전 종합편 (한 권으로 끝내는, <b>파이썬</b>+넘파이+텐서플로우로 인공지능 딥러닝 직접 구현하기)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20937519",
# "image": "https://bookthumb-phinf.pstatic.net/cover/209/375/20937519.jpg?type=m1&udate=20211118",
# "author": "서민우",
# "price": "23000",
# "discount": "20700",
# "publisher": "앤써북",
# "pubdate": "20210925",
# "isbn": "118555386X 9791185553863",
# "description": "〈한 권으로 끝내는 <b>파이썬</b> 인공지능 입문+실전(종합편)〉 책을 통해 <b>파이썬</b>, 넘파이, 텐서플로우를 이용하여 인공지능 일고리즘을 구현해 보면서... ㆍ 1단계 : 인공지능 딥러닝 이해 ㆍ 2단계 : <b>파이썬</b>으로 딥러닝 알고리즘 구현ㆍ 3단계 : 넘파이로 행렬기반 딥러닝 알고리즘 구현 ㆍ 4단계 : 직접 구현으로... "
#
# },
# {
# "title": "엑셀 자동화 with <b>파이썬</b> (복잡하고 지루한 반복 업무를 쉽고 빠르게 해치우는 방법,일 잘하는 직장인을 위한)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16894128",
# "image": "https://bookthumb-phinf.pstatic.net/cover/168/941/16894128.jpg?type=m1&udate=20211002",
# "author": "최은석",
# "price": "30000",
# "discount": "27000",
# "publisher": "위키북스",
# "pubdate": "20201110",
# "isbn": "1158392265 9791158392260",
# "description": "<b>파이썬</b>을 활용해 엑셀 파일과 데이터를 자유자재로 다루자!엑셀은 기능이 풍부하고 사용하기가 쉬워서 오랫동안 사랑받아온 프로그램이지만 대량의... 이 책은 <b>파이썬</b>을 이용해 엑셀 업무를 자동화하는 방법을 다룹니다. 기본적인 <b>파이썬</b> 문법부터 데이터 분석과 엑셀 자동화까지 상세히 설명하고 있어 <b>파이썬</b>을... "
#
# },
# {
# "title": "<b>파이썬</b> 머신러닝 판다스 데이터 분석",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=15028524",
# "image": "https://bookthumb-phinf.pstatic.net/cover/150/285/15028524.jpg?type=m1&udate=20210317",
# "author": "오승환",
# "price": "25000",
# "discount": "22500",
# "publisher": "정보문화사",
# "pubdate": "20190615",
# "isbn": "8956748330 9788956748337",
# "description": "데이터 과학자가 되기 위한 첫걸음!<b>파이썬</b> 초급자나 중급자가 데이터 분석과 머신러닝을 배우고자 마음먹었다면 이 책을 선택해야 한다. 필수... 그 출발 선상에 섰다면 이 책과 함께 예제코드를 하나씩 실행해보면, <b>파이썬</b> 데이터 분석을 즐기고 있는 본인을 발견할 것이다.\n\n학습에 필요한 예제 코드와... "
#
# },
# {
# "title": "<b>파이썬</b> 데이터 클리닝 쿡북 (<b>파이썬</b>과 판다스를 활용한 데이터 전처리)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21289619",
# "image": "https://bookthumb-phinf.pstatic.net/cover/212/896/21289619.jpg?type=m1&udate=20211112",
# "author": "마이클 워커",
# "price": "28000",
# "discount": "25200",
# "publisher": "위키북스",
# "pubdate": "20211119",
# "isbn": "1158392788 9791158392789",
# "description": "《<b>파이썬</b> 데이터 클리닝 쿡북》은 <b>파이썬</b>으로 데이터를 다루고 정제할 때 사용할 수 있는 도구와 기법을 보여준다.먼저 통상적인 데이터 소스로부터... 체이닝으로 <b>파이썬</b> 판다스 작업 생산성을 향상◎ 시각화를 통해 통찰을 얻고 잠재적인 데이터 이슈를 식별◎ 데이터의 변동을 파악하는 능력을 향상◎ 사용자... "
#
# },
# {
# "title": "<b>파이썬</b> 라이브러리를 활용한 데이터 분석 (영화 평점, 이름 통계, 선거 데이터 등 실사례 사용)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14922211",
# "image": "https://bookthumb-phinf.pstatic.net/cover/149/222/14922211.jpg?type=m1&udate=20211207",
# "author": "웨스 맥키니",
# "price": "35000",
# "discount": "31500",
# "publisher": "한빛미디어",
# "pubdate": "20190520",
# "isbn": "116224190X 9791162241905",
# "description": "이 책은 NumPy, pandas, matplotlib, IPython, Jupyter 등 다양한 <b>파이썬</b> 라이브러리를 사용해서 효과적으로 데이터를 분석하는 방법을 알려준다. pandas의 새로운 기능뿐만 아니라 메모리 사용량을 줄이고 성능을 개선하는 고급 사용법까지 다룬다. 또한 모델링 도구인 statsmodels와 scikit-learn... "
#
# },
# {
# "title": "<b>파이썬</b> 머신러닝 실무 테크닉 100",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21347076",
# "image": "https://bookthumb-phinf.pstatic.net/cover/213/470/21347076.jpg?type=m1&udate=20211215",
# "author": "시모야마 데루마사|미키 다카유키|이토 준지",
# "price": "25000",
# "discount": "22500",
# "publisher": "제이펍",
# "pubdate": "20211214",
# "isbn": "1191600432 9791191600438",
# "description": "하지만 실무 현장에서의 기술 활용이나 대처 방법과 같은 노하우는 입문서로 공부하는 것만으로는 결코 익힐 수 없습니다.이 책은 큰 호평을 받았던 《<b>파이썬</b> 데이터 분석 실무 테크닉 100》을 잇는 것으로, 실제 실무 현장을 가정한 100개의 문제를 풀면서 현장의 관점과 응용력을 몸에 익히도록 구성한... "
#
# },
# {
# "title": "그림으로 배우는 <b>파이썬</b>",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21148889",
# "image": "https://bookthumb-phinf.pstatic.net/cover/211/488/21148889.jpg?type=m1&udate=20211028",
# "author": "다카하시 마나",
# "price": "18000",
# "discount": "16200",
# "publisher": "영진닷컴",
# "pubdate": "20211110",
# "isbn": "8931465858 9788931465853",
# "description": "<b>파이썬</b> 기초부터 라이브러리, 기계학습 입문까지 <b>파이썬</b>은 간결해서 배우기 쉽고, 프로그램을 빠르게 개발할 수 있으며, 인공지능 등 다양한 분야에... 이 책은 풍부한 일러스트와 친절한 설명을 통해 기초 문법부터 차근차근 다지고, 많은 예제 프로그램을 통해 초보자도 <b>파이썬</b> 프로그래밍을 확실히 익힐 수... "
#
# },
# {
# "title": "<b>파이썬</b>으로 살펴보는 아키텍처 패턴 (TDD, DDD, EDM 적용하기)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20554246",
# "image": "https://bookthumb-phinf.pstatic.net/cover/205/542/20554246.jpg?type=m1&udate=20211207",
# "author": "해리 퍼시벌|밥 그레고리",
# "price": "32000",
# "discount": "28800",
# "publisher": "한빛미디어",
# "pubdate": "20210603",
# "isbn": "1162244313 9791162244319",
# "description": "아키텍처 패턴의 기초부터 활용까지 다루는 실전 가이드\n\n<b>파이썬</b>을 활용한 프로젝트의 규모가 커지면서 육각형/클린 아키텍처, 이벤트 기반 아키텍처... 낮추고, 테스트 스위트에서 최선의 가치를 얻는 방법을 알려준다. 또한 자바나 C#보다 간단하고 우아한 <b>파이썬</b> 코드의 장점을 잘 살려 각 패턴을 설명한다."
#
# },
# {
# "title": "<b>파이썬</b>과 케라스를 이용한 딥러닝/강화학습 주식투자 (퀀트 투자 알고리즘 트레이딩을 위한 최첨단 해법 입문)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16330711",
# "image": "https://bookthumb-phinf.pstatic.net/cover/163/307/16330711.jpg?type=m1&udate=20200418",
# "author": "퀀티랩",
# "price": "28000",
# "discount": "25200",
# "publisher": "위키북스",
# "pubdate": "20200427",
# "isbn": "1158392036 9791158392031",
# "description": "실제 주식 데이터를 이용해 <b>파이썬</b>으로 강화학습 주식투자 프로그램을 직접 구현해 봅니다!강화학습은 스스로 학습하는 머신러닝 기법으로 주식 데이터 학습에 잘 적용되는 기법입니다. 이 책은 <b>파이썬</b>을 이용한 강화학습 기반의 주식투자 시뮬레이션 프로그램 개발에 대해 설명합니다. 이를 위한 이론과 코드... "
#
# },
# {
# "title": "<b>파이썬</b> 코딩 도장",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14144026",
# "image": "https://bookthumb-phinf.pstatic.net/cover/141/440/14144026.jpg?type=m1&udate=20191011",
# "author": "남재윤",
# "price": "25000",
# "discount": "22500",
# "publisher": "길벗",
# "pubdate": "20181130",
# "isbn": "1160506183 9791160506181",
# "description": "외우기만 해서는 <b>파이썬</b>도 어렵다!\n프로그래밍은 연습으로 배우는 것!\n문법을 외우기만 해서는 <b>파이썬</b>도 배우기 어렵다. 프로그래밍은 개념을 습득하고... 최고의 학습은 반복이고, 스스로 생각하기다\n<b>파이썬</b> 문법을 학습한 다음에는 반드시 퀴즈를 풀어보게 했다. 퀴즈를 풀어본 다음에는 반드시 연습문제로... "
#
# },
# {
# "title": "모두의 <b>파이썬</b> (20일 만에 배우는 프로그래밍 기초)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=10541921",
# "image": "https://bookthumb-phinf.pstatic.net/cover/105/419/10541921.jpg?type=m1&udate=20181102",
# "author": "이승찬",
# "price": "12000",
# "discount": "",
# "publisher": "길벗",
# "pubdate": "20160509",
# "isbn": "1186978899 9791186978894",
# "description": "<b>파이썬</b>이 무엇인지 몰라도 상관 없다. 《모두의 <b>파이썬</b>》은 어려운 개념과 복잡한 이론 설명은 최대한 줄이고, 초보자가 프로그래밍을 쉽게 배울 수... 어느새 <b>파이썬</b> 프로그램으로 멋진 그림을 그리고, 계산을 하고, 간단한 게임을 만들고, 수학 문제를 푸는 자신을 발견하게 될 것이다. 《모두의 <b>파이썬</b>》으로... "
#
# },
# {
# "title": "특강마스터 <b>파이썬</b> 마스터 3급",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21348572",
# "image": "https://bookthumb-phinf.pstatic.net/cover/213/485/21348572.jpg?type=m1&udate=20211214",
# "author": "김상민",
# "price": "18000",
# "discount": "16200",
# "publisher": "렉스미디어닷넷",
# "pubdate": "20211201",
# "isbn": "8959604143 9788959604142",
# "description": "[구성 및 특징]ㆍ <b>파이썬</b> 프로그램의 출제 기능을 쉽게 설명ㆍ <b>파이썬</b> 3급 출제 기준을 분석하여 예상 문제 제공ㆍ CBT 모의시험 방법 안내, 모의고사 8회 / 정답 및 해설 제공"
#
# },
# {
# "title": "이것이 데이터 분석이다 with <b>파이썬</b> (<b>파이썬</b>으로 배우는 데이터 분석 입문)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16237901",
# "image": "https://bookthumb-phinf.pstatic.net/cover/162/379/16237901.jpg?type=m1&udate=20210211",
# "author": "윤기태",
# "price": "28000",
# "discount": "25200",
# "publisher": "한빛미디어",
# "pubdate": "20200210",
# "isbn": "1162242515 9791162242513",
# "description": "실생활 예제로 쉽게, 단계별 분석에 따라 구조적으로 배우는 데이터 분석 입문서데이터를 다루는 데 언어나 라이브러리는 도구일 뿐입니다. 진짜 중요한 것은 문제해결 능력입니다. 이 책은 주어진 문제를 어떻게 단계적으로 접근하면 좋을지에 대해 독자 친화적으로 가이드를 주는 책입니다. 프로그래밍 기초... "
#
# },
# {
# "title": "AWS로 시작하는 AI 서비스 with <b>파이썬</b>",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21159306",
# "image": "https://bookthumb-phinf.pstatic.net/cover/211/593/21159306.jpg?type=m1&udate=20211029",
# "author": "이노우에 켄이치",
# "price": "22000",
# "discount": "19800",
# "publisher": "영진닷컴",
# "pubdate": "20211105",
# "isbn": "8931465823 9788931465822",
# "description": "AWS에서 제공하는 AI 서비스를 따라 하며 실제 실무에 적용한다!AWS의 모체인 AMAZON은 세계 제일의 쇼핑 사이트이다. AMAZON 내부에서 다양한 AI가 사용되고 있다는 것은 쉽게 상상할 수 있다. AWS의 AI 서비스는 무척 다양하여 전체를 파악하는 것조차도 상당히 어려울 정도이다. AWS에서는... "
#
# },
# {
# "title": "데이터 과학 기반의 <b>파이썬</b> 빅데이터 분석 (IT@COOKBOOK)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17762418",
# "image": "https://bookthumb-phinf.pstatic.net/cover/177/624/17762418.jpg?type=m1&udate=20210930",
# "author": "이지영",
# "price": "28000",
# "discount": "27440",
# "publisher": "한빛아카데미",
# "pubdate": "20201230",
# "isbn": "1156645077 9791156645078",
# "description": "핵심 <b>파이썬</b> 문법을 배울 수 있습니다.\n4차 산업혁명, 데이터 과학, 빅데이터의 관계를 이해하고 빅데이터 분석에 적용할 데이터 과학 방법론을 배웁니다. 빅데이터 분석에 필요한 핵심 <b>파이썬</b> 문법을 살펴보고 빅데이터 수집 방법으로 유용한 <b>파이썬</b> 크롤링 방법도 실습과 함께 살펴봅니다.\n\n■ 기본 분석부터... "
#
# },
# {
# "title": "<b>파이썬</b>과 데이터 과학 (따라하며 배우는)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17718057",
# "image": "https://bookthumb-phinf.pstatic.net/cover/177/180/17718057.jpg?type=m1&udate=20210509",
# "author": "천인국|박동규|강영민",
# "price": "26000",
# "discount": "25480",
# "publisher": "생능출판",
# "pubdate": "20201228",
# "isbn": "897050477X 9788970504773",
# "description": "최근 가장 빠르게 인기를 얻고 있는 프로그래밍 언어는 바로 <b>파이썬</b>이다. 그 속도는 놀라울 정도로 빠르며, 새롭게 프로그래밍 언어를 배우는 이들이 가장 많이 시작하는 언어로 자리 잡았다. 다른 언어를 주로 사용하던 프로그래머들도 <b>파이썬</b>을 접하고 나서는 자신이 사용하는 프로그래밍 언어 목록에서 <b>파이썬</b>... "
#
# },
# {
# "title": "<b>파이썬</b> 라이브러리를 활용한 머신러닝 (번역개정판,사이킷런 핵심 개발자가 쓴 머신러닝과 데이터 과학 실무서)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14645299",
# "image": "https://bookthumb-phinf.pstatic.net/cover/146/452/14645299.jpg?type=m1&udate=20211207",
# "author": "안드레아스 뮐러|세라 가이도",
# "price": "32000",
# "discount": "28800",
# "publisher": "한빛미디어",
# "pubdate": "20190329",
# "isbn": "1162241640 9791162241646",
# "description": "사이킷런 핵심 개발자에게 배우는 머신러닝 이론과 구현 \n\n현업에서 머신러닝을 연구하고 인공지능 서비스를 개발하기 위해 꼭 학위를 받을 필요는 없습니다. 사이킷런(scikit-learn)과 같은 훌륭한 머신러닝 라이브러리가 복잡하고 난해한 작업을 직관적인 인터페이스로 감싸주는 덕분이죠. 이 책에서는... "
#
# },
# {
# "title": "<b>파이썬</b> GUI 프로그래밍 쿡북 (Tkinter, PyQt5를 활용한 반응형 사용자 인터페이스 개발)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20906006",
# "image": "https://bookthumb-phinf.pstatic.net/cover/209/060/20906006.jpg?type=m1&udate=20211007",
# "author": "부르크하르트 메이어",
# "price": "35000",
# "discount": "31500",
# "publisher": "에이콘출판",
# "pubdate": "20210930",
# "isbn": "1161755713 9791161755717",
# "description": "<b>파이썬</b> 3를 사용해 GUI 프로그래밍 방법을 단계별로 설명한다. 2판의 레시피를 개선해 해당 라이브러리가 왜 필요하고, 어떻게 사용하는지 다양한 분야의 새로운 개념을 쉽게 이해할 수 있도록 설명한다. GUI 관련 기술뿐만 아니라 네트워크, 데이터베이스, 객체지향적 사고에 이르기까지 단계별로 배울 수... "
#
# },
# {
# "title": "고성능 <b>파이썬</b> (<b>파이썬</b> 성능 잠재력을 끌어내는 실용적인 개발 전략서)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=18992661",
# "image": "https://bookthumb-phinf.pstatic.net/cover/189/926/18992661.jpg?type=m1&udate=20211207",
# "author": "미샤 고렐릭|이안 오스발트",
# "price": "36000",
# "discount": "32400",
# "publisher": "한빛미디어",
# "pubdate": "20210510",
# "isbn": "1162244216 9791162244210",
# "description": "<b>파이썬</b>의 성능을 제대로 올려주는 코드 작성법\n\n<b>파이썬</b> 코드가 제대로 동작하더라도 더 빠르게 실행되도록 해야 할 때가 있다. 이 책은 <b>파이썬</b> 3에 맞춰 내용을 보강한 개정판으로, 처리할 데이터 용량이 큰 프로그램의 병목현상을 찾고, 이를 해결해 성능을 향상하는 방법을 알려준다. 프로그램 설계 시 여러 선택... "
#
# },
# {
# "title": "<b>파이썬</b> 딥러닝 머신러닝 입문",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17597510",
# "image": "https://bookthumb-phinf.pstatic.net/cover/175/975/17597510.jpg?type=m1&udate=20210509",
# "author": "오승환",
# "price": "25000",
# "discount": "22500",
# "publisher": "정보문화사",
# "pubdate": "20210105",
# "isbn": "8956749000 9788956749006",
# "description": "아직도 <b>파이썬</b>을 모른다고?&#x0D;&#x0D;이 책은 코드를 직접 입력하고 실행하는 데 필요한 기본적인 환경을 ‘구글 코랩’을 활용하여 <b>파이썬</b>의 가장 기본적인 문법 중 핵심적인 내용만 간단하게 설명한다. 머신러닝과 딥러닝을 직접 경험해보고 싶지만 <b>파이썬</b> 초보자라면 이 책이 적합할 것이다. 데이터를... "
#
# },
# {
# "title": "<b>파이썬</b>을 이용한 데이터 분석의 정석 (넘파이, 판다스, 맷플롯립과 실전 예제로 배우는)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20666311",
# "image": "https://bookthumb-phinf.pstatic.net/cover/206/663/20666311.jpg?type=m1&udate=20210628",
# "author": "채진석",
# "price": "32000",
# "discount": "28800",
# "publisher": "루비페이퍼",
# "pubdate": "20210625",
# "isbn": "1186710705 9791186710708",
# "description": "<b>파이썬</b> 데이터 분석에 필수로 사용되는 라이브러리를 단계적으로 다루어 데이터를 전처리하고 분석하는 능력을 갖춘다. 이 과정에서 넘파이, 판다스, 맷플롯립은 물론 연관 라이브러리까지 상세히 소개한다. 그리고 소개한 라이브러리를 종합하여 활용할 수 있는 세 가지 실전 예제를 담았다."
#
# },
# {
# "title": "<b>파이썬</b> 데이터 분석 실무 테크닉 100 (100가지 예제로 배우는 데이터 가공, 머신러닝, 이미지/자연어 처리의 기술)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16427881",
# "image": "https://bookthumb-phinf.pstatic.net/cover/164/278/16427881.jpg?type=m1&udate=20210509",
# "author": "시모야마 테루마사|마쯔다 유마|미키 타카유키",
# "price": "26000",
# "discount": "23400",
# "publisher": "위키북스",
# "pubdate": "20200730",
# "isbn": "1158392176 9791158392178",
# "description": "《<b>파이썬</b> 데이터 분석 실무 테크닉 100》은 실제 비즈니스 현장에서 마주칠 수 있는 100개의 예제를 풀면서 현장 분위기를 몸에 익히고 현장에 맞게 기술을 응용하는 힘을 기를 수 있게 설계한 문제집입니다.\n\n이 책에 실린 100개의 테크닉을 익힌다고 해서 바로 현장에 적용할 수 있는 것은 아니지만, 현장 감각을... "
#
# },
# {
# "title": "<b>파이썬</b>으로 배우는 게임 개발 (입문편, 미로, 진단 애플리케이션, RPG 등을, 블록 낙하 퍼즐,퀴즈, 주사위)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16851586",
# "image": "https://bookthumb-phinf.pstatic.net/cover/168/515/16851586.jpg?type=m1&udate=20211218",
# "author": "히로세 츠요시",
# "price": "28000",
# "discount": "25200",
# "publisher": "제이펍",
# "pubdate": "20201026",
# "isbn": "1190665441 9791190665445",
# "description": "인기 장르의 게임을 만들며 배우는 <b>파이썬</b> 활용법!\n25년차 현직 게임 프로그래머가 알려 주는 게임 개발 노하우!\n\n<b>파이썬</b>은 초보자도 직관적으로 이해하기... 입문편에서는 <b>파이썬</b>의 기초 규칙을 먼저 안내하고 미로 게임, 블록 낙하 퍼즐, RPG 등의 다양한 게임을 만드는 과정을 설명합니다."
#
# },
# {
# "title": "<b>파이썬</b>으로 배우는 포트폴리오 (금융공학/퀀트 투자의 기초부터 투자 모델, 머신 러닝까지!)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=18121206",
# "image": "https://bookthumb-phinf.pstatic.net/cover/181/212/18121206.jpg?type=m1&udate=20210327",
# "author": "곽승주",
# "price": "26000",
# "discount": "23400",
# "publisher": "길벗",
# "pubdate": "20210315",
# "isbn": "1165214865 9791165214869",
# "description": "포트폴리오, 재무 기초, <b>파이썬</b> 프로그래밍 기술까지\n실제 재무 데이터로 구현하는 이론과 실전의 최적 조합!이 책은 주식 투자에서 위험을 줄이고... 재무 기초, 포트폴리오 이론, 투자 모델을 수학과 그림, <b>파이썬</b> 코드를 사용해 명확히 이해시키고자 했다. <b>파이썬</b>의 기초는 물론 NUMPY, MATPLOTLIB, PANDAS의... "
#
# },
# {
# "title": "C#과 <b>파이썬</b>을 활용한 OpenCV 4 프로그래밍 (컴퓨터 비전 기초 이론부터 머신러닝을 활용한 영상 처리 프로젝트까지)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=18872549",
# "image": "https://bookthumb-phinf.pstatic.net/cover/188/725/18872549.jpg?type=m1&udate=20211207",
# "author": "윤대희",
# "price": "36000",
# "discount": "32400",
# "publisher": "위키북스",
# "pubdate": "20210415",
# "isbn": "1158392559 9791158392550",
# "description": "또한 C#과 <b>파이썬</b>이라는 두 가지 프로그래밍 언어로 구성돼 있어 C#이나 <b>파이썬</b> 개발자분들이 손쉽게 OpenCV를 배울 수 있는 영상처리 입문서입니다.\n\n이 책에서는 OpenCV를 폭넓게 활용할 수 있도록 머신러닝/딥러닝 모듈을 비롯해 Tesseract-OCR과 텐서플로(TensorFlow) 등을 활용해 영상 처리... "
#
# },
# {
# "title": "<b>파이썬</b> 해킹 레시피 (웹 크롤링 및 취약점 진단 도구를 구현해보는 정보 보안 실습)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20579892",
# "image": "https://bookthumb-phinf.pstatic.net/cover/205/798/20579892.jpg?type=m1&udate=20211208",
# "author": "공재웅",
# "price": "26000",
# "discount": "23400",
# "publisher": "비제이퍼블릭",
# "pubdate": "20210604",
# "isbn": "1165920727 9791165920722",
# "description": "이 책에서만 볼 수 있는 <b>파이썬</b> 요리 비법 대공개\n해킹 도구를 <b>파이썬</b>으로 직접 만들며 공부해보자\n\n<b>파이썬</b>은 서버, 머신러닝, 자동화 분야에 이미 광범위하게 이용되고 있어 하나의 언어로 여러 분야에 적용 가능하다. 또한 개발 입문자부터 데이터 분석가, 기업 실무자에 이르기까지 그 수요가 많다.\n이... "
#
# },
# {
# "title": "<b>파이썬</b> Express (파워 유저를 위한)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17526679",
# "image": "https://bookthumb-phinf.pstatic.net/cover/175/266/17526679.jpg?type=m1&udate=20210320",
# "author": "천인국",
# "price": "30000",
# "discount": "29400",
# "publisher": "생능출판",
# "pubdate": "20201120",
# "isbn": "8970504664 9788970504667",
# "description": "<b>파이썬</b>은 현재 가장 각광받는 언어라고 감히 말할 수 있다. 최근에 인공지능이나 데이터 과학, 영상 처리 분야는 <b>파이썬</b>으로 프로그램을 작성하는 것이 거의 표준으로 되어 있다. 해가 갈수록 <b>파이썬</b> 활용이 폭발적으로 늘어나고 있다.&#x0D;&#x0D;필자가 보기에 <b>파이썬</b>은 두 얼굴을 가진 언어인 거 같다. 쉽게... "
#
# },
# {
# "title": "<b>파이썬</b>으로 만드는 인공지능",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17848721",
# "image": "https://bookthumb-phinf.pstatic.net/cover/178/487/17848721.jpg?type=m1&udate=20211207",
# "author": "오일석|이진석",
# "price": "31000",
# "discount": "30380",
# "publisher": "한빛아카데미",
# "pubdate": "20210105",
# "isbn": "1156645085 9791156645085",
# "description": "이론과 실습으로 배우는 인공지능과 딥러닝\n\n인공지능 이론을 79개의 <b>파이썬</b> 프로그램으로 실습하며 배우는 책입니다. 컨볼루션 신경망, 순환 신경망, 강화 학습 등의 인공지능 핵심 이론을 다양한 예시와 수식, 그래프를 통해 학습할 수 있습니다. 또한 로봇 기자, 집 지킴이, 비트코인 가격 예측, 동요 편곡, 패션... "
#
# },
# {
# "title": "<b>파이썬</b>으로 하는 데브옵스 (자동화, 클라우드, 머신러닝, 데이터 엔지니어링까지)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20626882",
# "image": "https://bookthumb-phinf.pstatic.net/cover/206/268/20626882.jpg?type=m1&udate=20210813",
# "author": "노아 기프트|케네디 베어먼|알프레도 데자|그릭 게오르규",
# "price": "40000",
# "discount": "36000",
# "publisher": "에이콘출판",
# "pubdate": "20210630",
# "isbn": "1161755381 9791161755380",
# "description": "<b>파이썬</b>을 통해 데브옵스를 가장 효율적으로 실천할 수 있는 방법을 구체적인 사례와 함께 설명한다. 특히 CI/CD, 모니터링, 테스트 자동화 등 데브옵스 전문가에게 필요한 다양한 업무와 더 나아가 클라우드와 머신러닝에 이르기까지 <b>파이썬</b>을 활용해 얼마나 다양하고 가치 있는 일을 할 수 있는지 배울 수 있다."
#
# },
# {
# "title": "직장인을 위한 데이터 분석 실무 with <b>파이썬</b> (마케팅, 영업, 기획 실무 담당자를 위한 데이터 분석의 기술)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17134126",
# "image": "https://bookthumb-phinf.pstatic.net/cover/171/341/17134126.jpg?type=m1&udate=20201106",
# "author": "이형석|장남수|전상환|정상욱",
# "price": "28000",
# "discount": "25200",
# "publisher": "위키북스",
# "pubdate": "20201112",
# "isbn": "1158392281 9791158392284",
# "description": "이 책은 <b>파이썬</b>을 처음 접하는 마케팅, 영업, 기획 실무 담당자들이 <b>파이썬</b>을 활용한 데이터 분석에 재미있게 빠져들 수 있도록 실제 업무에 활용할 수 있거나 흥미로운 예제로 구성돼 있습니다. 이 책을 마치고 나면 데이터를 기반으로 좋은 질문에 답할 수 있는 실력을 키울 수 있을 것입니다.\n\n★ 이 책에서... "
#
# },
# {
# "title": "<b>파이썬</b> 딥러닝 텐서플로",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20740822",
# "image": "https://bookthumb-phinf.pstatic.net/cover/207/408/20740822.jpg?type=m1&udate=20210708",
# "author": "오승환|이경록|김태헌|홍재권",
# "price": "27000",
# "discount": "24300",
# "publisher": "정보문화사",
# "pubdate": "20210630",
# "isbn": "8956749094 9788956749099",
# "description": "파트1에서는 <b>파이썬</b> 코드를 직접 실행할 수 있는 개발 환경을 설정하는 방법을 소개한다. 파트2에서는 텐서플로의 특징과 텐서플로에서 데이터를 처리하는 기본 자료형인 텐서에 대해 설명한다. 파트3에서는 딥러닝 프레임워크 중에서도 텐서플로 케라스에 대해 설명한다. 또한 인공신경망 구조를 정의하고... "
#
# },
# {
# "title": "400제로 배우는 <b>파이썬</b> 입문 (취업 성공을 위한 속성 프로세스 + 400제 plus)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21154037",
# "image": "https://bookthumb-phinf.pstatic.net/cover/211/540/21154037.jpg?type=m1&udate=20211207",
# "author": "김범준",
# "price": "28000",
# "discount": "25200",
# "publisher": "심통",
# "pubdate": "20211029",
# "isbn": "1197529527 9791197529528",
# "description": "400제 plus로 <b>파이썬</b> 활용 능력 키우기!  \n\n핵심 문법을 배우고 400여 개의 예제를 하나하나 만들어 가다 보면 <b>파이썬</b>을 마음대로 활용할 수 있도록 구성하였습니다!\n\n1 챕터 시작 전, 맛보기 예제로 워밍업\n맛보기 예제를 일단 따라하다 보면 이 챕터에서 배울 핵심 내용을 미리 익힐 수 있습니다.\n\n2 상세한 소스... "
#
# },
# {
# "title": "처음 시작하는 <b>파이썬</b> (<b>파이썬</b> 패키지를 활용한 모던 컴퓨팅 입문)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16588295",
# "image": "https://bookthumb-phinf.pstatic.net/cover/165/882/16588295.jpg?type=m1&udate=20201012",
# "author": "빌 루바노빅",
# "price": "36000",
# "discount": "32400",
# "publisher": "한빛미디어",
# "pubdate": "20200824",
# "isbn": "1162243333 9791162243336",
# "description": "전 세계 1등 언어 <b>파이썬</b>을 <b>파이썬</b>답게 쓰게 해주는 최고의 안내서이 책은 프로그래밍을 막 시작하는 입문자나, 이미 다른 프로그래밍 언어를 학습한 개발자가 <b>파이썬</b>을 쉽고 빠르게 배울 수 있게 안내한다. 1판과 다르게 2판은 1부와 2부로 나뉘었다. 1부에서는 테스팅, 디버깅, 코드 재사용 방법, 기타... "
#
# },
# {
# "title": "머신 러닝·딥 러닝에 필요한 기초 수학 with <b>파이썬</b>",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16890922",
# "image": "https://bookthumb-phinf.pstatic.net/cover/168/909/16890922.jpg?type=m1&udate=20211207",
# "author": "조준우",
# "price": "27000",
# "discount": "24300",
# "publisher": "인사이트",
# "pubdate": "20201104",
# "isbn": "8966262856 9788966262854",
# "description": "<b>파이썬</b> 등 프로그래밍 도구를 이용하여 배운 수학 개념을 눈으로 확인해 볼 수 있게 하였습니다.\n수학과 실제 작업을 단단하게 연결하는 경험을 통해서 앞으로 새로운 알고리즘을 공부할 때도 스스로 학습할 수 있는 능력을 기를 수 있도록 하였습니다."
#
# },
# {
# "title": "누구나 <b>파이썬</b> 통계분석",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16328841",
# "image": "https://bookthumb-phinf.pstatic.net/cover/163/288/16328841.jpg?type=m1&udate=20201024",
# "author": "타니아이 히로키",
# "price": "26000",
# "discount": "23400",
# "publisher": "한빛아카데미",
# "pubdate": "20200406",
# "isbn": "1156644887 9791156644880",
# "description": "<b>파이썬</b>을 활용하면 복잡한 수식이 없이도 통계분석을 할 수 있습니다!\n책을 따라 실습하다 보면 어느새 통계분석을 하는 자신을 발견하게 됩니다.\n\n이런 분들이 보면 더 좋습니다.\n■ <b>파이썬</b>을 사용해 통계분석을 공부하고 싶다.\n■ <b>파이썬</b>의 기초는 배웠지만, 이어서 공부할 내용을 찾지 못했다.\n■ 통계분석에... "
#
# },
# {
# "title": "두근두근 <b>파이썬</b> (쉽고! 재밌고! 흥미로운 코딩 맛!)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=11573148",
# "image": "https://bookthumb-phinf.pstatic.net/cover/115/731/11573148.jpg?type=m1&udate=20210129",
# "author": "천인국",
# "price": "24000",
# "discount": "22800",
# "publisher": "생능출판",
# "pubdate": "20170116",
# "isbn": "8970508937 9788970508931",
# "description": "『두근두근 <b>파이썬</b>』은 프로그래밍을 처음 시작하는 학습자도 쉽게 따라올 수 있도록 변수, 조건문, 반복문, 함수 등의 기본적인 프로그래밍 개념을 자세히 설명하여 탄탄한 기초를 만들 수 있다. 또한, 적절한 그림을 가능한 많이 사용하여 더욱 친숙하고, 지루하지 않으며 독자들이 이해하기 쉬우며... "
#
# },
# {
# "title": "시간순삭 <b>파이썬</b>",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16625087",
# "image": "https://bookthumb-phinf.pstatic.net/cover/166/250/16625087.jpg?type=m1&udate=20210509",
# "author": "천인국|정영민|최자영",
# "price": "22000",
# "discount": "19800",
# "publisher": "생능출판",
# "pubdate": "20200827",
# "isbn": "8970504656 9788970504650",
# "description": "다루는 친근한 소재를 융합적으로 다루어 실습 예제인 LAB으로 제공하고 있다. 이 책을 읽게 된다면 <b>파이썬</b>이 얼마나 재미있는 프로그래밍 언어인지 알게 될 것이다! 또한 코딩 플랫폼 ‘엘리스 아카데미(HTTPS://ACADEMY.ELICE..IO/COURSES/5056/INFO)’를 통해 책에 있는 모든 예제를 직접 실습해볼 수 있습니다."
#
# },
# {
# "title": "엑셀과 비교하며 배우는 <b>파이썬</b> 데이터 분석",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20596443",
# "image": "https://bookthumb-phinf.pstatic.net/cover/205/964/20596443.jpg?type=m1&udate=20210608",
# "author": "장쥔홍",
# "price": "24000",
# "discount": "21600",
# "publisher": "제이펍",
# "pubdate": "20210617",
# "isbn": "1191600114 9791191600117",
# "description": "어떠한 데이터이든지 처리하고 정리하여 일목요연하게 파악하기 쉽도록 만들어주는 최고의 툴인 엑셀과 <b>파이썬</b>을, 둘 중 어느 것도 놓치지 않고 두 도구의 장점만을 취해 데이터 처리와 분석을 효과적으로 쉽게 해낼 수 있도록 해줍니다. 이 책과 함께라면 데이터를 다루는 그 어떤 업무에서도 빠르고 효율적으로... "
#
# },
# {
# "title": "<b>파이썬</b>을 이용한 알고리즘 트레이딩 (아이디어 도출부터 클라우드 배포까지)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20764338",
# "image": "https://bookthumb-phinf.pstatic.net/cover/207/643/20764338.jpg?type=m1&udate=20210819",
# "author": "이브스 힐피쉬",
# "price": "29000",
# "discount": "26100",
# "publisher": "제이펍",
# "pubdate": "20210729",
# "isbn": "1191600106 9791191600100",
# "description": "'<b>파이썬</b>을 이용한 알고리즘 트레이딩'이라는 주제와 관련해서 말하자면, 이 정도로 넓고 깊게 다루는... <b>파이썬</b>과 이와 관련된 강력한 패키지 생태계는 오늘날 수많은 트레이더가 선택하는 필수 도구가... 분야에서 <b>파이썬</b>을 활용하는 방법을 보여줍니다.또한, 이 책은 자동화한 알고리즘 트레이딩 전략을... "
#
# },
# {
# "title": "<b>파이썬</b> 2학년 스크래핑의 구조 (체험으로 배우고! 대화 형식으로 공부!,Python)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21259836",
# "image": "https://bookthumb-phinf.pstatic.net/cover/212/598/21259836.jpg?type=m1&udate=20211111",
# "author": "모리 요시나오",
# "price": "17000",
# "discount": "15300",
# "publisher": "성안당",
# "pubdate": "20211117",
# "isbn": "8931556896 9788931556896",
# "description": "데이터 수집이나 해석, 분석에 대해 알기 쉽게 설명!<b>파이썬</b>은 인공지능의 기초 언어로 배우기 쉬우면서 각종 데이터 분석에 사용되는 프로그래밍 언어로 절정의 인기를 누리고 있다. 기존이 <b>파이썬</b>... 하는데, <b>파이썬</b>은 인터넷에 액세스할 수 있는 라이브러리가 풍부해 이 두가지 모두 쉽고 편하게 할 수... "
#
# },
# {
# "title": "전문가를 위한 <b>파이썬</b> (간단하고, 명료하고, 효율적인 <b>파이썬</b> 프로그래밍,<b>파이썬</b>3 버전 기준)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=10910543",
# "image": "https://bookthumb-phinf.pstatic.net/cover/109/105/10910543.jpg?type=m1&udate=20211210",
# "author": "루시아누 하말류",
# "price": "55000",
# "discount": "49500",
# "publisher": "한빛미디어",
# "pubdate": "20160812",
# "isbn": "8968484988 9788968484988",
# "description": "<b>파이썬</b> 기능을 활용하여, 효율적인 <b>파이썬</b> 코드 작성 방법을 제시하는 실용 안내서『전문가를 위한 <b>파이썬</b>』. 이 책은 특히 다른 언어에서는 찾아볼 수 없는 <b>파이썬</b> 고유의 기능을 중점적으로 살펴본다. <b>파이썬</b>의 핵심 요소 및 주요 기본 라이브러리도 기본에 충실하게 소개한다."
#
# },
# {
# "title": "똑똑한 <b>파이썬</b> (주니어를 위한 최적의 코딩 학습서)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20567964",
# "image": "https://bookthumb-phinf.pstatic.net/cover/205/679/20567964.jpg?type=m1&udate=20210602",
# "author": "황재호|황예린",
# "price": "18000",
# "discount": "16200",
# "publisher": "인포앤북",
# "pubdate": "20210601",
# "isbn": "1196440980 9791196440985",
# "description": "이 책은 2019년 출간된 『똑똑한 <b>파이썬</b>』의 개정판으로 <b>파이썬</b>이 처음인 초중학생을 대상으로 문제 풀이 위주로 <b>파이썬</b>을 재미있게 공부할 수 있도록 고안되었습니다. 이번 개정판에서는 기존의 책이 가지고 있던 장점인 아이들에게 친근한 일러스트 편집, 쉬운 예제 중심의 학습 등은 그대로 유지하고... "
#
# },
# {
# "title": "<b>파이썬</b>으로 완성하는 비지도 학습 알고리즘 (비감독 모형과 텐서플로 2를 이용한 전처리 기법의 머신러닝 구현)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21376355",
# "image": "https://bookthumb-phinf.pstatic.net/cover/213/763/21376355.jpg?type=m1&udate=20211222",
# "author": "송동근",
# "price": "34000",
# "discount": "30600",
# "publisher": "비제이퍼블릭",
# "pubdate": "20211130",
# "isbn": "1165921103 9791165921101",
# "description": "다양한 비지도 학습 문제들을이제 실제 <b>파이썬</b> 코드로 구현한다!실제 이론을 코드로 구현하는 데에는... 나누고 <b>파이썬</b> 코드로 단계별 결과들을 최대한 상세하게 다루었다.또한 텐서플로 2의 오토 인코더와... 이 책이 필요한 독자- <b>파이썬</b>을 데이터 분석에 활용하고자 하는 분- 비지도 학습에 대해 더 자세히... "
#
# },
# {
# "title": "<b>파이썬</b> for Beginner (쉽고 빠르게 익히는 프로그래밍의 기본 원리)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=15871779",
# "image": "https://bookthumb-phinf.pstatic.net/cover/158/717/15871779.jpg?type=m1&udate=20210902",
# "author": "우재남",
# "price": "23000",
# "discount": "22540",
# "publisher": "한빛아카데미",
# "pubdate": "20200106",
# "isbn": "1156644666 9791156644668",
# "description": "다양한 예제와 프로젝트를 활용해 초보자도 쉽게 프로그래밍의 기본을 익힐 수 있는 <b>파이썬</b> 입문서. 문법을 사전식으로 나열하지 않고 작지만 기능적인 프로그램을 하나씩 완성하면서 익힐 수 있게 구성했다. 단계별로 완성하는 프로젝트를 바탕으로 자신만의 그럴듯한 프로그램도 완성할 수 있다.\n\nIT... "
#
# },
# {
# "title": "<b>파이썬</b>으로 배우는 알고리즘 트레이딩 (내 손으로 만드는 자동 주식 거래 시스템)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14623546",
# "image": "https://bookthumb-phinf.pstatic.net/cover/146/235/14623546.jpg?type=m1&udate=20211206",
# "author": "조대표",
# "price": "40000",
# "discount": "36000",
# "publisher": "위키북스",
# "pubdate": "20190307",
# "isbn": "1158391463 9791158391461",
# "description": "이 책은 <b>파이썬</b>이라는 프로그래밍 언어를 이용한 알고리즘 트레이딩을 다룹니다. 프로그래밍을 전혀 모르는 비전공자나 HTS(Home Trading System)로 주식 투자 정도만 할 수 있는 일반인도 빠르게 <b>파이썬</b>과 알고리즘 트레이딩을 배울 수 있는 알고리즘 트레이딩 입문서입니다.\n\n<b>파이썬</b> 기초 문법에 대한... "
#
# },
# {
# "title": "<b>파이썬</b>과 리액트를 활용한 주식 자동 거래 시스템 구축 (데이터 수집부터 거래 자동화, API 서버, 웹 개발, 데이터 분석까지 아우르는)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16241301",
# "image": "https://bookthumb-phinf.pstatic.net/cover/162/413/16241301.jpg?type=m1&udate=20210509",
# "author": "박재현",
# "price": "28000",
# "discount": "25200",
# "publisher": "위키북스",
# "pubdate": "20200212",
# "isbn": "1158391889 9791158391881",
# "description": "<b>파이썬</b>을 이용해 데이터를 수집, 저장, 가공, 분석하는 방법부터 리액트를 이용해 사용자의 화면까지 개발하는 방법까지 한 권에 담았다. 이 책을... ★ 이 책에서 다루는 내용 ★\n◎ 증권사(이베스트)에서 제공하는 API를 이용해 <b>파이썬</b>으로 거래 자동화 시스템을 개발한다.\n◎ 외부로 기능을 제공하기 위한... "
#
# },
# {
# "title": "IT 비전공자를 위한 돈 버는 <b>파이썬</b> 코딩 (N잡러 자동부업 수익창출)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20938214",
# "image": "https://bookthumb-phinf.pstatic.net/cover/209/382/20938214.jpg?type=m1&udate=20211025",
# "author": "비현코",
# "price": "18000",
# "discount": "16200",
# "publisher": "디지털북스",
# "pubdate": "20211010",
# "isbn": "8960883808 9788960883802",
# "description": "그러나 수학과 담을 쌓은 문과, 인문, 비전공자라면 나와는 상관 없는, 남의 나라 남의 이야기처럼 들릴 것이다.본 도서는 코딩으로 <b>파이썬</b>을 배운다는... 싶은데, 회사는 다녀야겠고, 내가 잠자는 동안에도 내가 일하는 동안에도, 나 대신 ‘코딩’으로 무엇인가 수익을 창출하는 수단으로써 <b>파이썬</b> 코딩을 접근한다."
#
# },
# {
# "title": "<b>파이썬</b> 스킬 업 (기초를 넘어서, <b>파이썬</b>을 <b>파이썬</b>답게 사용하자!)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20569414",
# "image": "https://bookthumb-phinf.pstatic.net/cover/205/694/20569414.jpg?type=m1&udate=20211207",
# "author": "브라이언 오버랜드|존 베넷",
# "price": "40000",
# "discount": "36000",
# "publisher": "길벗",
# "pubdate": "20210531",
# "isbn": "1165215675 9791165215675",
# "description": "기초를 넘어서, <b>파이썬</b> 고수로 성장하는 첫걸음!\n런타임 효율성, 고급 문법, 람다 함수, 정규표현식... 이 책으로 <b>파이썬</b> 전체 기본 문법을 깊은 수준으로 처음부터 끝까지 훑어보면서 그 과정에서 학습한... 또한, 스킬 업할 수 있는 다양한 주제들도 함께 설명하므로 <b>파이썬</b> 기초를 익힌 후 다음 단계로 나아가고... "
#
# },
# {
# "title": "엑셀 × <b>파이썬</b> 업무 자동화 (매크로, VBA는 이제 낡았다!)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17468044",
# "image": "https://bookthumb-phinf.pstatic.net/cover/174/680/17468044.jpg?type=m1&udate=20210217",
# "author": "카네히로 카즈미",
# "price": "18000",
# "discount": "16200",
# "publisher": "인사이트",
# "pubdate": "20201203",
# "isbn": "8966262848 9788966262847",
# "description": "- 2020년 일본 아마존 IT 분야 최고의 베스트셀러 -이 책은 업무에서 가장 많이 사용하는 엑셀을 <b>파이썬</b>으로... 이제 누구나 쉽게 배울 수 있고, 확장성도 뛰어난 <b>파이썬</b>으로 회사 업무에 활력을 불어넣자.\n\n이 책의 특징\n1. 반복 업무만 줄여도 업무 시간을 반으로\n반복적인 엑셀 수작업을 <b>파이썬</b>으로 순식간에... "
#
# },
# {
# "title": "<b>파이썬</b> 입문 (예제 중심)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16328732",
# "image": "https://bookthumb-phinf.pstatic.net/cover/163/287/16328732.jpg?type=m1&udate=20210509",
# "author": "황재호",
# "price": "25000",
# "discount": "22500",
# "publisher": "인포앤북",
# "pubdate": "20200601",
# "isbn": "1196440921 9791196440923",
# "description": "알지만 <b>파이썬</b>은 처음인 분을 대상으로 내용이 구성되었습니다. 이 책은 두 단계로 구성되어 있습니다. 첫 단계에서는 변수, 데이터 형, 조건문, 반복문, 함수, 리스트, 튜플, 딕셔너리, 객체지향 등의 <b>파이썬</b> 기초를 익힙니다. 그리고 두 번째 단계에서는 Numpy, Pandas, Matplotlib의 <b>파이썬</b> 패키지를 이용하여... "
#
# },
# {
# "title": "<b>파이썬</b> 프로그래밍 (데이터 과학을 위한)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14412454",
# "image": "https://bookthumb-phinf.pstatic.net/cover/144/124/14412454.jpg?type=m1&udate=20211209",
# "author": "최성철",
# "price": "25000",
# "discount": "24500",
# "publisher": "한빛아카데미",
# "pubdate": "20190101",
# "isbn": "1156644364 9791156644361",
# "description": "데이터 과학을 기반으로 쉽게 배우는 <b>파이썬</b> 프로그래밍\n\n《데이터 과학을 위한 <b>파이썬</b> 프로그래밍》은 K-MOOC 공개강좌인 최성철 교수의 ‘데이터 과학을 위한 <b>파이썬</b>’ 강의를 기반으로 집필하였습니다. \n\n이 책은 <b>파이썬</b>으로 프로그래밍을 시작하는 입문자가 쉽게 이해할 수 있도록 기본 개념을 상세하게... "
#
# },
# {
# "title": "윤성우의 열혈 <b>파이썬</b> 기초편",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14261211",
# "image": "https://bookthumb-phinf.pstatic.net/cover/142/612/14261211.jpg?type=m1&udate=20210509",
# "author": "윤성우",
# "price": "16000",
# "discount": "14400",
# "publisher": "오렌지미디어",
# "pubdate": "20181120",
# "isbn": "8996094080 9788996094081",
# "description": "누구나 쉽게 공부할 수 있는 <b>파이썬</b>의 기초를 설명한다.\n<b>파이썬</b> 3을 기본으로 코딩 경험이 없는 초보자에게 <b>파이썬</b>을 설명합니다.그러나 이 책의 내용만 다 공부하더라도 기본적인 <b>파이썬</b> 활용이 가능한 수준에 이를 수 있습니다.\n또한 연계해서 출간되는 책들을 통해 학습을 이어 나갈 수 있다는 장점도... "
#
# },
# {
# "title": "<b>파이썬</b>으로 웹 크롤러 만들기 (초간단 나만의 웹 크롤러로 원하는 데이터를 가져오는 방법)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14649485",
# "image": "https://bookthumb-phinf.pstatic.net/cover/146/494/14649485.jpg?type=m1&udate=20210113",
# "author": "라이언 미첼",
# "price": "25000",
# "discount": "22500",
# "publisher": "한빛미디어",
# "pubdate": "20190329",
# "isbn": "1162241632 9791162241639",
# "description": "필요한 무기는 이 책과 <b>파이썬</b>뿐. BEAUTIFULSOUP, 셀레니움, 테서랙트 등 강력한 <b>파이썬</b> 라이브러리 사용법과 함께 API, 인증, 이미지 및 텍스트 인식, 로그인 처리 등 웹 크롤링의 기초부터 고급 기법까지 종합적으로 다루는 유일한 책. 실제 업무와 생활에 적용할 수 있는 예제가 가득하다. 2판은 예제를 추가... "
#
# },
# {
# "title": "<b>파이썬</b> 챌린지 (150개의 코딩 과제로 배운다)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20477376",
# "image": "https://bookthumb-phinf.pstatic.net/cover/204/773/20477376.jpg?type=m1&udate=20211208",
# "author": "니콜라 레이시",
# "price": "11200",
# "discount": "10080",
# "publisher": "제이펍",
# "pubdate": "20210512",
# "isbn": "1191600017 9791191600018",
# "description": "150개의 챌린지(코딩 과제)로 배우는 <b>파이썬</b> 코딩!\n\n영국의 캠브리지 대학교에서 출판한 이 책은 핵심 위주의 문법 설명. 그리고 그 문법 이해를 도와주는 간결한 예제, 이어서 독자들의 도전 의식을 자극하는 150개의 코딩 챌린지(도전 과제)가 이어지는 구성을 취하고 있습니다. 난이도가 점차 높아지는 150개의... "
#
# },
# {
# "title": "게임으로 배우는 <b>파이썬</b>",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14641076",
# "image": "https://bookthumb-phinf.pstatic.net/cover/146/410/14641076.jpg?type=m1&udate=20190315",
# "author": "다나카 겐이치로",
# "price": "17000",
# "discount": "15300",
# "publisher": "영진닷컴",
# "pubdate": "20190329",
# "isbn": "893145998X 9788931459982",
# "description": "게임을 만들며 즐겁게 배우는 <b>파이썬</b> 프로그래밍<b>파이썬</b>은 머신러닝과 AI 등 최첨단의 분야에서 주목받고 있으며, 프로그래밍의 원리를 배우기 위한... 이 책에서는 간단한 게임을 직접 만들어 보면서 쉽고 재미있게 <b>파이썬</b>을 배웁니다. 기초편에서는 <b>파이썬</b> 문법과 PYGAME 등 기초 지식에 대해서 설명하고... "
#
# },
# {
# "title": "<b>파이썬</b> for Beginner (쉽고 빠르게 익히는 프로그래밍의 기본 원리)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21371083",
# "image": "https://bookthumb-phinf.pstatic.net/cover/213/710/21371083.jpg?type=m1&udate=20211221",
# "author": "우재남",
# "price": "25000",
# "discount": "22500",
# "publisher": "한빛아카데미",
# "pubdate": "20220103",
# "isbn": "1156645743 9791156645740",
# "description": "일단 따라하면 바로 이해되는 <b>파이썬</b> 프로그래밍\n<b>파이썬</b>을 처음 접하는 독자를 대상으로 일대일 수업처럼 자세히 설명한 책입니다.\n꼭 알아야 할 핵심... 일단 코드를 입력하고 실행하다 보면 어느새 <b>파이썬</b> 프로그래밍과 친숙해져 있을 것입니다!\n※ 본 도서는 대학 강의용 교재로 개발되었으므로 연습문제... "
#
# },
# {
# "title": "<b>파이썬</b> 웹 프로그래밍 (Django장고로 배우는 쉽고 빠른 웹 개발)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=13878877",
# "image": "https://bookthumb-phinf.pstatic.net/cover/138/788/13878877.jpg?type=m1&udate=20211208",
# "author": "김석훈",
# "price": "22000",
# "discount": "19800",
# ...
#
# },
# {
# "title": "난생처음 컴퓨팅 사고 with <b>파이썬</b>",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17717718",
# "image": "https://bookthumb-phinf.pstatic.net/cover/177/177/17717718.jpg?type=m1&udate=20210828",
# "author": "김명호",
# "price": "23000",
# "discount": "22540",
# "publisher": "한빛아카데미",
# "pubdate": "20210105",
# "isbn": "1156645212 9791156645214",
# "description": "우선 컴퓨팅 사고의 의미를 이해하고 알고리즘을 표현하는 방법을 배운 후에 <b>파이썬</b> 문법을 다룬다. 또한 컴퓨팅 사고력과 코딩 실력을 함께 기르기 위하여 4개의 미니 프로젝트를 제공한다. 컴퓨팅 사고와 <b>파이썬</b>이 처음이더라도 188개의 예제를 따라 하다보면 어느새 프로그래밍 실력과 문제 해결 실력이... "
#
# },
# {
# "title": "윤성우의 열혈 <b>파이썬</b> 중급편",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=15658995",
# "image": "https://bookthumb-phinf.pstatic.net/cover/156/589/15658995.jpg?type=m1&udate=20210422",
# "author": "윤성우",
# "price": "16000",
# "discount": "14400",
# "publisher": "오렌지미디어",
# "pubdate": "20191029",
# "isbn": "8996094099 9788996094098",
# "description": "윤성우의 열혈 <b>파이썬</b> 기초편 이후를 말합니다.\n이미 출간되어서 좋은 평가를 받고 있는 '열혈 <b>파이썬</b> 기초편'의 뒤를 잇는 내용의 서적입니다. <b>파이썬</b>을 조금 더 알고 싶어하는 이들을 대상으로 내용이 구성되어 있기 때문에 이전에 저자가 출간한 <b>파이썬</b> 기초편에 준하는 수준의 기본 지식이 있다면 즐겁고... "
#
# },
# {
# "title": "금융 <b>파이썬</b> 쿡북 (금융 데이터 처리와 기술 분석부터 딥러닝 적용까지)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17932118",
# "image": "https://bookthumb-phinf.pstatic.net/cover/179/321/17932118.jpg?type=m1&udate=20210406",
# "author": "에릭 르윈슨",
# "price": "35000",
# "discount": "31500",
# "publisher": "에이콘출판",
# "pubdate": "20210210",
# "isbn": "1161750509 9791161750507",
# "description": "금융 데이터 처리와 기술 분석부터 딥러닝 적용까지\n금융 <b>파이썬</b> 쿡북<b>파이썬</b>은 금융에서 가장 보편적으로 사용되는 언어이면서 방대한 라이브러리를 갖고 있다. 금융 데이터를 다운로드하는 다양한 방법과 모델링을 위해 준비하는 기법을 알려준다. 기술분석에 사용되는 볼린저 밴드, MACD, RSI 그리고... "
#
# },
# {
# "title": "모두의 알고리즘 with <b>파이썬</b> (컴퓨팅 사고를 위한 기초 알고리즘)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=12057147",
# "image": "https://bookthumb-phinf.pstatic.net/cover/120/571/12057147.jpg?type=m1&udate=20210508",
# "author": "이승찬",
# "price": "16000",
# "discount": "14400",
# "publisher": "길벗",
# "pubdate": "20170518",
# "isbn": "1160501726 9791160501728",
# "description": "《모두의 알고리즘 with <b>파이썬</b>》은 중요하지만 어려운 주제인 알고리즘을 초보자와 비전공자가 배울 수 있게 최대한 전문 용어와 복잡한 수학을 사용하지 않고 설명한다. 또한, 간단한 문제를 풀면서 기초 알고리즘을 설명하기 때문에 쉽게 이해할 수 있다. 그동안 알고리즘을 배우고 싶었지만, 어려워서... "
#
# },
# {
# "title": "Introduction to <b>파이썬</b> (338 예제로 완성하는 <b>파이썬</b>)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17854273",
# "image": "https://bookthumb-phinf.pstatic.net/cover/178/542/17854273.jpg?type=m1&udate=20211208",
# "author": "황재호",
# "price": "25000",
# "discount": "22500",
# "publisher": "인포앤북",
# "pubdate": "20210301",
# "isbn": "1196440948 9791196440947",
# "description": "338 예제로 <b>파이썬</b>을 정복하자!\n<b>파이썬</b> 초보를 위한 최선의 학습서!\n\n이 책은 다양한 난이도의 예제를 재미있게 풀어보면서 자연스럽게 <b>파이썬</b> 프로그래밍의 기초와 활용 방법을 익힐 수 있도록 고안되었습니다. 프로그래밍을 처음 접하는 초보자나 다른 컴퓨터 언어는 어느 정도 알지만 <b>파이썬</b>은 처음인 분을... "
#
# },
# {
# "title": "<b>파이썬</b>으로 배우는 컴퓨팅 사고 (문제해결 중심의 <b>파이썬</b> 프로그래밍)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14618518",
# "image": "https://bookthumb-phinf.pstatic.net/cover/146/185/14618518.jpg?type=m1&udate=20200304",
# "author": "김완섭",
# "price": "17000",
# "discount": "16150",
# "publisher": "인피니티북스",
# "pubdate": "20200212",
# "isbn": "1185578439 9791185578439",
# "description": "<b>파이썬</b>은 프로그래밍 초보자가 사용하기에 매우 적합한 언어이다. 다른 언어에 비해 쉽기 때문에 자신도... 소프트웨어 분야에 호기심이 있고, 프로그래밍 언어에 관심이 있다면 <b>파이썬</b>으로 시작하는 게 정답일 것이다.\n\n그러나 쉬운 초보자용 언어라고 가볍게 생각하면 안 된다. <b>파이썬</b>은 쉬울 뿐만 아니라 매우... "
#
# },
# {
# "title": "<b>파이썬</b> 웹프로그래밍 실전편 (Django장고를 활용한 쉽고 빠른 웹 개발)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=15654623",
# "image": "https://bookthumb-phinf.pstatic.net/cover/156/546/15654623.jpg?type=m1&udate=20191202",
# "author": "김석훈",
# "price": "32000",
# "discount": "28800",
# "publisher": "한빛미디어",
# "pubdate": "20191101",
# "isbn": "1162242264 9791162242261",
# "description": "이 책이 제시하는 핵심 내용\n장고 프레임워크를 사용해서 상용화 수준의 앱을 만들고, 앱의 기능을 확장하고, 클라우드 서버에서 배포하는 것까지 다룬다."
#
# },
# {
# "title": "구글과 <b>파이썬</b>으로 시작하는 보안 (취약점은 이제 끝! 실전 예제와 코드로 배우는 데이터 보호)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20870356",
# "image": "https://bookthumb-phinf.pstatic.net/cover/208/703/20870356.jpg?type=m1&udate=20210910",
# "author": "김용재",
# "price": "33000",
# "discount": "29700",
# "publisher": "비제이퍼블릭",
# "pubdate": "20210831",
# "isbn": "1165920816 9791165920814",
# "description": "보여주는 <b>파이썬</b> 예제들로 구성되어 있습니다. 예제들을 통해 보안에서 <b>파이썬</b>을 어떻게 응용할지에 대한 아이디어를 얻고 책 전반을 통해 보안, 개인... - <b>파이썬</b> 코드를 통해 데이터의 흐름을 보며 좀더 직관적으로 이해할 수 있다.- 보안이 가진 원초적인 불완전함을 극복하기 위해 해야 될 노력들에... "
#
# },
# {
# "title": "<b>파이썬</b> 마스터 1·2급",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21223572",
# "image": "https://bookthumb-phinf.pstatic.net/cover/212/235/21223572.jpg?type=m1&udate=20211030",
# "author": "유성열",
# "price": "22000",
# "discount": "19800",
# "publisher": "명진씨앤피",
# "pubdate": "20211101",
# "isbn": "8992561520 9788992561525",
# "description": "<b>파이썬</b>에 대한 전문지식과 IT서비스 및 인프라 구축의 모든 것을 담았다〈<b>파이썬</b>의 기본 개념부터 심화 학습까지, <b>파이썬</b> 마스터로의 도약을 꿈꾸다〉<b>파이썬</b>은 초보자부터 전문가까지 넓은 사용자층을 보유하고 있다. 누구나 쉽게 접근할 수 있을 뿐 아니라 대부분의 응용 소프트웨어에서 사용 가능하기... "
#
# },
# {
# "title": "잡아라! 텍스트 마이닝 with <b>파이썬</b> (지금 바로 할 수 있는 데이터 추출과 분석)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14820664",
# "image": "https://bookthumb-phinf.pstatic.net/cover/148/206/14820664.jpg?type=m1&udate=20210509",
# "author": "서대호",
# "price": "17000",
# "discount": "15300",
# "publisher": "비제이퍼블릭",
# "pubdate": "20190430",
# "isbn": "1186697784 9791186697788",
# "description": "<b>파이썬</b>을 이용한 텍스트 마이닝으로\n‘아’ 다르고 ‘어’ 다른 한글 텍스트 분석하기알고리즘에 대한 수학적인 이해가 없어도 개념 파악을 도와주며 독자들이 코드를 따라하면서 결과를 바로바로 확인할 수 있도록 구성했다. 또한 텍스트 데이터 추출을 위해 필수적인 웹 크롤링 기술도 익힌다. 따라서... "
#
# },
# {
# "title": "21개의 작고 재미난 <b>파이썬</b> 프로젝트 (프로그래밍 스킬, 새로운 알고리즘, 테스트 주도 개발을 배우다)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20810302",
# "image": "https://bookthumb-phinf.pstatic.net/cover/208/103/20810302.jpg?type=m1&udate=20211218",
# "author": "켄 유엔스-클락",
# "price": "30000",
# "discount": "27000",
# "publisher": "제이펍",
# "pubdate": "20210811",
# "isbn": "1191600343 9791191600346",
# "description": "모든 <b>파이썬</b> 프로그래머를 위해 마련한 코딩 기술을 향상하기 위한 최고의 한 권!\n\n이 책은 다른 책들과 달리 명령줄 프로그램을 사용해서 다양한 <b>파이썬</b>의 기능을 설명하고 있다. 각 장마다 문제... 아울러 이 책은 잘 구조화되고 문서화돼 있으며, 테스트할 수 있는 코드를 <b>파이썬</b>으로 작성하는 방법을... "
#
# },
# {
# "title": "<b>파이썬</b> 데이터 과학 통계 학습",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20578051",
# "image": "https://bookthumb-phinf.pstatic.net/cover/205/780/20578051.jpg?type=m1&udate=20210731",
# "author": "황본현우|정지현",
# "price": "29000",
# "discount": "26100",
# "publisher": "정보문화사",
# "pubdate": "20210525",
# "isbn": "8956749078 9788956749075",
# "description": "<b>파이썬</b>으로 데이터 과학 완전 정복!이 책에서는 데이터 과학 데이터 분석을 위한 가장 보편적인 프로그래밍 언어인 <b>파이썬</b>을 다룬다. <b>파이썬</b>의 설치 방법과 기본적인 지식부터 차근차근 설명해나간다. 자료형, 변수, 예약어, 식별자, 리터럴 상수 등 <b>파이썬</b>의 기초부터 넘파이, 판다스, 사이파이, 사이킷런 등... "
#
# },
# {
# "title": "바이오<b>파이썬</b>으로 만나는 생물정보학 (<b>파이썬</b> 프로그래밍을 통해 풀어보는 생명의 구조)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14633452",
# "image": "https://bookthumb-phinf.pstatic.net/cover/146/334/14633452.jpg?type=m1&udate=20210211",
# "author": "한주현",
# "price": "26000",
# "discount": "23400",
# "publisher": "비제이퍼블릭",
# "pubdate": "20190322",
# "isbn": "1186697814 9791186697818",
# "description": "실제로 현업에서 사용하는 바이오<b>파이썬</b> 모듈과 100개의 프로그래밍 예제를 통해 &#x0D;생물정보학 <b>파이썬</b> 프로그래밍의 기초를 쌓을 수 있는 도서!&#x0D;... 쏟아지는 생물정보 빅데이터를 처리함에 있어 배우기 쉽고 원하는 결과를 신속하게 만들어 낼 수 있는 <b>파이썬</b>은 이 시대의 단연 인기 있는 언어다.... "
#
# },
# {
# "title": "<b>파이썬</b>을 활용한 나만의 RPA 만들기 (2021)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17716979",
# "image": "https://bookthumb-phinf.pstatic.net/cover/177/169/17716979.jpg?type=m1&udate=20210106",
# "author": "안정국",
# "price": "25000",
# "discount": "22500",
# "publisher": "삼일인포마인",
# "pubdate": "20210104",
# "isbn": "8959429120 9788959429127",
# "description": "<b>파이썬</b>을 활용하여 나만의 로봇 비서를 만들어 보자!\n\n[특장점]\n● 국내 최초로 <b>파이썬</b>을 활용한 RPA 제작 사례를 설명\n● <b>파이썬</b> 기초, 판다스 기초에 대한 상세한 설명\n● 일반업무 뿐만 아니라 재무/회계와 관련된 RPA 작성 사례 및 텔레그램을 이용한 자동 전달 기능 구현 사례 설명\n\n[주요내용]... "
#
# }
# ]
# }
#
# <class 'str'>
# {'lastBuildDate': 'Fri, 24 Dec 2021 12:35:14 +0900', 'total': 1428, 'start': 1, 'display': 100, 'items': [{'title': '이것이 취업을 위한 코딩 테스트다 with <b>파이썬</b> (취업과 이직을 결정하는 알고리즘 인터뷰 완벽 가이드)', 'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16439154', 'image': 'https://bookthumb-phinf.pstatic.net/cover/164/391/16439154.jpg?type=m1&udate=20200928', 'author': '나동빈', 'price': '34000', 'discount': '30600', 'publisher': '한빛미디어', 'pubdate': '20200805', 'isbn': '1162243074 9791162243077', 'description': '8가지 핵심 알고리즘 이론을 쉽게 설명하고, 관련 실전 문제를 풀이했다. 출제 유형 분석, 이론 설명, 기출문제 풀이까지! 어떤 코딩 테스트도 이 책 한 권으로 대비할 수 있을 것이다. 코딩 테스트에서 주로 선택하는 <b>파이썬</b>을 기반으로 설명되어 있으며, <b>파이썬</b> 코드 외에도 C/C++, 자바 코드를 추가로 제공한다.'}, {'title': '혼자 공부하는 <b>파이썬</b> (<b>파이썬</b> 최신 버전 반영)', 'link': 'http://book.naver.com/bookdb/book_detail.php?bid=15028688', 'image': 'https://bookthumb-phinf.pstatic.net/cover/150/286/15028688.jpg?type=m1&udate=20211206', 'author': '윤인성', 'price': '18000', 'discount': '16200', 'publisher': '한빛미디어', 'pubdate': '20190610', 'isbn': '1162241888 9791162241882', 'description': '1:1 과외하듯 배우는 <b>파이썬</b> 프로그래밍 자습서(<b>파이썬</b> 최신 버전 반영)\n27명의 베타리더 검증으로, ‘함께 만든’ 입문자 맞춤형 도서\n\n이 책은 독학으로 프로그래밍 언어를 처음 배우려는 입문자가, 혹은 <b>파이썬</b>을 배우려는 입문자가 ‘꼭 필요한 내용을 제대로’ 학습할 수 있도록 구성했다. ‘무엇을’... '}, {'title': 'Do it! 점프 투 <b>파이썬</b>', 'link': 'http://book.naver.com/bookdb/book_detail.php?bid=15052904', 'image': 'https://bookthumb-phinf.pstatic.net/cover/150/529/15052904.jpg?type=m1&udate=20200910', 'author': '박응용', 'price': '18800', 'discount': '16900', 'publisher': '이지스퍼블리싱', 'pubdate': '20190620', 'isbn': '1163030910 9791163030911', 'description': '<b>파이썬</b> 4년 연속 베스트셀러 1위!\n《DO IT! 점프 투 <b>파이썬</b>》 전면 개정판 출시!문과생도 중고등학생도 직장인도 프로그래밍에 눈뜨게 만든 바로 그 책이... 점프 투 <b>파이썬</b>》으로 출간되었던 이 책은 약 4년 동안의 피드백을 반영하여 초보자가 더 빠르게 입문하고, 더 깊이 있게 공부할 수 있도록 개정되었다.... '}, {'title': '<b>파이썬</b> 알고리즘 인터뷰 (95가지 알고리즘 문제 풀이로 완성하는 코딩 테스트)', 'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16406247', 'image': 'https://bookthumb-phinf.pstatic.net/cover/164/062/16406247.jpg?type=m1&udate=20211209', 'author': '박상길', 'price': '38000', 'discount': '34200', 'publisher': '책만', 'pubdate': '20200715', 'isbn': '1189909170 9791189909178', 'description': '물론, <b>파이썬</b>으로 구현하는 코드 풀이를 통해 성능 최적화 기법, <b>파이썬</b>의 핵심 문법과 다양한 실용 테크닉까지 배울 수 있는, 초보 개발자와 숙련 개발자... 이 책은 현업과 실무에 유용한 주요 알고리즘 이론을 깊숙이 이해하고, <b>파이썬</b>의 핵심 기능과 문법까지 상세하게 이해할 수 있는 취업용 코딩 테스트를... '}, {'title': '<b>파이썬</b> 무작정 따라하기 (미래의 프로그래머를 위한)', 'link': 'http://book.naver.com/bookdb/book_detail.php?bid=21354236', 'image': 'https://bookthumb-phinf.pstatic.net/cover/213/542/21354236.jpg?type=m1&udate=20211215', 'author': '송석리|서승희', 'price': '16000', 'discount': '14400', 'publisher': '길벗', 'pubdate': '20211220', 'isbn': '1165217899 9791165217891', 'description': '초등학생을 위한 <b>파이썬</b> 교재첫 코딩을 쉽고 재밌게!이 책은 초등학생부터 청소년까지 쉽고 체계적으로 <b>파이썬</b> 코딩을 배울 수 있는 책입니다. 데이터... 블록 코딩을 끝낸 뒤 텍스트 코딩을 본격적으로 배우고 싶다면 이 책으로 시작해 보세요!<b>파이썬</b> 설치부터 활용 방법, 기본 개념을 꼼꼼하게 자세하게... '}, {'title': '<b>파이썬</b> 증권 데이터 분석 (<b>파이썬</b> 입문, 웹 스크레이핑, 트레이딩 전략, 자동 매매)', 'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16381920', 'image': 'https://bookthumb-phinf.pstatic.net/cover/163/819/16381920.jpg?type=m1&udate=20201117', 'author': '김황후', 'price': '32000', 'discount': '28800', 'publisher': '한빛미디어', 'pubdate': '20200701', 'isbn': '1162243201 9791162243206', 'description': '투자 기법과 프로그래밍 기술로 &#x0D;자신만의 퀀트 투자 시스템을 완성하라&#x0D;&#x0D;『<b>파이썬</b> 증권 데이터 분석』은 웹 스크레이핑으로 증권 데이터를 주기적으로 자동 수집, 분석, 자동 매매, 예측하는 전 과정을 <b>파이썬</b>으로 직접 구현한다. 그 과정에서 금융 데이터 처리 기본 라이브러리(팬더스)부터 주가... '}, {'title': '<b>파이썬</b> 머신러닝 완벽 가이드 (다양한 캐글 예제와 함께 기초 알고리즘부터 최신 기법까지 배우는)', 'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16238302', 'image': 'https://bookthumb-phinf.pstatic.net/cover/162/383/16238302.jpg?type=m1&udate=20200423', 'author': '권철민', 'price': '38000', 'discount': '34200', 'publisher': '위키북스', 'pubdate': '20200207', 'isbn': '1158391927 9791158391928', 'description': '자세한 이론 설명과 <b>파이썬</b> 실습을 통해 머신러닝을 완벽하게 배울 ...
# ['이것이 취업을 위한 코딩 테스트다 with <b>파이썬</b> (취업과 이직을 결정하는 알고리즘 인터뷰 완벽 가이드)', '혼자 공부하는 <b>파이썬</b> (<b>파이썬</b> 최신 버전 반영)', 'Do it! 점프 투 <b>파이썬</b>', '<b>파이썬</b> 알고리즘 인터뷰 (95가지 알고리즘 문제 풀이로 완성하는 코딩 테스트)', '<b>파이썬</b> 무작정 따라하기 (미래의 프로그래머를 위한)', '<b>파이썬</b> 증권 데이터 분석 (<b>파이썬</b> 입문, 웹 스크레이핑, 트레이딩 전략, 자동 매매)', '<b>파이썬</b> 머신러닝 완벽 가이드 (다양한 캐글 예제와 함께 기초 알고리즘부터 최신 기법까지 배우는)', '쉽게 따라 만드는 <b>파이썬</b> 주식 자동매매 시스템 (증권사 API 사용, 매매전략 구현, 실전 투자 전환까지!)', '<b>파이썬</b>을 이용한 비트코인 자동매매', '머신 러닝 교과서 with <b>파이썬</b>, 사이킷런, 텐서플로 (최신 넘파이, 사이킷런, 텐서플로 2로 배우는 머신 러닝, 딥러닝 핵심 알고)', '생활코딩 머신러닝 실습편 with <b>파이썬</b> 텐서플로 (누구나 쉽게 시작하는 인공지능 첫걸음)', 'Do it! 첫 코딩 with <b>파이썬</b> (보통 사람이 알아야 할 프로그래밍 기초)', 'Do it! <b>파이썬</b> 생활 프로그래밍', '모두의 <b>파이썬</b> (20일 만에 배우는 프로그래밍 기초)', '선형대수와 통계학으로 배우는 머신러닝 with <b>파이썬</b> (선형대수와 통계학으로 배우는 머신러닝 with <b>파이썬</b>)', '혼자 공부하는 첫 프로그래밍 with <b>파이썬</b> (1:1 과외하듯 배우는 왕초보 코딩 입문서)', '모두의 데이터 분석 with <b>파이썬</b> (실생활 예제로 시작하는 데이터 분석 첫걸음)', '<b>파이썬</b> 코딩의 기술 (Effective Python 2nd,똑똑하게 코딩하는 법)', 'Do it! 첫 <b>파이썬</b> (게임하듯 배우는 나의 첫 프로그래밍 책)', '모두의 인공지능 with <b>파이썬</b> (누구나 쉽게 시작하는 딥러닝 기초 프로그래밍)', 'Do it! 장고+부트스트랩 <b>파이썬</b> 웹 개발의 정석 (웹 기초부터 블로그 개발 배포 운영까지, 만들면서 배우는 웹 개발 A to Z)', '<b>파이썬</b> 매일 코딩 (매일 10분, 50가지 연습 문제로 키우는 <b>파이썬</b> 코딩 실력!)', 'Let’s Get IT <b>파이썬</b> 프로그래밍 (데이터 분석 프로젝트로 프로그래밍 사고력 기르기)', '머신러닝&딥러닝 with <b>파이썬</b> (인공지능 핵심 개념과 사용 사례부터,한 권으로 다지는)', '<b>파이썬</b> 딥러닝 파이토치 (Python Deep Learning PyTorch)', '<b>파이썬</b> 생활밀착형 프로젝트 (웹크롤링, 카카오톡 메시지 보내기, 업무자동화까지 11가지 <b>파이썬</b>프로젝트, 백견불여일타 이젠 프로젝트다!)', '<b>파이썬</b> 인공지능 입문+실전 종합편 (한 권으로 끝내는, <b>파이썬</b>+넘파이+텐서플로우로 인공지능 딥러닝 직접 구현하기)', '엑셀 자동화 with <b>파이썬</b> (복잡하고 지루한 반복 업무를 쉽고 빠르게 해치우는 방법,일 잘하는 직장인을 위한)', '<b>파이썬</b> 머신러닝 판다스 데이터 분석', '<b>파이썬</b> 데이터 클리닝 쿡북 (<b>파이썬</b>과 판다스를 활용한 데이터 전처리)', '<b>파이썬</b> 라이브러리를 활용한 데이터 분석 (영화 평점, 이름 통계, 선거 데이터 등 실사례 사용)', '<b>파이썬</b> 머신러닝 실무 테크닉 100', '그림으로 배우는 <b>파이썬</b>', '<b>파이썬</b>으로 살펴보는 아키텍처 패턴 (TDD, DDD, EDM 적용하기)', '<b>파이썬</b>과 케라스를 이용한 딥러닝/강화학습 주식투자 (퀀트 투자 알고리즘 트레이딩을 위한 최첨단 해법 입문)', '<b>파이썬</b> 코딩 도장', '모두의 <b>파이썬</b> (20일 만에 배우는 프로그래밍 기초)', '특강마스터 <b>파이썬</b> 마스터 3급', '이것이 데이터 분석이다 with <b>파이썬</b> (<b>파이썬</b>으로 배우는 데이터 분석 입문)', 'AWS로 시작하는 AI 서비스 with <b>파이썬</b>', '데이터 과학 기반의 <b>파이썬</b> 빅데이터 분석 (IT@COOKBOOK)', '<b>파이썬</b>과 데이터 과학 (따라하며 배우는)', '<b>파이썬</b> 라이브러리를 활용한 머신러닝 (번역개정판,사이킷런 핵심 개발자가 쓴 머신러닝과 데이터 과학 실무서)', '<b>파이썬</b> GUI 프로그래밍 쿡북 (Tkinter, PyQt5를 활용한 반응형 사용자 인터페이스 개발)', '고성능 <b>파이썬</b> (<b>파이썬</b> 성능 잠재력을 끌어내는 실용적인 개발 전략서)', '<b>파이썬</b> 딥러닝 머신러닝 입문', '<b>파이썬</b>을 이용한 데이터 분석의 정석 (넘파이, 판다스, 맷플롯립과 실전 예제로 배우는)', '<b>파이썬</b> 데이터 분석 실무 테크닉 100 (100가지 예제로 배우는 데이터 가공, 머신러닝, 이미지/자연어 처리의 기술)', '<b>파이썬</b>으로 배우는 게임 개발 (입문편, 미로, 진단 애플리케이션, RPG 등을, 블록 낙하 퍼즐,퀴즈, 주사위)', '<b>파이썬</b>으로 배우는 포트폴리오 (금융공학/퀀트 투자의 기초부터 투자 모델, 머신 러닝까지!)', 'C#과 <b>파이썬</b>을 활용한 OpenCV 4 프로그래밍 (컴퓨터 비전 기초 이론부터 머신러닝을 활용한 영상 처리 프로젝트까지)', '<b>파이썬</b> 해킹 레시피 (웹 크롤링 및 취약점 진단 도구를 구현해보는 정보 보안 실습)', '<b>파이썬</b> Express (파워 유저를 위한)', '<b>파이썬</b>으로 만드는 인공지능', '<b>파이썬</b>으로 하는 데브옵스 (자동화, 클라우드, 머신러닝, 데이터 엔지니어링까지)', '직장인을 위한 데이터 분석 실무 with <b>파이썬</b> (마케팅, 영업, 기획 실무 담당자를 위한 데이터 분석의 기술)', '<b>파이썬</b> 딥러닝 텐서플로', '400제로 배우는 <b>파이썬</b> 입문 (취업 성공을 위한 속성 프로세스 + 400제 plus)', '처음 시작하는 <b>파이썬</b> (<b>파이썬</b> 패키지를 활용한 모던 컴퓨팅 입문)', '머신 러닝·딥 러닝에 필요한 기초 수학 with <b>파이썬</b>', '누구나 <b>파이썬</b> 통계분석', '두근두근 <b>파이썬</b> (쉽고! 재밌고! 흥미로운 코딩 맛!)', '시간순삭 <b>파이썬</b>', '엑셀과 비교하며 배우는 <b>파이썬</b> 데이터 분석', '<b>파이썬</b>을 이용한 알고리즘 트레이딩 (아이디어 도출부터 클라우드 배포까지)', '<b>파이썬</b> 2학년 스크래핑의 구조 (체험으로 배우고! 대화 형식으로 공부!,Python)', '전문가를 위한 <b>파이썬</b> (간단하고, 명료하고, 효율적인 <b>파이썬</b> 프로그래밍,<b>파이썬</b>3 버전 기준)', '똑똑한 <b>파이썬</b> (주니어를 위한 최적의 코딩 학습서)', '<b>파이썬</b>으로 완성하는 비지도 학습 알고리즘 (비감독 모형과 텐서플로 2를 이용한 전처리 기법의 머신러닝 구현)', '<b>파이썬</b> for Beginner (쉽고 빠르게 익히는 프로그래밍의 기본 원리)', '<b>파이썬</b>으로 배우는 알고리즘 트레이딩 (내 손으로 만드는 자동 주식 거래 시스템)', '<b>파이썬</b>과 리액트를 활용한 주식 자동 거래 시스템 구축 (데이터 수집부터 거래 자동화, API 서버, 웹 개발, 데이터 분석까지 아우르는)', 'IT 비전공자를 위한 돈 버는 <b>파이썬</b> 코딩 (N잡러 자동부업 수익창출)', '<b>파이썬</b> 스킬 업 (기초를 넘어서, <b>파이썬</b>을 <b>파이썬</b>답게 사용하자!)', '엑셀 × <b>파이썬</b> 업무 자동화 (매크로, VBA는 이제 낡았다!)', '< ...
